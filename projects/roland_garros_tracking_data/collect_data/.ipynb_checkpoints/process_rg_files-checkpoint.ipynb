# %% [markdown]
# # Functions to extract information from json files

# %% [markdown]
# To do list:
# ----------
#
# - [x] Create Trajectory data frame (separate)
#
# - [x] Create flag for which points there exist accesible trajectory data
#
# - [ ] Add in `statsData` indicator columns for Dfs, Aces, points won, etc
#
# - [ ] Figure out what returner and server coordinates are (location at last shot????)

# %%
import json
import pandas as pd
import os
import numpy as np

pd.set_option('display.max_columns', None)
pd.set_option("max_rows", None)

# %%
def get_match_level_info(tracking_data_json, year):
    '''
    Args:
    -----
    year: match year
    tracking_data_json [json]: Json file
    
    Returns:
    --------
    dict of row to append into a dataframe
    '''
    
    # Get to the crux of the information
    tracking_data_dict = tracking_data_json['courtVisionData'][0]
    
    #atp_tracking_data_dict['isMatchComplete']


    # -----------------------------
    # Player information
    # -----------------------------
    player1_info = tracking_data_dict['playersData']['playerTeam']
    player2_info = tracking_data_dict['playersData']['opponentTeam']

    
    match_dict = dict(
        year = year,
        player1 = player1_info[0]['name'],
        player2 = player2_info[0]['name'],
        player1_id = player1_info[0]['id'],
        player1_country = player1_info[0]['country'],
        player1_seed = player1_info[0]['seed'],
        player2_id = player2_info[0]['id'],
        player2_country = player2_info[0]['country'],
        player2_seed = player2_info[0]['seed'],
        
    # -------------------------------
    # - I have no idea what this is
    # -------------------------------
        point_id = tracking_data_dict['pointId'],
        court_name = tracking_data_dict['courtName'],
        court_id = tracking_data_dict['courtId'],
        num_sets_completed = tracking_data_dict['setsCompleted'],
        
        # Mens/Womens Singles
        match_type = tracking_data_dict['eventType'],

        # Complete status?
        match_status = tracking_data_dict['matchStatus']
        
        
    )
    
    return match_dict

# %%
### Loop through all json files in directory
data_list = []

for filename in os.listdir('./json_data/'):
    if filename.endswith(".json"): 
         with open('./json_data/' + filename) as file_name:
                tracking_data_json = json.load(file_name)
                file_year = [int(s) for s in filename.split('_') if s.isdigit()]
                data_list.append(get_match_level_info(tracking_data_json, year = file_year[0]))
    else:
        continue

        
available_matches = pd.DataFrame(data_list)
available_matches.sort_values(by=['year'], inplace = True)
available_matches.to_csv('matches_in_repo.csv')

#available_matches[available_matches['match_type'] == "Men's Singles"]

# %%
#available_matches[available_matches['match_type'] == "Women's Singles"]

# %% [markdown]
# ### Notes:
# -----
#
# * I suspect `point_id` is the last point played ?
#     * Ex: `2_7_6` is | Set 2 | Game 7 | 6 ? |
#     * Ex: `3_9_9` is | Set 3 | Game ? Nadal vs Djokovic was game 12... | ... |

# %% [markdown]
# ### Rough Notes

# %%
# Open one tracking json file (for debugging***)
with open('json_data/year_2020_SM001_tracking_data.json') as filename:
  atp_tracking_data_json = json.load(filename)

# %%
atp_tracking_data_dict = atp_tracking_data_json['courtVisionData'][0]
atp_tracking_data_dict.keys()
# Out:
# dict_keys(['pointsData', 'eventType', 'matchStatus', 'playersData', 'pointId', 'isMatchComplete', 'statsData', 'courtName', 'courtId', 'setsCompleted'])

# %% [markdown]
# ### Play-by-Play processing

# %%
def categorise_serve_direction(serveBounceCordinate_y):
    '''
    Args:
    -----
    
    Returns:
    --------
    
    Assumes Serve bounce coordinate is given in metres
    '''
    
    if serveBounceCordinate_y == None:
        return None
    
    one_third_length = 4.115/3

    # Tenuous at the moment
    # What if a player really miss-hits the ball, and it bounces to the opposite side of the court?
    if ( (serveBounceCordinate_y <= one_third_length) and (serveBounceCordinate_y >= -one_third_length) ):
        serve_dir = 'T'
    elif ((serveBounceCordinate_y < 2*one_third_length) and (serveBounceCordinate_y > one_third_length)  ) or ((serveBounceCordinate_y > -2*one_third_length) and (serveBounceCordinate_y < -one_third_length)  ):
        serve_dir = 'Body'
    elif (serveBounceCordinate_y >= 2*one_third_length) or ( serveBounceCordinate_y <= -2*one_third_length ):
        serve_dir = 'Wide'
    else:
        serve_dir = None
        
        
    return serve_dir

# %%
categorise_serve_direction(None)

# %%
def get_point_level_info(one_point_sequence):
    '''
    Args:
    -----
    one_point_sequence [dict]: Dictionary
    
    Returns:
    --------
    dict of row to append into a dataframe
    
    Notes:
    ------
    Don't convert them to integers...yet
    '''
    
    serve_speed_kph = one_point_sequence['ballSpeedFrench']
    if ( (serve_speed_kph == '0') | ( serve_speed_kph == 'NA' ) ):
        serve_speed_kph = one_point_sequence['returnSpeedFrench']
        
    serve_speed_v2 = one_point_sequence['ballSpeed']
    
    if ( (serve_speed_v2 == '0') | ( serve_speed_v2 == 'NA' ) ):
        serve_speed_v2 = one_point_sequence['returnSpeed']
        
    # Flag for whether we have tracking data on this point sequence
    
    is_track_avail = True
    if len(one_point_sequence['trajectoryData']) == 0 :
        is_track_avail = False
    
    
    # Identify whether serve bounce is Body, Wide, or Down the T
    serveBounceCordinate_y = one_point_sequence['serveBounceCordinate']['y']
    
    serve_dir = categorise_serve_direction(serveBounceCordinate_y)
    

    point_dict = dict(
        # Match situation information
        #point_ID_v2 = one_point_sequence['id'],
        point_ID = one_point_sequence['pointId'],
        set_num = one_point_sequence['set'],
        #set_num_v2 = one_point_sequence['setNumber'],
        game_num = one_point_sequence['game'], 
        point_num = one_point_sequence['point'],
        #point_number_v2 = one_point_sequence['pointNumber'],
        serve_num = one_point_sequence['serve'],
        
        # players involved
        server_id = one_point_sequence['serverId'],
        returner_id = one_point_sequence['receiverId'],
        point_winner_id = one_point_sequence['scorerId'],
        court_side = one_point_sequence['court'],
        
        # Serve Stats
        serve_speed_kph = serve_speed_kph,
        serve_speed_v2 = serve_speed_v2,
        serve_type = one_point_sequence['serveType'],
        fault_distance_missed_ft = one_point_sequence['distanceOutsideCourt'],
        fault_distance_missed_m = one_point_sequence['distanceOutsideCourtFrench'],
        #return_placement = one_point_sequence['returnPlacement'],
        
        
        # How point ended
        rally_length = one_point_sequence['rallyLength'],
        point_end_type = one_point_sequence['pointEndType'],
        error_type = one_point_sequence['errorType'],
        trapped_by_net = one_point_sequence['trappedByNet'],

        strokeType = one_point_sequence['strokeType'],
        hand = one_point_sequence['hand'],
        
        last_stroke_net_height_ft = one_point_sequence['heightAboveNet'],
        last_stroke_net_height_m = one_point_sequence['heightAboveNetFrench'],
        # 0 is ground height...height does not start on top of the net!!!
        
        winner_placement = one_point_sequence['winnerPlacement'],
        unforcedErrorPlacement = one_point_sequence['unforcedErrorPlacement'],
        is_break_point = one_point_sequence['breakPoint'],
        is_break_point_converted = one_point_sequence['breakPointConverted'],
        runAroundForeHand = one_point_sequence['runAroundForeHand'],

        
        # Tracking info
        is_track_avail = is_track_avail,
        
        serveBounceCordinate_x = one_point_sequence['serveBounceCordinate']['x'],
        serveBounceCordinate_y = one_point_sequence['serveBounceCordinate']['y'],
        serveBounceCordinate_z = one_point_sequence['serveBounceCordinate']['z'],
        serve_dir = serve_dir,
        
        # (initial) Ball coordinate on last shot 
        ballHitCordinate_x = one_point_sequence['ballHitCordinate']['x'],
        ballHitCordinate_y = one_point_sequence['ballHitCordinate']['y'],
        ballHitCordinate_z = one_point_sequence['ballHitCordinate']['z'],
        
        # Ball coordinate on its last bounce of rally
        ballBounceCordinate_x = one_point_sequence['ballBounceCordinate']['x'],
        ballBounceCordinate_y = one_point_sequence['ballBounceCordinate']['y'],
        ballBounceCordinate_z = one_point_sequence['ballBounceCordinate']['z'],
        
        # Server and Returner coordinates
        server_coord_x = one_point_sequence['serverCordinate']['x'],
        server_coord_y = one_point_sequence['serverCordinate']['y'],
        server_coord_z = one_point_sequence['serverCordinate']['z'],
        returner_coord_x = one_point_sequence['receiverCordinate']['x'],
        returner_coord_y = one_point_sequence['receiverCordinate']['y'],
        returner_coord_z = one_point_sequence['receiverCordinate']['z'],
        
        # unknowns
        spin_rpm = one_point_sequence['spin'],
        cruciality = one_point_sequence['cruciality'],
        returnPlacement =  one_point_sequence['returnPlacement']
    )
    
    return point_dict

# %%
# Open one tracking json file
with open('json_data/year_2020_SM001_tracking_data.json') as filename:
  atp_tracking_data_json = json.load(filename)

atp_tracking_data_dict = atp_tracking_data_json['courtVisionData'][0]
point_id = '1_1_6_1'
one_point_sequence = atp_tracking_data_dict['pointsData'][point_id]


get_point_level_info(one_point_sequence)
# Out:
# {'point_ID': '1_1_6_1',
#  'set_num': '1',
#  'game_num': '1',
#  'point_num': '6',
#  'serve_num': '1',
#  'server_id': '9801',
#  'returner_id': '7792',
#  'point_winner_id': '7792',
#  'court_side': 'AdCourt',
#  'serve_speed_kph': '190 KPH',
#  'serve_speed_v2': '190 KPH',
#  'serve_type': 'Flat',
#  'fault_distance_missed_ft': 'NA',
#  'fault_distance_missed_m': 'NA',
#  'rally_length': 10,
#  'point_end_type': 'Winner',
#  'error_type': 'NA',
#  'trapped_by_net': False,
#  'strokeType': 'Ground',
#  'hand': 'BackHand',
#  'last_stroke_net_height_ft': '5.01 Feet',
#  'last_stroke_net_height_m': '1.53 Metre',
#  'winner_placement': 'Cross Court',
#  'unforcedErrorPlacement': 'NA',
#  'is_break_point': False,
#  'is_break_point_converted': False,
#  'runAroundForeHand': False,
#  'is_track_avail': True,
#  'serveBounceCordinate_x': 5.643,
#  'serveBounceCordinate_y': -0.478,
#  'serveBounceCordinate_z': 0.039,
#  'serve_dir': 'T',
#  'ballHitCordinate_x': 11.172,
#  'ballHitCordinate_y': 2.161,
#  'ballHitCordinate_z': 1.04,
#  'ballBounceCordinate_x': -9.23,
#  'ballBounceCordinate_y': -4.023,
#  'ballBounceCordinate_z': 0.033,
#  'server_coord_x': -16.408,
#  'server_coord_y': 2.816,
#  'server_coord_z': 0.0,
#  'returner_coord_x': 11.882,
#  'returner_coord_y': 1.555,
#  'returner_coord_z': 0.0,
#  'spin_rpm': '3162.74',
#  'cruciality': 'false',
#  'returnPlacement': 3.5097500000000004}

# %%
def get_match_point_level_info(raw_json_file):
    '''
    Args:
    -----
    one_point_sequence [dict]: Dictionary
    
    Returns:
    --------
    pandas DataFrame
    '''
    all_tracking_data_dict = raw_json_file['courtVisionData'][0]['pointsData']
    
    data_list = []
    for point_id_key in sorted(all_tracking_data_dict.keys()):
        #print(point_id_key)
        data_list.append( get_point_level_info( all_tracking_data_dict[point_id_key] ) )
    
    match_point_df = pd.DataFrame(data_list)
    
    # Sort Dataframe by Set Number, Game number, Point Number, Serve Number
    match_point_df[['set_num', 'game_num', 'point_num', 'serve_num']] = match_point_df[['set_num', 'game_num', 'point_num', 'serve_num']].astype(int)


    match_point_df.sort_values(by = ['set_num', 'game_num', 'point_num', 'serve_num'], inplace = True)
    
    return match_point_df

# %%
test_match = get_match_point_level_info(atp_tracking_data_json)
test_match.to_csv('point_sequence_djokovic_nadal_2020_rolandgarros_pbp.csv', index = False)
#test_match[['point_ID','server_coord_x', 'server_coord_y', 'server_coord_z', 'returner_coord_x','returner_coord_y', 'returner_coord_z']]

#test_match[['point_end_type', 'error_type', 'fault_distance_missed_m','last_stroke_net_height_m', 'serveBounceCordinate_x', 'serveBounceCordinate_y', 'serveBounceCordinate_z']]

# %%
#test_match[['point_ID', 'point_end_type', 'strokeType', 'hand']]
#test_match[['is_track_avail','point_ID', 'point_end_type', 'error_type', 'serve_num', 'distance_missed_fault_ft', 'distance_missed_fault_m', 'last_stroke_net_clearance_m']]
test_match
# Out:
#      point_ID  set_num  game_num  point_num  serve_num server_id returner_id  \
# 0     1_1_1_1        1         1          1          1      9801        7792
# 1     1_1_1_2        1         1          1          2      9801        7792
# 2     1_1_2_1        1         1          2          1      9801        7792
# 3     1_1_2_2        1         1          2          2      9801        7792
# 4     1_1_3_1        1         1          3          1      9801        7792
# 5     1_1_3_2        1         1          3          2      9801        7792
# 6     1_1_4_2        1         1          4          2      9801        7792
# 7     1_1_5_1        1         1          5          1      9801        7792
# 8     1_1_6_1        1         1          6          1      9801        7792
# 9     1_1_7_1        1         1          7          1      9801        7792
# 10    1_1_8_1        1         1          8          1      9801        7792
# 11    1_1_8_2        1         1          8          2      9801        7792
# 12    1_2_1_1        1         2          1          1      7792        9801
# 13    1_2_1_2        1         2          1          2      7792        9801
# 14    1_2_2_1        1         2          2          1      7792        9801
# 15    1_2_3_1        1         2          3          1      7792        9801
# 16    1_2_4_1        1         2          4          1      7792        9801
# 17    1_2_4_2        1         2          4          2      7792        9801
# 18    1_2_5_1        1         2          5          1      7792        9801
# 19    1_2_6_1        1         2          6          1      7792        9801
# 20    1_2_7_1        1         2          7          1      7792        9801
# 21    1_2_7_2        1         2          7          2      7792        9801
# 22    1_2_8_1        1         2          8          1      7792        9801
# 23    1_3_1_1        1         3          1          1      9801        7792
# 24    1_3_1_2        1         3          1          2      9801        7792
# 25    1_3_2_1        1         3          2          1      9801        7792
# 26    1_3_2_2        1         3          2          2      9801        7792
# 27    1_3_3_1        1         3          3          1      9801        7792
# 28    1_3_4_1        1         3          4          1      9801        7792
# 29    1_3_4_2        1         3          4          2      9801        7792
# 30    1_3_5_1        1         3          5          1      9801        7792
# 31    1_3_5_2        1         3          5          2      9801        7792
# 32    1_3_6_1        1         3          6          1      9801        7792
# 33    1_3_6_2        1         3          6          2      9801        7792
# 37    1_4_1_1        1         4          1          1      7792        9801
# 38    1_4_2_1        1         4          2          1      7792        9801
# 39    1_4_3_1        1         4          3          1      7792        9801
# 40    1_4_3_2        1         4          3          2      7792        9801
# 41    1_4_4_1        1         4          4          1      7792        9801
# 42    1_4_5_1        1         4          5          1      7792        9801
# 43    1_4_6_1        1         4          6          1      7792        9801
# 44    1_4_7_1        1         4          7          1      7792        9801
# 45    1_4_8_1        1         4          8          1      7792        9801
# 46    1_4_8_2        1         4          8          2      7792        9801
# 47    1_4_9_1        1         4          9          1      7792        9801
# 48    1_4_9_2        1         4          9          2      7792        9801
# 34   1_4_10_1        1         4         10          1      7792        9801
# 35   1_4_11_1        1         4         11          1      7792        9801
# 36   1_4_12_1        1         4         12          1      7792        9801
# 52    1_5_1_1        1         5          1          1      9801        7792
# 53    1_5_2_2        1         5          2          2      9801        7792
# 54    1_5_3_1        1         5          3          1      9801        7792
# 55    1_5_4_2        1         5          4          2      9801        7792
# 56    1_5_5_2        1         5          5          2      9801        7792
# 57    1_5_6_1        1         5          6          1      9801        7792
# 58    1_5_7_1        1         5          7          1      9801        7792
# 59    1_5_8_2        1         5          8          2      9801        7792
# 60    1_5_9_2        1         5          9          2      9801        7792
# 49   1_5_10_1        1         5         10          1      9801        7792
# 50   1_5_11_1        1         5         11          1      9801        7792
# 51   1_5_12_1        1         5         12          1      9801        7792
# 61    1_6_1_1        1         6          1          1      7792        9801
# 62    1_6_2_1        1         6          2          1      7792        9801
# 63    1_6_3_1        1         6          3          1      7792        9801
# 64    1_6_4_1        1         6          4          1      7792        9801
# 65    1_6_5_1        1         6          5          1      7792        9801
# 70    2_1_1_1        2         1          1          1      9801        7792
# 71    2_1_2_1        2         1          2          1      9801        7792
# 72    2_1_3_1        2         1          3          1      9801        7792
# 73    2_1_4_1        2         1          4          1      9801        7792
# 74    2_1_5_1        2         1          5          1      9801        7792
# 75    2_1_6_1        2         1          6          1      9801        7792
# 76    2_1_7_1        2         1          7          1      9801        7792
# 77    2_1_8_1        2         1          8          1      9801        7792
# 78    2_1_9_1        2         1          9          1      9801        7792
# 66   2_1_10_1        2         1         10          1      9801        7792
# 67   2_1_10_2        2         1         10          2      9801        7792
# 68   2_1_11_1        2         1         11          1      9801        7792
# 69   2_1_12_1        2         1         12          1      9801        7792
# 79    2_2_1_1        2         2          1          1      7792        9801
# 80    2_2_2_1        2         2          2          1      7792        9801
# 81    2_2_3_1        2         2          3          1      7792        9801
# 82    2_2_4_1        2         2          4          1      7792        9801
# 83    2_2_4_2        2         2          4          2      7792        9801
# 84    2_2_5_1        2         2          5          1      7792        9801
# 85    2_2_6_1        2         2          6          1      7792        9801
# 87    2_3_1_1        2         3          1          1      9801        7792
# 88    2_3_1_2        2         3          1          2      9801        7792
# 89    2_3_2_1        2         3          2          1      9801        7792
# 90    2_3_3_1        2         3          3          1      9801        7792
# 91    2_3_4_1        2         3          4          1      9801        7792
# 92    2_3_5_1        2         3          5          1      9801        7792
# 93    2_3_5_2        2         3          5          2      9801        7792
# 94    2_3_6_1        2         3          6          1      9801        7792
# 95    2_3_7_1        2         3          7          1      9801        7792
# 96    2_3_7_2        2         3          7          2      9801        7792
# 97    2_3_8_1        2         3          8          1      9801        7792
# 98    2_3_9_1        2         3          9          1      9801        7792
# 86   2_3_10_1        2         3         10          1      9801        7792
# 99    2_4_1_1        2         4          1          1      7792        9801
# 100   2_4_2_1        2         4          2          1      7792        9801
# 101   2_4_3_1        2         4          3          1      7792        9801
# 102   2_4_4_1        2         4          4          1      7792        9801
# 103   2_4_5_1        2         4          5          1      7792        9801
# 104   2_4_6_1        2         4          6          1      7792        9801
# 105   2_4_7_1        2         4          7          1      7792        9801
# 106   2_4_8_1        2         4          8          1      7792        9801
# 107   2_4_8_2        2         4          8          2      7792        9801
# 108   2_5_1_1        2         5          1          1      9801        7792
# 109   2_5_1_2        2         5          1          2      9801        7792
# 110   2_5_2_1        2         5          2          1      9801        7792
# 111   2_5_3_1        2         5          3          1      9801        7792
# 112   2_5_4_1        2         5          4          1      9801        7792
# 113   2_5_5_1        2         5          5          1      9801        7792
# 114   2_5_5_2        2         5          5          2      9801        7792
# 115   2_5_6_1        2         5          6          1      9801        7792
# 116   2_5_7_1        2         5          7          1      9801        7792
# 117   2_5_8_1        2         5          8          1      9801        7792
# 118   2_6_1_1        2         6          1          1      7792        9801
# 119   2_6_1_2        2         6          1          2      7792        9801
# 120   2_6_2_1        2         6          2          1      7792        9801
# 121   2_6_3_1        2         6          3          1      7792        9801
# 122   2_6_4_1        2         6          4          1      7792        9801
# 123   2_6_4_2        2         6          4          2      7792        9801
# 124   2_7_1_1        2         7          1          1      9801        7792
# 125   2_7_2_1        2         7          2          1      9801        7792
# 126   2_7_2_2        2         7          2          2      9801        7792
# 127   2_7_3_1        2         7          3          1      9801        7792
# 128   2_7_4_1        2         7          4          1      9801        7792
# 129   2_7_4_2        2         7          4          2      9801        7792
# 130   2_7_5_1        2         7          5          1      9801        7792
# 131   2_8_1_1        2         8          1          1      7792        9801
# 132   2_8_2_1        2         8          2          1      7792        9801
# 133   2_8_2_2        2         8          2          2      7792        9801
# 134   2_8_3_1        2         8          3          1      7792        9801
# 135   2_8_4_1        2         8          4          1      7792        9801
# 136   2_8_4_2        2         8          4          2      7792        9801
# 137   2_8_5_1        2         8          5          1      7792        9801
# 138   2_8_5_2        2         8          5          2      7792        9801
# 139   2_8_6_1        2         8          6          1      7792        9801
# 140   2_8_6_2        2         8          6          2      7792        9801
# 161   3_1_1_1        3         1          1          1      9801        7792
# 162   3_1_1_2        3         1          1          2      9801        7792
# 163   3_1_2_1        3         1          2          1      9801        7792
# 164   3_1_3_1        3         1          3          1      9801        7792
# 165   3_1_4_1        3         1          4          1      9801        7792
# 166   3_1_5_1        3         1          5          1      9801        7792
# 167   3_1_5_2        3         1          5          2      9801        7792
# 168   3_2_1_1        3         2          1          1      7792        9801
# 169   3_2_2_1        3         2          2          1      7792        9801
# 170   3_2_3_1        3         2          3          1      7792        9801
# 171   3_2_4_1        3         2          4          1      7792        9801
# 172   3_2_5_1        3         2          5          1      7792        9801
# 173   3_2_6_1        3         2          6          1      7792        9801
# 174   3_3_1_1        3         3          1          1      9801        7792
# 175   3_3_1_2        3         3          1          2      9801        7792
# 176   3_3_2_1        3         3          2          1      9801        7792
# 177   3_3_2_2        3         3          2          2      9801        7792
# 178   3_3_3_1        3         3          3          1      9801        7792
# 179   3_3_4_1        3         3          4          1      9801        7792
# 180   3_3_5_1        3         3          5          1      9801        7792
# 181   3_3_6_1        3         3          6          1      9801        7792
# 182   3_3_6_2        3         3          6          2      9801        7792
# 183   3_3_7_1        3         3          7          1      9801        7792
# 184   3_3_8_1        3         3          8          1      9801        7792
# 185   3_3_8_2        3         3          8          2      9801        7792
# 186   3_4_1_1        3         4          1          1      7792        9801
# 187   3_4_1_2        3         4          1          2      7792        9801
# 188   3_4_2_1        3         4          2          1      7792        9801
# 189   3_4_2_2        3         4          2          2      7792        9801
# 190   3_4_3_1        3         4          3          1      7792        9801
# 191   3_4_3_2        3         4          3          2      7792        9801
# 192   3_4_4_1        3         4          4          1      7792        9801
# 193   3_4_4_2        3         4          4          2      7792        9801
# 194   3_4_5_1        3         4          5          1      7792        9801
# 195   3_4_5_2        3         4          5          2      7792        9801
# 196   3_4_6_1        3         4          6          1      7792        9801
# 197   3_5_1_1        3         5          1          1      9801        7792
# 198   3_5_2_1        3         5          2          1      9801        7792
# 199   3_5_3_1        3         5          3          1      9801        7792
# 200   3_5_4_1        3         5          4          1      9801        7792
# 201   3_6_1_1        3         6          1          1      7792        9801
# 202   3_6_1_2        3         6          1          2      7792        9801
# 203   3_6_2_1        3         6          2          1      7792        9801
# 204   3_6_3_1        3         6          3          1      7792        9801
# 205   3_6_3_2        3         6          3          2      7792        9801
# 206   3_6_4_1        3         6          4          1      7792        9801
# 207   3_6_5_1        3         6          5          1      7792        9801
# 208   3_6_6_1        3         6          6          1      7792        9801
# 209   3_6_6_2        3         6          6          2      7792        9801
# 210   3_6_7_1        3         6          7          1      7792        9801
# 211   3_6_7_2        3         6          7          2      7792        9801
# 212   3_6_8_1        3         6          8          1      7792        9801
# 213   3_6_8_2        3         6          8          2      7792        9801
# 214   3_7_1_1        3         7          1          1      9801        7792
# 215   3_7_2_1        3         7          2          1      9801        7792
# 216   3_7_3_1        3         7          3          1      9801        7792
# 217   3_7_3_2        3         7          3          2      9801        7792
# 218   3_7_4_1        3         7          4          1      9801        7792
# 219   3_7_5_1        3         7          5          1      9801        7792
# 220   3_8_1_1        3         8          1          1      7792        9801
# 221   3_8_2_1        3         8          2          1      7792        9801
# 222   3_8_2_2        3         8          2          2      7792        9801
# 223   3_8_3_1        3         8          3          1      7792        9801
# 224   3_8_4_1        3         8          4          1      7792        9801
# 225   3_8_5_1        3         8          5          1      7792        9801
# 226   3_8_6_1        3         8          6          1      7792        9801
# 228   3_9_1_1        3         9          1          1      9801        7792
# 229   3_9_2_1        3         9          2          1      9801        7792
# 230   3_9_3_1        3         9          3          1      9801        7792
# 231   3_9_4_1        3         9          4          1      9801        7792
# 232   3_9_5_1        3         9          5          1      9801        7792
# 233   3_9_6_1        3         9          6          1      9801        7792
# 234   3_9_6_2        3         9          6          2      9801        7792
# 235   3_9_7_1        3         9          7          1      9801        7792
# 236   3_9_8_1        3         9          8          1      9801        7792
# 237   3_9_8_2        3         9          8          2      9801        7792
# 238   3_9_9_1        3         9          9          1      9801        7792
# 227  3_9_10_1        3         9         10          1      9801        7792
# 141  3_10_1_1        3        10          1          1      7792        9801
# 142  3_10_2_1        3        10          2          1      7792        9801
# 143  3_10_3_1        3        10          3          1      7792        9801
# 144  3_10_3_2        3        10          3          2      7792        9801
# 145  3_10_4_1        3        10          4          1      7792        9801
# 146  3_10_4_2        3        10          4          2      7792        9801
# 147  3_10_5_1        3        10          5          1      7792        9801
# 148  3_10_5_2        3        10          5          2      7792        9801
# 149  3_11_1_1        3        11          1          1      9801        7792
# 150  3_11_2_1        3        11          2          1      9801        7792
# 151  3_11_3_1        3        11          3          1      9801        7792
# 152  3_11_4_1        3        11          4          1      9801        7792
# 153  3_11_5_1        3        11          5          1      9801        7792
# 154  3_11_6_1        3        11          6          1      9801        7792
# 155  3_11_6_2        3        11          6          2      9801        7792
# 156  3_12_1_1        3        12          1          1      7792        9801
# 157  3_12_1_2        3        12          1          2      7792        9801
# 158  3_12_2_1        3        12          2          1      7792        9801
# 159  3_12_3_1        3        12          3          1      7792        9801
# 160  3_12_4_1        3        12          4          1      7792        9801
#
#     point_winner_id  court_side serve_speed_kph serve_speed_v2    serve_type  \
# 0              None  DeuceCourt           0 KPH             NA            NA
# 1              9801  DeuceCourt         136 KPH        136 KPH            NA
# 2              9801  DeuceCourt           0 KPH             NA            NA
# 3              7792     AdCourt           0 KPH             NA            NA
# 4              7792  DeuceCourt           0 KPH             NA            NA
# 5              9801  DeuceCourt         137 KPH        137 KPH            NA
# 6              9801     AdCourt         153 KPH        153 KPH            NA
# 7              7792  DeuceCourt         194 KPH        194 KPH            NA
# 8              7792     AdCourt         190 KPH        190 KPH          Flat
# 9              7792  DeuceCourt         174 KPH        174 KPH  Unclassified
# 10             7792     AdCourt      193.31 KPH     193.31 KPH  Unclassified
# 11             7792     AdCourt         134 KPH        134 KPH  Unclassified
# 12             None  DeuceCourt      191.41 KPH     191.41 KPH  Unclassified
# 13             9801  DeuceCourt         149 KPH        149 KPH          Flat
# 14             7792     AdCourt         170 KPH        170 KPH      Pronated
# 15             7792  DeuceCourt         188 KPH        188 KPH         Slice
# 16             7792     AdCourt      197.42 KPH     197.42 KPH  Unclassified
# 17             7792     AdCourt         161 KPH        161 KPH  Unclassified
# 18             9801  DeuceCourt         182 KPH        182 KPH          Flat
# 19             9801     AdCourt         192 KPH        192 KPH  Unclassified
# 20             9801  DeuceCourt      191.74 KPH     191.74 KPH  Unclassified
# 21             7792  DeuceCourt         145 KPH        145 KPH      Pronated
# 22             7792     AdCourt         165 KPH        165 KPH      Pronated
# 23             7792  DeuceCourt      195.21 KPH     195.21 KPH  Unclassified
# 24             9801  DeuceCourt         144 KPH        144 KPH          Flat
# 25             9801     AdCourt      194.78 KPH     194.78 KPH  Unclassified
# 26             7792     AdCourt         149 KPH        149 KPH  Unclassified
# 27             7792  DeuceCourt         179 KPH        179 KPH      Pronated
# 28             7792     AdCourt      197.18 KPH     197.18 KPH         Slice
# 29             7792     AdCourt      152.36 KPH     152.36 KPH         Slice
# 30             7792  DeuceCourt      158.13 KPH     158.13 KPH  Unclassified
# 31             9801  DeuceCourt         151 KPH        151 KPH  Unclassified
# 32             9801     AdCourt      193.86 KPH     193.86 KPH  Unclassified
# 33             7792     AdCourt         144 KPH        144 KPH  Unclassified
# 37             7792  DeuceCourt         179 KPH        179 KPH  Unclassified
# 38             9801     AdCourt         185 KPH        185 KPH         Slice
# 39             9801  DeuceCourt      191.72 KPH     191.72 KPH         Slice
# 40             7792  DeuceCourt         149 KPH        149 KPH          Flat
# 41             9801     AdCourt         181 KPH        181 KPH         Slice
# 42             9801  DeuceCourt         178 KPH        178 KPH  Unclassified
# 43             7792     AdCourt         186 KPH        186 KPH      Pronated
# 44             9801  DeuceCourt         188 KPH        188 KPH      Pronated
# 45             9801     AdCourt      182.63 KPH     182.63 KPH         Slice
# 46             7792     AdCourt         152 KPH        152 KPH          Flat
# 47             7792  DeuceCourt      188.58 KPH     188.58 KPH      Pronated
# 48             9801  DeuceCourt         150 KPH        150 KPH  Unclassified
# 34             7792     AdCourt         171 KPH        171 KPH          Flat
# 35             7792  DeuceCourt         192 KPH        192 KPH          Flat
# 36             7792     AdCourt              NA             NA            NA
# 52             9801  DeuceCourt         186 KPH        186 KPH            NA
# 53             9801     AdCourt         145 KPH        145 KPH            NA
# 54             9801  DeuceCourt         190 KPH        190 KPH            NA
# 55             7792     AdCourt         179 KPH        179 KPH            NA
# 56             7792  DeuceCourt         144 KPH        144 KPH            NA
# 57             7792     AdCourt         187 KPH        187 KPH            NA
# 58             7792  DeuceCourt         193 KPH        193 KPH            NA
# 59             9801     AdCourt         143 KPH        143 KPH            NA
# 60             7792  DeuceCourt         179 KPH        179 KPH            NA
# 49             9801     AdCourt         185 KPH        185 KPH            NA
# 50             7792  DeuceCourt         190 KPH        190 KPH          Flat
# 51             7792     AdCourt         185 KPH        185 KPH      Pronated
# 61             7792  DeuceCourt         187 KPH        187 KPH      Pronated
# 62             9801     AdCourt         185 KPH        185 KPH          Flat
# 63             7792  DeuceCourt         188 KPH        188 KPH          Flat
# 64             7792     AdCourt         185 KPH        185 KPH          Flat
# 65             7792  DeuceCourt         177 KPH        177 KPH          Flat
# 70             9801  DeuceCourt         180 KPH        180 KPH      Pronated
# 71             7792     AdCourt         182 KPH        182 KPH  Unclassified
# 72             7792  DeuceCourt         187 KPH        187 KPH      Pronated
# 73             7792     AdCourt         187 KPH        187 KPH          Flat
# 74             9801  DeuceCourt         191 KPH        191 KPH      Pronated
# 75             9801     AdCourt         186 KPH        186 KPH          Flat
# 76             7792  DeuceCourt         193 KPH        193 KPH          Flat
# 77             9801     AdCourt         188 KPH        188 KPH      Pronated
# 78             9801  DeuceCourt         190 KPH        190 KPH  Unclassified
# 66             9801     AdCourt      199.09 KPH     199.09 KPH          Flat
# 67             7792     AdCourt         148 KPH        148 KPH          Flat
# 68             9801  DeuceCourt         171 KPH        171 KPH  Unclassified
# 69             9801     AdCourt         190 KPH        190 KPH          Flat
# 79             7792  DeuceCourt         186 KPH        186 KPH         Slice
# 80             9801     AdCourt         171 KPH        171 KPH          Flat
# 81             9801  DeuceCourt         176 KPH        176 KPH          Flat
# 82             9801     AdCourt      179.94 KPH     179.94 KPH      Pronated
# 83             7792     AdCourt         152 KPH        152 KPH  Unclassified
# 84             7792  DeuceCourt         183 KPH        183 KPH      Pronated
# 85             7792     AdCourt         171 KPH        171 KPH  Unclassified
# 87             9801  DeuceCourt      176.59 KPH     176.59 KPH         Slice
# 88             7792  DeuceCourt         142 KPH        142 KPH         Slice
# 89             7792     AdCourt         188 KPH        188 KPH          Flat
# 90             9801  DeuceCourt         169 KPH        169 KPH      Pronated
# 91             9801     AdCourt         186 KPH        186 KPH      Pronated
# 92             9801  DeuceCourt      174.19 KPH     174.19 KPH  Unclassified
# 93             7792  DeuceCourt         144 KPH        144 KPH  Unclassified
# 94             9801     AdCourt         188 KPH        188 KPH         Slice
# 95             9801  DeuceCourt      198.53 KPH     198.53 KPH          Flat
# 96             7792  DeuceCourt         140 KPH        140 KPH          Flat
# 97             9801     AdCourt         191 KPH        191 KPH  Unclassified
# 98             7792  DeuceCourt         193 KPH        193 KPH          Flat
# 86             7792     AdCourt         185 KPH        185 KPH  Unclassified
# 99             9801  DeuceCourt         189 KPH        189 KPH      Pronated
# 100            7792     AdCourt         170 KPH        170 KPH         Slice
# 101            7792  DeuceCourt         193 KPH        193 KPH  Unclassified
# 102            7792     AdCourt         187 KPH        187 KPH  Unclassified
# 103            9801  DeuceCourt         188 KPH        188 KPH          Flat
# 104            9801     AdCourt         174 KPH        174 KPH          Flat
# 105            7792  DeuceCourt         184 KPH        184 KPH      Pronated
# 106            7792     AdCourt      200.97 KPH     200.97 KPH      Pronated
# 107            7792     AdCourt         145 KPH        145 KPH  Unclassified
# 108            7792  DeuceCourt      192.62 KPH     192.62 KPH          Flat
# 109            9801  DeuceCourt         137 KPH        137 KPH         Slice
# 110            7792     AdCourt         189 KPH        189 KPH  Unclassified
# 111            7792  DeuceCourt         189 KPH        189 KPH      Pronated
# 112            9801     AdCourt         188 KPH        188 KPH      Pronated
# 113            7792  DeuceCourt      194.33 KPH     194.33 KPH  Unclassified
# 114            7792  DeuceCourt      145.63 KPH     145.63 KPH  Unclassified
# 115            9801     AdCourt         190 KPH        190 KPH          Flat
# 116            7792  DeuceCourt         185 KPH        185 KPH         Slice
# 117            7792     AdCourt         184 KPH        184 KPH          Flat
# 118            7792  DeuceCourt      196.32 KPH     196.32 KPH         Slice
# 119            7792  DeuceCourt         142 KPH        142 KPH      Pronated
# 120            7792     AdCourt         173 KPH        173 KPH  Unclassified
# 121            7792  DeuceCourt         185 KPH        185 KPH      Pronated
# 122            7792     AdCourt      192.93 KPH     192.93 KPH      Pronated
# 123            7792     AdCourt         149 KPH        149 KPH      Pronated
# 124            7792  DeuceCourt         187 KPH        187 KPH      Pronated
# 125            7792     AdCourt      186.43 KPH     186.43 KPH          Flat
# 126            9801     AdCourt         143 KPH        143 KPH         Slice
# 127            9801  DeuceCourt         193 KPH        193 KPH      Pronated
# 128            9801     AdCourt      194.09 KPH     194.09 KPH  Unclassified
# 129            9801     AdCourt         147 KPH        147 KPH      Pronated
# 130            9801  DeuceCourt         191 KPH        191 KPH      Pronated
# 131            7792  DeuceCourt         182 KPH        182 KPH  Unclassified
# 132            7792     AdCourt      201.07 KPH     201.07 KPH  Unclassified
# 133            7792     AdCourt         136 KPH        136 KPH  Unclassified
# 134            7792  DeuceCourt         189 KPH        189 KPH      Pronated
# 135            9801     AdCourt      201.33 KPH     201.33 KPH      Pronated
# 136            9801     AdCourt      174.61 KPH     174.61 KPH      Pronated
# 137            7792  DeuceCourt      192.41 KPH     192.41 KPH  Unclassified
# 138            9801  DeuceCourt         148 KPH        148 KPH      Pronated
# 139            9801     AdCourt      175.18 KPH     175.18 KPH  Unclassified
# 140            7792     AdCourt         143 KPH        143 KPH  Unclassified
# 161            9801  DeuceCourt      171.27 KPH     171.27 KPH         Slice
# 162            7792  DeuceCourt         152 KPH        152 KPH         Slice
# 163            9801     AdCourt         183 KPH        183 KPH      Pronated
# 164            9801  DeuceCourt         169 KPH        169 KPH          Flat
# 165            9801     AdCourt         181 KPH        181 KPH      Pronated
# 166            9801  DeuceCourt      195.92 KPH     195.92 KPH  Unclassified
# 167            9801  DeuceCourt         155 KPH        155 KPH      Pronated
# 168            9801  DeuceCourt         188 KPH        188 KPH          Flat
# 169            7792     AdCourt         165 KPH        165 KPH      Pronated
# 170            7792  DeuceCourt         189 KPH        189 KPH      Pronated
# 171            7792     AdCourt         170 KPH        170 KPH      Pronated
# 172            9801  DeuceCourt         181 KPH        181 KPH          Flat
# 173            7792     AdCourt         169 KPH        169 KPH      Pronated
# 174            9801  DeuceCourt      174.69 KPH     174.69 KPH         Slice
# 175            7792  DeuceCourt         141 KPH        141 KPH         Slice
# 176            7792     AdCourt      192.83 KPH     192.83 KPH  Unclassified
# 177            9801     AdCourt         158 KPH        158 KPH      Pronated
# 178            7792  DeuceCourt         178 KPH        178 KPH          Flat
# 179            9801     AdCourt         188 KPH        188 KPH      Pronated
# 180            7792  DeuceCourt         174 KPH        174 KPH      Pronated
# 181            7792     AdCourt      200.67 KPH     200.67 KPH      Pronated
# 182            9801     AdCourt         150 KPH        150 KPH          Flat
# 183            9801  DeuceCourt         169 KPH        169 KPH      Pronated
# 184            9801     AdCourt      197.05 KPH     197.05 KPH      Pronated
# 185            9801     AdCourt         137 KPH        137 KPH          Flat
# 186            7792  DeuceCourt      190.71 KPH     190.71 KPH      Pronated
# 187            9801  DeuceCourt         141 KPH        141 KPH          Flat
# 188            9801     AdCourt      185.35 KPH     185.35 KPH          Flat
# 189            7792     AdCourt         141 KPH        141 KPH  Unclassified
# 190            7792  DeuceCourt      186.84 KPH     186.84 KPH         Slice
# 191            7792  DeuceCourt         153 KPH        153 KPH      Pronated
# 192            7792     AdCourt      170.57 KPH     170.57 KPH  Unclassified
# 193            9801     AdCourt         147 KPH        147 KPH      Pronated
# 194            9801  DeuceCourt      179.81 KPH     179.81 KPH  Unclassified
# 195            7792  DeuceCourt         149 KPH        149 KPH          Flat
# 196            7792     AdCourt         173 KPH        173 KPH          Flat
# 197            7792  DeuceCourt         172 KPH        172 KPH  Unclassified
# 198            7792     AdCourt         182 KPH        182 KPH      Pronated
# 199            7792  DeuceCourt         190 KPH        190 KPH      Pronated
# 200            7792     AdCourt         184 KPH        184 KPH  Unclassified
# 201            7792  DeuceCourt      192.24 KPH     192.24 KPH          Flat
# 202            7792  DeuceCourt         150 KPH        150 KPH      Pronated
# 203            9801     AdCourt         178 KPH        178 KPH      Pronated
# 204            9801  DeuceCourt      182.27 KPH     182.27 KPH  Unclassified
# 205            9801  DeuceCourt         145 KPH        145 KPH  Unclassified
# 206            7792     AdCourt         157 KPH        157 KPH         Slice
# 207            9801  DeuceCourt         182 KPH        182 KPH      Pronated
# 208            9801     AdCourt      194.07 KPH     194.07 KPH          Flat
# 209            7792     AdCourt         147 KPH        147 KPH      Pronated
# 210            7792  DeuceCourt      203.97 KPH     203.97 KPH  Unclassified
# 211            9801  DeuceCourt         158 KPH        158 KPH         Slice
# 212            9801     AdCourt      169.56 KPH     169.56 KPH      Pronated
# 213            9801     AdCourt         151 KPH        151 KPH          Flat
# 214            9801  DeuceCourt         169 KPH        169 KPH         Slice
# 215            7792     AdCourt         193 KPH        193 KPH      Pronated
# 216            7792  DeuceCourt      193.04 KPH     193.04 KPH      Pronated
# 217            9801  DeuceCourt         135 KPH        135 KPH          Flat
# 218            9801     AdCourt         189 KPH        189 KPH      Pronated
# 219            9801  DeuceCourt         174 KPH        174 KPH      Pronated
# 220            7792  DeuceCourt         184 KPH        184 KPH         Slice
# 221            7792     AdCourt      175.95 KPH     175.95 KPH  Unclassified
# 222            9801     AdCourt         156 KPH        156 KPH  Unclassified
# 223            7792  DeuceCourt         188 KPH        188 KPH          Flat
# 224            7792     AdCourt         180 KPH        180 KPH  Unclassified
# 225            9801  DeuceCourt         189 KPH        189 KPH      Pronated
# 226            7792     AdCourt         195 KPH        195 KPH  Unclassified
# 228            9801  DeuceCourt         189 KPH        189 KPH      Pronated
# 229            7792     AdCourt         191 KPH        191 KPH      Pronated
# 230            9801  DeuceCourt         189 KPH        189 KPH         Slice
# 231            7792     AdCourt         190 KPH        190 KPH          Kick
# 232            9801  DeuceCourt         195 KPH        195 KPH  Unclassified
# 233            9801     AdCourt      198.61 KPH     198.61 KPH  Unclassified
# 234            7792     AdCourt         150 KPH        150 KPH  Unclassified
# 235            7792  DeuceCourt         172 KPH        172 KPH      Pronated
# 236            7792     AdCourt      194.76 KPH     194.76 KPH          Flat
# 237            9801     AdCourt         186 KPH        186 KPH         Slice
# 238            9801  DeuceCourt         175 KPH        175 KPH      Pronated
# 227            9801     AdCourt         190 KPH        190 KPH          Flat
# 141            9801  DeuceCourt         182 KPH        182 KPH          Flat
# 142            7792     AdCourt         178 KPH        178 KPH          Flat
# 143            7792  DeuceCourt      192.73 KPH     192.73 KPH          Flat
# 144            7792  DeuceCourt         143 KPH        143 KPH      Pronated
# 145            7792     AdCourt      180.49 KPH     180.49 KPH  Unclassified
# 146            7792     AdCourt         146 KPH        146 KPH  Unclassified
# 147            7792  DeuceCourt      197.24 KPH     197.24 KPH      Pronated
# 148            7792  DeuceCourt         149 KPH        149 KPH      Pronated
# 149            7792  DeuceCourt         173 KPH        173 KPH         Slice
# 150            9801     AdCourt         185 KPH        185 KPH          Flat
# 151            9801  DeuceCourt         185 KPH        185 KPH          Flat
# 152            7792     AdCourt         191 KPH        191 KPH  Unclassified
# 153            7792  DeuceCourt         172 KPH        172 KPH          Flat
# 154            7792     AdCourt      199.41 KPH     199.41 KPH          Flat
# 155            7792     AdCourt      151.74 KPH     151.74 KPH          Flat
# 156            7792  DeuceCourt      189.64 KPH     189.64 KPH  Unclassified
# 157            7792  DeuceCourt         145 KPH        145 KPH  Unclassified
# 158            7792     AdCourt         174 KPH        174 KPH  Unclassified
# 159            7792  DeuceCourt         189 KPH        189 KPH  Unclassified
# 160            7792     AdCourt         171 KPH        171 KPH      Pronated
#
#     fault_distance_missed_ft fault_distance_missed_m  rally_length  \
# 0                         NA                      NA             0
# 1                         NA                      NA             3
# 2                         NA                      NA             0
# 3                         NA                      NA             6
# 4                         NA                      NA             0
# 5                         NA                      NA             5
# 6                         NA                      NA            11
# 7                         NA                      NA             2
# 8                         NA                      NA            10
# 9                         NA                      NA            10
# 10                  2.4 Feet              0.73 Metre             1
# 11                        NA                      NA             8
# 12                 1.09 Feet              0.33 Metre             1
# 13                        NA                      NA            10
# 14                        NA                      NA             3
# 15                        NA                      NA            11
# 16                    1 Feet              0.31 Metre             1
# 17                        NA                      NA             3
# 18                        NA                      NA             4
# 19                        NA                      NA             4
# 20                 0.44 Feet              0.13 Metre             1
# 21                        NA                      NA             7
# 22                        NA                      NA            15
# 23                 3.27 Feet                 1 Metre             1
# 24                        NA                      NA            15
# 25                 2.32 Feet              0.71 Metre             1
# 26                        NA                      NA             4
# 27                        NA                      NA            10
# 28                    0 Feet                 0 Metre             2
# 29                 0.47 Feet              0.14 Metre             0
# 30                    0 Feet                 0 Metre             1
# 31                        NA                      NA            13
# 32                 0.58 Feet              0.18 Metre             1
# 33                        NA                      NA             2
# 37                        NA                      NA            13
# 38                        NA                      NA             8
# 39                 6.89 Feet               2.1 Metre             2
# 40                        NA                      NA             7
# 41                        NA                      NA            10
# 42                        NA                      NA             8
# 43                        NA                      NA             7
# 44                        NA                      NA             8
# 45                 14.1 Feet               4.3 Metre             1
# 46                        NA                      NA             5
# 47                 1.29 Feet              0.39 Metre             1
# 48                        NA                      NA            14
# 34                        NA                      NA             3
# 35                        NA                      NA             1
# 36                        NA                      NA             1
# 52                        NA                      NA            15
# 53                        NA                      NA             5
# 54                        NA                      NA             5
# 55                        NA                      NA             0
# 56                        NA                      NA             6
# 57                        NA                      NA             2
# 58                        NA                      NA             4
# 59                        NA                      NA            11
# 60                        NA                      NA             4
# 49                        NA                      NA             7
# 50                        NA                      NA            10
# 51                        NA                      NA             4
# 61                        NA                      NA             3
# 62                        NA                      NA             4
# 63                        NA                      NA             3
# 64                        NA                      NA             5
# 65                        NA                      NA             1
# 70                        NA                      NA             3
# 71                        NA                      NA             4
# 72                        NA                      NA            10
# 73                        NA                      NA             4
# 74                        NA                      NA             3
# 75                        NA                      NA             7
# 76                        NA                      NA             8
# 77                        NA                      NA             5
# 78                        NA                      NA             5
# 66                 0.47 Feet              0.14 Metre             1
# 67                        NA                      NA             2
# 68                        NA                      NA             1
# 69                        NA                      NA            13
# 79                        NA                      NA             1
# 80                        NA                      NA             4
# 81                        NA                      NA             4
# 82                 0.52 Feet              0.16 Metre             2
# 83                        NA                      NA             1
# 84                        NA                      NA            15
# 85                        NA                      NA             1
# 87                 4.21 Feet              1.28 Metre             1
# 88                        NA                      NA            12
# 89                        NA                      NA            10
# 90                        NA                      NA             3
# 91                        NA                      NA             7
# 92                 8.38 Feet              2.56 Metre             2
# 93                        NA                      NA             2
# 94                        NA                      NA             7
# 95                 0.16 Feet              0.05 Metre             1
# 96                        NA                      NA             6
# 97                        NA                      NA             3
# 98                        NA                      NA            14
# 86                        NA                      NA             2
# 99                        NA                      NA            12
# 100                       NA                      NA             3
# 101                       NA                      NA             1
# 102                       NA                      NA             1
# 103                       NA                      NA             6
# 104                       NA                      NA             6
# 105                       NA                      NA             5
# 106                3.76 Feet              1.15 Metre             1
# 107                       NA                      NA             3
# 108                1.61 Feet              0.49 Metre             1
# 109                       NA                      NA             7
# 110                       NA                      NA             2
# 111                       NA                      NA             8
# 112                       NA                      NA             7
# 113                0.63 Feet              0.19 Metre             1
# 114                 7.4 Feet              2.25 Metre             0
# 115                       NA                      NA             1
# 116                       NA                      NA            16
# 117                       NA                      NA             2
# 118                4.03 Feet              1.23 Metre             2
# 119                       NA                      NA             5
# 120                       NA                      NA             5
# 121                       NA                      NA             7
# 122                 0.9 Feet              0.28 Metre             1
# 123                       NA                      NA             3
# 124                       NA                      NA             4
# 125                2.17 Feet              0.66 Metre             1
# 126                       NA                      NA             5
# 127                       NA                      NA             1
# 128                0.59 Feet              0.18 Metre             1
# 129                       NA                      NA             5
# 130                       NA                      NA             3
# 131                       NA                      NA             5
# 132                0.98 Feet               0.3 Metre             1
# 133                       NA                      NA             7
# 134                       NA                      NA             3
# 135                0.33 Feet               0.1 Metre             1
# ...
# 37              3.355               0.0  1500.15      false         3.31125
# 38              1.291               0.0        0      false           4.112
# 39             -3.174               0.0  1681.96      false           3.348
# 40             -0.448               0.0  2055.31      false           2.756
# 41             -0.135               0.0   962.66      false         4.17075
# 42              3.408               0.0  1571.55      false          3.3275
# 43              0.096               0.0       NA      false         4.15125
# 44              4.830               0.0       NA      false         3.35275
# 45              4.223               0.0        0      false          3.5774
# 46              5.545               0.0  1368.36      false           4.102
# 47             -3.476               0.0        0      false          2.9642
# 48             -2.357               0.0  3953.62      false            3.02
# 34              2.607               0.0  3205.37      false          4.1805
# 35             -2.077               0.0  1065.79      false         3.30725
# 36                NaN               NaN        0      false             NaN
# 52                NaN               NaN        0      false             NaN
# 53             -2.357               0.0        0      false             NaN
# 54                NaN               NaN        0      false             NaN
# 55                NaN               NaN        0      false             NaN
# 56             -2.077               0.0        0      false             NaN
# 57                NaN               NaN        0      false             NaN
# 58                NaN               NaN        0      false             NaN
# 59             -2.357               0.0        0      false             NaN
# 60                NaN               NaN        0      false             NaN
# 49                NaN               NaN        0      false             NaN
# 50              2.553               0.0  1619.22      false         4.52225
# 51              4.051               0.0   2318.9      false          3.2655
# 61              0.037               0.0  3892.11      false           3.136
# 62             -3.765               0.0     1537      false         4.06475
# 63              3.795               0.0  2378.39      false            3.21
# 64             -2.668               0.0  1695.84      false         4.00525
# 65              3.400               0.0        0      false          3.3028
# 70              2.821               0.0  3503.32      false          4.3665
# 71             -0.663               0.0  3118.95      false           3.412
# 72              1.163               0.0  2515.09      false         4.61325
# 73             -1.736               0.0  3634.55      false          3.6205
# 74             -0.002               0.0  1083.32      false            4.51
# 75             -2.147               0.0   2005.2      false         3.58475
# 76             -1.444               0.0  1971.38      false         4.37325
# 77              1.232               0.0  2035.01      false         3.72075
# 78              1.417               0.0  1666.26      false          4.2815
# 66              3.831               0.0        0      false           3.794
# 67             -0.738               0.0  1703.86      false         3.08675
# 68             -6.069               0.0       NA      false          4.2755
# 69              1.704               0.0        0      false            3.85
# 79             -1.574               0.0       NA      false          3.2955
# 80              4.542               0.0  1398.12      false         4.52325
# 81             -0.344               0.0  2678.01      false         3.37275
# 82              5.220               0.0  1491.38      false         4.39675
# 83              3.684               0.0  1822.02      false         4.00425
# 84              0.688               0.0  3560.88      false           3.276
# 85              5.618               0.0  1864.36      false         4.57075
# 87              4.552               0.0        0      false          3.5448
# 88              2.764               0.0       NA      false         4.24675
# 89              1.011               0.0  2813.85      false         3.49025
# 90              1.398               0.0  1575.26      false         4.25725
# 91              2.047               0.0        0      false           3.563
# 92              4.650               0.0        0      false           4.601
# 93              3.431               0.0  2564.11      false         4.42125
# 94             -2.504               0.0  3417.94      false         3.36075
# 95              4.501               0.0        0      false          4.0898
# 96              1.919               0.0  2499.14      false         4.42725
# 97             -1.770               0.0  1611.16      false         3.44175
# 98              2.088               0.0       NA      false         4.67225
# 86              0.168               0.0  2785.93      false           3.453
# 99             -2.673               0.0       NA      false           3.287
# 100            -3.608               0.0       NA      false           4.188
# 101             2.024               0.0     1472      false          3.2105
# 102            -2.400               0.0  1630.92      false         4.07225
# 103            -0.628               0.0  3604.84      false         3.35675
# 104            -2.179               0.0  1847.04      false           4.109
# 105             1.204               0.0       NA      false         3.28875
# 106            -4.244               0.0        0      false          3.8526
# 107            -1.940               0.0  2644.76      false           4.155
# 108            -4.677               0.0        0      false          4.2824
# 109             0.000               0.0       NA      false           4.323
# 110            -0.520               0.0  2724.36      false         3.38225
# 111            -0.001               0.0  2723.93      false         4.62575
# 112             1.028               0.0       NA      false               0
# 113            -4.521               0.0        0      false          3.6192
# 114            -4.120               0.0       NA      false         4.31233
# 115             3.749               0.0        0      false          3.8744
# 116            -2.423               0.0       NA      false         4.56475
# 117            -0.441               0.0  3507.29      false         3.61025
# 118            -2.748               0.0  1528.42      false         3.27675
# 119             2.681               0.0   1994.7      false           3.104
# 120             3.128               0.0   1589.5      false          4.6445
# 121             1.020               0.0  1916.66      false           3.326
# 122             4.418               0.0        0      false          3.9346
# 123             2.904               0.0  2422.42      false           4.025
# 124            -1.991               0.0  1489.95      false           4.241
# 125            -3.522               0.0        0      false          2.7386
# 126             0.968               0.0       NA      false          3.5385
# 127             3.182               0.0  2287.54      false          4.5425
# 128            -3.643               0.0        0      false         2.70375
# 129            -1.437               0.0  3037.34      false           3.378
# 130             3.285               0.0  1680.81      false         3.93025
# 131            -0.992               0.0       NA      false         3.01075
# 132            -4.209               0.0        0      false           4.071
# 133            -3.063               0.0       NA      false          4.1045
# 134             0.268               0.0  3394.98      false          3.2165
# 135            -4.134               0.0        0      false          3.6682
# 136            -3.239               0.0  2355.25      false           3.932
# 137             3.337               0.0        0      false          3.1044
# 138            -0.538               0.0       NA      false         2.98375
# 139            -4.197               0.0        0      false          4.3225
# 140            -4.416               0.0   842.24      false           3.923
# 161            -4.646               0.0        0      false          4.7748
# 162            -0.144               0.0       NA      false         4.33825
# 163            -3.081               0.0       NA      false         3.76225
# 164            -0.065               0.0  1547.33      false         4.68525
# 165             5.360               0.0  1446.72      false           3.747
# 166            -4.305               0.0        0      false           4.453
# 167            -1.326               0.0       NA      false          4.2015
# 168            -1.706               0.0  2303.07      false          3.1705
# 169            -1.276               0.0  3885.23      false          4.6385
# 170            -2.578               0.0  1473.98      false         3.35225
# 171             4.443               0.0        0      false          4.3978
# 172             2.127               0.0       NA      false         3.34125
# 173             5.322               0.0  1889.85      false          4.6405
# 174             4.637               0.0        0      false          3.6476
# 175             3.058               0.0  1719.58      false         4.33025
# 176            -3.871               0.0        0      false          2.9002
# 177             3.522               0.0  2072.94      false         3.15775
# 178             2.127               0.0  3070.24      false           4.457
# 179            -4.217               0.0   3776.9      false         3.74425
# 180             3.423               0.0  1110.26      false         4.59925
# 181            -5.119               0.0  2791.55      false         3.67175
# 182             4.592               0.0   2112.2      false         2.96975
# 183             2.891               0.0       NA      false          4.3885
# 184            -4.443               0.0  2575.66      false         3.58975
# 185             3.943               0.0   2034.9      false         3.72975
# 186             2.839               0.0        0      false         3.16233
# 187             0.328               0.0  2803.62      false           2.827
# 188            -4.357               0.0        0      false          2.1785
# 189             1.579               0.0       NA      false         4.09875
# 190             1.576               0.0  1550.93      false         3.09175
# 191            -3.461               0.0  2401.81      false         2.90275
# 192            -4.111               0.0        0      false           3.302
# 193            -2.597               0.0  2763.87      false           4.217
# 194             3.352               0.0        0      false          2.7462
# 195             2.308               0.0  1037.48      false           2.878
# 196            -4.706               0.0  1622.53      false          4.3025
# 197            -3.532               0.0       NA      false          4.4805
# 198            -0.014               0.0       NA      false           3.624
# 199            -0.496               0.0  1086.69      false           4.506
# 200             3.372               0.0  1500.23      false          3.7325
# 201            -3.455               0.0        0      false          2.9964
# 202             1.530               0.0  2047.39      false         2.84425
# 203             1.370               0.0  2150.08      false          4.2085
# 204            -3.503               0.0        0      false          2.5752
# 205            -1.860               0.0  2683.95      false           2.813
# 206             6.774               0.0  1340.98      false         4.63775
# 207             2.619               0.0  3223.48      false           3.146
# 208             4.403               0.0        0      false           3.344
# 209             2.292               0.0   838.03      false           4.115
# 210            -3.400               0.0        0      false          3.0878
# 211             3.264               0.0  1398.14      false          2.8765
# 212             4.389               0.0        0      false          2.6854
# 213             1.296               0.0  2299.35      false         4.08875
# 214             3.590               0.0       NA      false               0
# 215             2.433               0.0       NA      false         3.65525
# 216             4.548               0.0        0      false           4.637
# 217             1.866               0.0  1872.73      false           4.613
# 218            -0.671               0.0   972.83      false         3.61825
# 219             4.743               0.0   762.75      false           4.331
# 220            -3.906               0.0       NA      false         3.08125
# 221            -4.264               0.0        0      false           3.539
# 222            -1.228               0.0  2534.34      false           4.013
# 223             2.697               0.0  2873.53      false         3.19775
# 224            -2.775               0.0  2471.34      false          4.3255
# 225             7.875               0.0   1131.8      false           3.019
# 226             3.445               0.0  3379.74      false          4.1805
# 228            -0.908               0.0  2683.39      false         4.51525
# 229             4.003               0.0  2436.13      false          3.6935
# 230            -2.413               0.0  2085.88      false          4.5535
# 231             1.830               0.0  1813.61      false          3.7225
# 232             2.829               0.0  1780.61      false         4.51525
# 233             3.878               0.0        0      false          3.0568
# 234            -0.101               0.0  1508.76      false         3.15925
# 235            -0.330               0.0  3500.17      false          4.5755
# 236             3.721               0.0        0      false          3.3582
# 237             3.391               0.0   938.85      false           3.073
# 238            -6.193               0.0       NA      false           4.514
# 227             1.236               0.0       NA      false         3.84225
# 141            -1.217               0.0  3323.63      false         3.15225
# 142             2.912               0.0  2081.04      false          4.4365
# 143            -1.849               0.0       NA      false          3.2845
# 144             3.445               0.0       NA      false         2.83925
# 145             4.324               0.0        0      false          3.5028
# 146             2.752               0.0  1590.01      false          4.0505
# 147            -3.420               0.0        0      false          2.5702
# 148             4.528               0.0  1632.23      false          2.8655
# 149             0.822               0.0   749.11      false           4.441
# 150            -0.436               0.0  1584.94      false          3.5605
# 151            -0.347               0.0       NA      false          4.5075
# 152            -3.926               0.0  1639.39      false          3.6695
# 153             3.503               0.0  2357.28      false          4.5055
# 154            -3.741               0.0        0      false          3.9708
# 155            -0.660               0.0  2333.74      false         3.14875
# 156             3.272               0.0        0      false          2.4356
# 157             2.230               0.0  1153.49      false         2.93475
# 158            -5.661               0.0  1330.54      false         4.28875
# 159             2.065               0.0  2740.45      false          3.1365
# 160             0.000               0.0        0      false               0

# %%
os.getcwd()
# Out:
# '/Users/petertea/tennis_analytics/projects/roland_garros_tracking_data'

# %%
# Save Nadal vs. Federer (2019)

# Open one tracking json file (for debugging***)
with open('/Users/petertea/tennis_analytics/projects/roland_garros_tracking_data/collect_data/json_data_2021/year_2019_SM003_tracking_data.json') as filename:
  rafa_fed_2019_tracking_data_json = json.load(filename)

rafa_fed_match = get_match_point_level_info(rafa_fed_2019_tracking_data_json)
rafa_fed_match.to_csv('point_sequence_federer_nadal_2019_rolandgarros_pbp.csv', index = False)

# %% [markdown]
# ### Save Ball Trajectory Data

# %%
def save_trajectory_data_one_rally(one_point_sequence):
    '''
    Args:
    -----
    one_point_sequence [dict]: Dictionary
    
    Returns:
    --------
    pandas DataFrame (for one point sequence)
    
    Notes:
    ------
    Don't convert them to integers...yet
    '''
    
    ball_trajectory_df = pd.DataFrame(one_point_sequence['trajectoryData'])
    
    if ball_trajectory_df.empty:
        return ball_trajectory_df
    
    #######################################################################
    #                     Match situation information                     #
    #######################################################################
    # --> Get indices where ball is hit 
    hit_indices = ball_trajectory_df.index[ball_trajectory_df['position'] == 'hit'].tolist()
    hit_indices.append(ball_trajectory_df.shape[0])

    # Get lengths of rally index (expect 4 or 5)
    # In the usual case, we expect this sequence: Hit --> Peak --> Net --> Bounce
    # But what if it's a half volley? (Hit --> Peak --> Net)
    # But what if it's a hit on the rise?  Hit --> Peak --> Net --> Bounce --> Peak
    # *** Ball trajectory also includes erroneous balls (mishits)...so we sometimes get strike_index = 1 + rally_index
    hit_indices_diff_len = [x - hit_indices[i - 1] for i, x in enumerate(hit_indices)][1:]

    rally_length = len(hit_indices_diff_len)

    rally_index_list = []
    for rally_ind in range(1, rally_length + 1):
        rally_index_list.append(np.repeat( rally_ind, repeats=hit_indices_diff_len[rally_ind-1]))
    
    # Combine a list of numpy arrays into a single array
    ball_trajectory_df['strike_index'] = np.concatenate( rally_index_list, axis=0 )
    
    ##################################################
    #          Match situation information           #
    ##################################################
    ball_trajectory_df['point_ID'] = one_point_sequence['pointId']
    ball_trajectory_df['set_num'] = one_point_sequence['set']
    ball_trajectory_df['game_num'] = one_point_sequence['game'] 
    ball_trajectory_df['point_num'] = one_point_sequence['point']
    ball_trajectory_df['serve_num'] = one_point_sequence['serve']
    
    return ball_trajectory_df

# %%
#save_trajectory_data_one_rally(one_point_sequence)

# %%
def get_match_point_ball_trajectory_data(raw_json_file):
    '''
    Args:
    -----
    one_point_sequence [dict]: Dictionary
    
    Returns:
    --------
    pandas DataFrame
    '''
    all_tracking_data_dict = raw_json_file['courtVisionData'][0]['pointsData']
    
    match_ball_trajectory_list = []
    
    for point_id_key in sorted(all_tracking_data_dict.keys()):
        #print(point_id_key)
        ball_trajectory_df = save_trajectory_data_one_rally( all_tracking_data_dict[point_id_key] )
        
        if ball_trajectory_df.empty:
            continue
        else:
            match_ball_trajectory_list.append( ball_trajectory_df )

            
    match_ball_trajectory_df = pd.concat(match_ball_trajectory_list)
    
    
    ### Reorder columns
    match_ball_trajectory_df = match_ball_trajectory_df[['point_ID', 'set_num', 'game_num', 'point_num', 'serve_num', 'strike_index', 'position', 'x', 'y', 'z' ]]
    
    return match_ball_trajectory_df#.reset_index(inplace = True)

# %%
test_trajectory = get_match_point_ball_trajectory_data(atp_tracking_data_json)

test_trajectory.reset_index(drop = True)
test_trajectory.to_csv('ball_trajectory_djokovic_nadal_2020_rolandgarros_pbp.csv', index = False)

# %% [markdown]
# ### Check out for each match, how many rally point data do we have?

# %%
data_list = []

for filename in os.listdir('./json_data_2021/'):
    if filename.endswith(".json"): 
         with open('./json_data_2021/' + filename) as file_name:
                #print(filename)
                atp_tracking_data_json = json.load(file_name)
                test_match = get_match_point_level_info(atp_tracking_data_json)
                num_points_avail = test_match['is_track_avail'].sum()
                num_points = test_match.shape[0]
                
                year = [int(s) for s in filename.split('_') if s.isdigit()][0]
                
                atp_flag = 'atp'
                if (filename[:3] == 'wta'):
                    atp_flag = 'wta'
                    
                tracking_data_dict = atp_tracking_data_json['courtVisionData'][0]
    
                #atp_tracking_data_dict['isMatchComplete']


                # -----------------------------
                # Player information
                # -----------------------------
                player1_info = tracking_data_dict['playersData']['playerTeam']
                player2_info = tracking_data_dict['playersData']['opponentTeam']
                player1 = player1_info[0]['name']
                player2 = player2_info[0]['name']



                    
                    
                
                summary_dict = dict(
                    player1 = player1,
                    player2 = player2,
                    num_points_avail = num_points_avail,
                    num_points = num_points,
                    year = year,
                    atp_flag = atp_flag,
                    filename=filename
                )
                data_list.append(summary_dict)
                
                #print('done!')
                
    else:
        continue

# %%
# Seems like we have a decent amount of available points!
summary_points_avail_df = pd.DataFrame(data_list)

summary_points_avail_df
# Out:
#                      player1                   player2  num_points_avail  \
# 0                M.GASPARYAN                 E.MERTENS                 0
# 1                Y. HANFMANN                  R. NADAL               207
# 2               S. TSITSIPAS               S. WAWRINKA               517
# 3                    J.MUNAR               S.TSITSIPAS               335
# 4                Kr.PLISKOVA                G.MUGURUZA               156
# 5                    S.HALEP                    I.BEGU               150
# 6                   S. HALEP                I. SWIATEK                 0
# 7                N. DJOKOVIC                  D. THIEM               409
# 8               D.SHAPOVALOV                   G.SIMON               383
# 9                   F. FERRO             K. MLADENOVIC               190
# 10               N. DJOKOVIC              H. LAAKSONEN               198
# 11               M.FUCSOVICS                  A.RUBLEV               448
# 12                 I.SWIATEK               N.PODOROSKA               120
# 13          Y. DUAN/S. ZHENG    T. BABOS/K. MLADENOVIC               138
# 14                  S. HALEP               L. TSURENKO               109
# 15                M.MCDONALD                   R.NADAL               175
# 16                 T. DANIEL                G. MONFILS               205
# 17                  M.SHERIF               Ka.PLISKOVA               255
# 18                S. CIRSTEA                  K. JUVAN               295
# 19                  O.JABEUR                 D.COLLINS               260
# 20                  A. HOANG                G. MONFILS               239
# 21             D.SCHWARTZMAN                   R.NADAL               269
# 22                   J.KONTA                   C.GAUFF               202
# 23               S. STEPHENS                    M. DOI               202
# 24               G. MUGURUZA                J. LARSSON               129
# 25                  H.GASTON                   D.THIEM               413
# 26                 D. GOFFIN                  R. NADAL               277
# 27                  S. HALEP                M. LINETTE               285
# 28                 I.SWIATEK                   S.KENIN               149
# 29                  D. VEKIC                  J. KONTA               159
# 30                   B.PAIRE                    S.KWON                 0
# 31                E.RYBAKINA                   F.FERRO               242
# 32                  A.BEDENE               S.TSITSIPAS               162
# 33                  D. THIEM                  R. NADAL               250
# 34                  C.GARCIA                 E.MERTENS               221
# 35            AK.SCHMIEDLOVA                V.WILLIAMS                 0
# 36                  C.GARCIA               A.SASNOVICH               193
# 37               A.KONTAVEIT                  C.GARCIA               241
# 38              K. KHACHANOV              J. DEL POTRO               351
# 39                 G.MONFILS                  A.BUBLIK               375
# 40              C. WOZNIACKI            V. KUDERMETOVA               238
# 41              K. NISHIKORI                  R. NADAL               181
# 42                  A.ZVEREV              M.CECCHINATO               237
# 43               N. DJOKOVIC                H. HURKACZ                 9
# 44                D.MEDVEDEV               M.FUCSOVICS               336
# 45                    M.MMOH                   R.OLIVO                 0
# 46                 K. KANEPI                 P. MARTIC               247
# 47               S. WILLIAMS                  S. KENIN               192
# 48                 P.KVITOVA                   O.DODIN               164
# 49                J. MILLMAN                 A. ZVEREV               462
# 50                  A.ZVEREV                PH.HERBERT               443
# 51              K. SINIAKOVA                   M. KEYS               168
# 52                    I.BARA                   S.KENIN               150
# 53                  S. HALEP              A. ANISIMOVA               146
# 54                   B.CORIC                  N.GOMBOS                 0
# 55              K. NISHIKORI                  Q. HALYS               248
# 56                K.ZAVATSKA                 K.BERTENS               207
# 57                   C. RUUD                R. FEDERER               271
# 58               L.SIEGEMUND              K.MLADENOVIC               206
# 59                N.DJOKOVIC               K.KHACHANOV               266
# 60                  A.RUBLEV               S.TSITSIPAS               222
# 61              A.KALINSKAYA                E.BOUCHARD                 0
# 62               G. MUGURUZA              E. SVITOLINA               168
# 63               R.BEMELMANS                D.ALTMAIER                 0
# 64                  S. HALEP            A. TOMLJANOVIC               202
# 65                    J.SOCK                  F.BAGNIS                 0
# 66                   S.HALEP          S.SORRIBES TORMO               128
# 67                 P.KVITOVA               L.SIEGEMUND               143
# 68                  B. PAIRE                P. HERBERT               574
# 69                   S.KORDA                   R.NADAL               190
# 70           R.BAUTISTA AGUT           P.CARRENO BUSTA               353
# 71               S. STEPHENS         S. SORRIBES TORMO               132
# 72                 I.SWIATEK                M.TREVISAN               145
# 73       K. KRAWIETZ/A. MIES   G. PELLA/D. SCHWARTZMAN               157
# 74              E.BENCHETRIT                   J.ISNER                 0
# 75                M.TREVISAN                 K.BERTENS               178
# 76                  R. NADAL              J. DEL POTRO                49
# 77                N.DJOKOVIC                  DE.GALAN               225
# 78                S. BOLELLI                L. POUILLE               239
# 79                V. KUZMOVA                K. BERTENS                41
# 80               K.SINIAKOVA                 K.BERTENS               111
# 81               S. WILLIAMS                   K. NARA               131
# 82                 P.KVITOVA                   S.ZHANG               169
# 83                 L. SONEGO                R. FEDERER               212
# 84             D.SCHWARTZMAN                   D.THIEM               515
# 85              S. TSITSIPAS             F. KRAJINOVIC               295
# 86                    J.SOCK                   D.THIEM               261
# 87               L.SAMSONOVA                   S.KENIN               241
# 88              K. NISHIKORI                  B. PAIRE               500
# 89               S. STEPHENS                  J. KONTA               128
# 90              M.KECMANOVIC             D.SCHWARTZMAN                 0
# 91         D.EVANS/H.HURKACZ  M.DEMOLINER/M.MIDDELKOOP                 0
# 92          M.PAVIC/B.SOARES         K.KRAWIETZ/A.MIES                49
# 93                 C. GARCIA                M. BARTHEL               150
# 94               N. DJOKOVIC                 A. ZVEREV               224
# 95                F. FOGNINI                 A. ZVEREV               311
# 96                S.WAWRINKA                  H.GASTON               431
# 97                  N. OSAKA              K. SINIAKOVA               166
# 98                  J.SINNER                   R.NADAL               252
# 99                N.DJOKOVIC                    M.YMER               176
# 100                 D. THIEM                   T. PAUL               306
# 101              E.SVITOLINA               N.PODOROSKA               157
# 102                  S.HALEP                 I.SWIATEK               141
# 103      J. CHARDY/F. MARTIN         J. CABAL/R. FARAH               158
# 104               V.POSPISIL              M.BERRETTINI               236
# 105             K. NISHIKORI                 J. TSONGA               339
# 106                A. KERBER               A. POTAPOVA               100
# 107                 D. THIEM              K. KHACHANOV               208
# 108                   C.RUUD                   D.THIEM               238
# 109             D.SHAPOVALOV         R.CARBALLES BAENA               527
# 110              N. DJOKOVIC                 J. STRUFF               196
# 111                 A.ZVEREV                   D.NOVAK               239
# 112               F. FOGNINI          R. BAUTISTA AGUT               162
# 113               J. LONDERO                  R. NADAL               206
# 114              E.SVITOLINA                V.GRACHEVA               204
# 115                 N. OSAKA            A. SCHMIEDLOVA               218
# 116                P.KVITOVA               L.FERNANDEZ               232
# 117           M. VONDROUSOVA                 P. MARTIC               210
# 118                D.COLLINS                G.MUGURUZA               290
# 119              N. DJOKOVIC                 S. CARUSO               202
# 120                 L.HARRIS              M.BERRETTINI               314
# 121                  F.FERRO                    PM.TIG               288
# 122                 S. KENIN                  A. BARTY               203
# 123               J.RODIONOV                  J.CHARDY               525
# 124                  M. KEYS                  A. BARTY               161
# 125                 P.CUEVAS               S.TSITSIPAS               198
# 126              S. WAWRINKA                R. FEDERER               425
# 127           M. VONDROUSOVA              A. SEVASTOVA               116
# 128                  M.CILIC                   D.THIEM               229
# 129                 A.BOGDAN                   S.KENIN               214
# 130              A. PETKOVIC                  A. BARTY               132
# 131      J. CHARDY/F. MARTIN       K. KRAWIETZ/A. MIES               178
# 132              S. STEPHENS                 P. HERCOG               277
# 133                D.COLLINS                   S.KENIN               228
# 134               E. MERTENS              A. SEVASTOVA               378
# 135              T. FABBIANO                  M. CILIC               180
# 136            P. PARMENTIER                K. BERTENS               165
# 137                 A.ZVEREV                  J.SINNER               342
# 138               D.ALTMAIER              M.BERRETTINI               255
# 139                  O. OTTE                R. FEDERER               216
# 140                J. TSONGA              P. GOJOWCZYK               316
# 141                  S.HALEP               A.ANISIMOVA               127
# 142                C. GARCIA               A. BLINKOVA               206
# 143          P.CARRENO BUSTA                D.ALTMAIER               257
# 144                M. KLIZAN                L. POUILLE               480
# 145               N.DJOKOVIC           P.CARRENO BUSTA               329
# 146                 L.SONEGO             D.SCHWARTZMAN               220
# 147                 N. JARRY              J. DEL POTRO               267
# 148              E.GERASIMOV                   R.NADAL               202
# 149  E. MERTENS/A. SABALENKA    T. BABOS/K. MLADENOVIC                71
# 150              J.OSTAPENKO               Ka.PLISKOVA               153
# 151                 D. THIEM                 P. CUEVAS               307
# 152             A. MANNARINO                G. MONFILS               229
# 153               N.DJOKOVIC               S.TSITSIPAS               427
# 154              E.SVITOLINA                  C.GARCIA               126
# 155                 N. OSAKA               V. AZARENKA               291
# 156              E.SVITOLINA             E.ALEXANDROVA               227
# 157               V.AZARENKA                 D.KOVINIC                98
# 158                 A. BARTY              A. ANISIMOVA               266
# 159    A.GUARACHI/D.KRAWCZYK      T.BABOS/K.MLADENOVIC               159
# 160                 D. THIEM                G. MONFILS               174
# 161               N.DJOKOVIC                R.BERANKIS               159
# 162                 C.PAQUET                  A.CORNET               153
# 163                    K.AHN                S.WILLIAMS               197
# 164                E. RODINA                   M. KEYS               126
# 165              S. STEPHENS               G. MUGURUZA               187
# 166               M. BRENGLE               K. PLISKOVA               135
# 167                 Y. MADEN                  R. NADAL               199
# 168                   B.PERA               A.ANISIMOVA               132
# 169                 J.SINNER                  D.GOFFIN               225
# 170              S. WILLIAMS             V. DIATCHENKO               185
# 171              A.SABALENKA                  J.PEGULA               162
# 172               R. FEDERER                  R. NADAL               228
# 173                 A. BARTY            M. VONDROUSOVA               147
# 174               M.BOUZKOVA                  K.KANEPI                 0
# 175                P. MARTIC             K. MLADENOVIC               118
# 176               S.WAWRINKA                  A.MURRAY               223
# 177              E.SVITOLINA                 R.ZARAZUA               189
# 178              S.TRAVAGLIA                   R.NADAL               154
# 179               S.WAWRINKA                 D.KOEPFER               288
# 180                 L. MAYER                R. FEDERER               210
# 181               N.DJOKOVIC                   R.NADAL               220
# 182                 D. THIEM                 A. BUBLIK               358
# 183                B. BENCIC              L. SIEGEMUND                10
# 184                P. MARTIC               K. PLISKOVA               165
# 185                  F.FERRO                   S.KENIN               213
# 186         A.CAZAUX/H.MAYOT            L.KUBOT/M.MELO                 0
# 187               G.DIMITROV               S.TSITSIPAS               273
# 188             S. TSITSIPAS               M. MARTERER               214
# 189                  S.KENIN                 P.KVITOVA               201
# 190             M.CECCHINATO               K.COPPEJANS                 0
#
#      num_points  year atp_flag  \
# 0           169  2020      wta
# 1           209  2019      atp
# 2           526  2019      atp
# 3           335  2020      atp
# 4           157  2020      wta
# 5           150  2020      wta
# 6           102  2019      wta
# 7           416  2019      atp
# 8           387  2020      atp
# 9           196  2019      wta
# 10          201  2019      atp
# 11          450  2020      atp
# 12          132  2020      wta
# 13          138  2019      atp
# 14          113  2019      wta
# 15          175  2020      atp
# 16          206  2019      atp
# 17          255  2020      wta
# 18          296  2019      wta
# 19          260  2020      wta
# 20          241  2019      atp
# 21          271  2020      atp
# 22          206  2020      wta
# 23          203  2019      wta
# 24          130  2019      wta
# 25          413  2020      atp
# 26          283  2019      atp
# 27          285  2019      wta
# 28          149  2020      wta
# 29          164  2019      wta
# 30          270  2020      atp
# 31          244  2020      wta
# 32          175  2020      atp
# 33          254  2019      atp
# 34          227  2020      wta
# 35          199  2020      wta
# 36          197  2020      wta
# 37          246  2020      wta
# 38          356  2019      atp
# 39          375  2020      atp
# 40          239  2019      wta
# 41          182  2019      atp
# 42          237  2020      atp
# 43          186  2019      atp
# 44          348  2020      atp
# 45          220  2020      atp
# 46          254  2019      wta
# 47          193  2019      wta
# 48          165  2020      wta
# 49          466  2019      atp
# 50          444  2020      atp
# 51          168  2019      wta
# 52          150  2020      wta
# 53          152  2019      wta
# 54          328  2020      atp
# 55          252  2019      atp
# 56          207  2020      wta
# 57          275  2019      atp
# 58          206  2020      wta
# 59          266  2020      atp
# 60          234  2020      atp
# 61          156  2020      wta
# 62          171  2019      wta
# 63          212  2020      atp
# 64          203  2019      wta
# 65          230  2020      atp
# 66          128  2020      wta
# 67          144  2020      wta
# 68          580  2019      atp
# 69          193  2020      atp
# 70          359  2020      atp
# 71          134  2019      wta
# 72          145  2020      wta
# 73          166  2019      atp
# 74          195  2020      atp
# 75          179  2020      wta
# 76           49  2018      atp
# 77          228  2020      atp
# 78          241  2019      atp
# 79           41  2019      wta
# 80          114  2020      wta
# 81          136  2019      wta
# 82          169  2020      wta
# 83          213  2019      atp
# 84          517  2020      atp
# 85          301  2019      atp
# 86          261  2020      atp
# 87          251  2020      wta
# 88          505  2019      atp
# 89          130  2019      wta
# 90          202  2020      atp
# 91          282  2020      atp
# 92          181  2020      atp
# 93          156  2019      wta
# 94          227  2019      atp
# 95          350  2019      atp
# 96          435  2020      atp
# 97          171  2019      wta
# 98          254  2020      atp
# 99          177  2020      atp
# 100         307  2019      atp
# 101         157  2020      wta
# 102         141  2020      wta
# 103         162  2019      atp
# 104         237  2020      atp
# 105         344  2019      atp
# 106         174  2019      wta
# 107         211  2019      atp
# 108         238  2020      atp
# 109         530  2020      atp
# 110         199  2019      atp
# 111         242  2020      atp
# 112         167  2019      atp
# 113         215  2019      atp
# 114         207  2020      wta
# 115         224  2019      wta
# 116         233  2020      wta
# 117         214  2019      wta
# 118         291  2020      wta
# 119         204  2019      atp
# 120         318  2020      atp
# 121         293  2020      wta
# 122         207  2019      wta
# 123         535  2020      atp
# 124         169  2019      wta
# 125         198  2020      atp
# 126         432  2019      atp
# 127         119  2019      wta
# 128         230  2020      atp
# 129         216  2020      wta
# 130         133  2019      wta
# 131         181  2019      atp
# 132         284  2019      wta
# 133         229  2020      wta
# 134         397  2019      wta
# 135         226  2019      atp
# 136         172  2019      wta
# 137         350  2020      atp
# 138         258  2020      atp
# 139         218  2019      atp
# 140         319  2019      atp
# 141         127  2020      wta
# 142         214  2019      wta
# 143         257  2020      atp
# 144         483  2019      atp
# 145         334  2020      atp
# 146         220  2020      atp
# 147         268  2019      atp
# 148         202  2020      atp
# 149         164  2019      atp
# 150         163  2020      wta
# 151         314  2019      atp
# 152         229  2019      atp
# 153         427  2020      atp
# 154         128  2020      wta
# 155         297  2019      wta
# 156         231  2020      wta
# 157          99  2020      wta
# 158         267  2019      wta
# 159         202  2020      atp
# 160         222  2019      atp
# 161         160  2020      atp
# 162         154  2020      wta
# 163         200  2020      wta
# 164         130  2019      wta
# 165         193  2019      wta
# 166         137  2019      wta
# 167         199  2019      atp
# 168         132  2020      wta
# 169         229  2020      atp
# 170         187  2019      wta
# 171         166  2020      wta
# 172         233  2019      atp
# 173         150  2019      wta
# 174         227  2020      wta
# 175         120  2019      wta
# 176         225  2020      atp
# 177         189  2020      wta
# 178         155  2020      atp
# 179         292  2020      atp
# 180         222  2019      atp
# 181         239  2020      atp
# 182         359  2019      atp
# 183         250  2019      wta
# 184         167  2019      wta
# 185         215  2020      wta
# 186         172  2020      atp
# 187         274  2020      atp
# 188         217  2019      atp
# 189         202  2020      wta
# 190         138  2020      atp
#
#                                              filename
# 0              wta_year_2020_SD087_tracking_data.json
# 1                  year_2019_SM127_tracking_data.json
# 2                  year_2019_SM012_tracking_data.json
# 3                  year_2020_SM095_tracking_data.json
# 4              wta_year_2020_SD051_tracking_data.json
# 5              wta_year_2020_SD032_tracking_data.json
# 6              wta_year_2019_SD010_tracking_data.json
# 7                  year_2019_SM002_tracking_data.json
# 8                  year_2020_SM088_tracking_data.json
# 9              wta_year_2019_SD125_tracking_data.json
# 10                 year_2019_SM032_tracking_data.json
# 11                 year_2020_SM010_tracking_data.json
# 12             wta_year_2020_SD002_tracking_data.json
# 13   doubles_women_year_2019_DD001_tracking_data.json
# 14             wta_year_2019_SD020_tracking_data.json
# 15                 year_2020_SM063_tracking_data.json
# 16                 year_2019_SM087_tracking_data.json
# 17             wta_year_2020_SD127_tracking_data.json
# 18             wta_year_2019_SD095_tracking_data.json
# 19             wta_year_2020_SD012_tracking_data.json
# 20                 year_2019_SM021_tracking_data.json
# 21                 year_2020_SM003_tracking_data.json
# 22             wta_year_2020_SD072_tracking_data.json
# 23             wta_year_2019_SD096_tracking_data.json
# 24             wta_year_2019_SD050_tracking_data.json
# 25                 year_2020_SM013_tracking_data.json
# 26                 year_2019_SM031_tracking_data.json
# 27             wta_year_2019_SD040_tracking_data.json
# 28             wta_year_2020_SD001_tracking_data.json
# 29             wta_year_2019_SD013_tracking_data.json
# 30                 year_2020_SM116_tracking_data.json
# 31             wta_year_2020_SD052_tracking_data.json
# 32                 year_2020_SM023_tracking_data.json
# 33                 year_2019_SM001_tracking_data.json
# 34             wta_year_2020_SD021_tracking_data.json
# 35             wta_year_2020_SD089_tracking_data.json
# 36             wta_year_2020_SD042_tracking_data.json
# 37             wta_year_2020_SD084_tracking_data.json
# 38                 year_2019_SM011_tracking_data.json
# 39                 year_2020_SM096_tracking_data.json
# 40             wta_year_2019_SD120_tracking_data.json
# 41                 year_2019_SM007_tracking_data.json
# 42                 year_2020_SM028_tracking_data.json
# 43                 year_2019_SM064_tracking_data.json
# 44                 year_2020_SM080_tracking_data.json
# 45        qual_men_year_2020_QM019_tracking_data.json
# 46             wta_year_2019_SD015_tracking_data.json
# 47             wta_year_2019_SD018_tracking_data.json
# 48             wta_year_2020_SD112_tracking_data.json
# 49                 year_2019_SM079_tracking_data.json
# 50                 year_2020_SM056_tracking_data.json
# 51             wta_year_2019_SD008_tracking_data.json
# 52             wta_year_2020_SD027_tracking_data.json
# 53             wta_year_2019_SD005_tracking_data.json
# 54                 year_2020_SM100_tracking_data.json
# 55                 year_2019_SM112_tracking_data.json
# 56             wta_year_2020_SD079_tracking_data.json
# 57                 year_2019_SM027_tracking_data.json
# 58             wta_year_2020_SD122_tracking_data.json
# 59                 year_2020_SM008_tracking_data.json
# 60                 year_2020_SM005_tracking_data.json
# 61             wta_year_2020_SD069_tracking_data.json
# 62             wta_year_2019_SD025_tracking_data.json
# 63        qual_men_year_2020_QM029_tracking_data.json
# 64             wta_year_2019_SD080_tracking_data.json
# 65        qual_men_year_2020_QM047_tracking_data.json
# 66             wta_year_2020_SD064_tracking_data.json
# 67             wta_year_2020_SD007_tracking_data.json
# 68                 year_2019_SM059_tracking_data.json
# 69                 year_2020_SM015_tracking_data.json
# 70                 year_2020_SM018_tracking_data.json
# 71             wta_year_2019_SD048_tracking_data.json
# 72             wta_year_2020_SD004_tracking_data.json
# 73     doubles_men_year_2019_DM003_tracking_data.json
# 74                 year_2020_SM123_tracking_data.json
# 75             wta_year_2020_SD009_tracking_data.json
# 76                 year_2018_SM002_tracking_data.json
# 77                 year_2020_SM016_tracking_data.json
# 78                 year_2019_SM091_tracking_data.json
# 79             wta_year_2019_SD055_tracking_data.json
# 80             wta_year_2020_SD019_tracking_data.json
# 81             wta_year_2019_SD036_tracking_data.json
# 82             wta_year_2020_SD014_tracking_data.json
# 83                 year_2019_SM111_tracking_data.json
# 84                 year_2020_SM006_tracking_data.json
# 85                 year_2019_SM024_tracking_data.json
# 86                 year_2020_SM055_tracking_data.json
# 87             wta_year_2020_SD111_tracking_data.json
# 88                 year_2019_SM014_tracking_data.json
# 89             wta_year_2019_SD006_tracking_data.json
# 90                 year_2020_SM103_tracking_data.json
# 91     doubles_men_year_2020_DM062_tracking_data.json
# 92     doubles_men_year_2020_DM001_tracking_data.json
# 93             wta_year_2019_SD068_tracking_data.json
# 94                 year_2019_SM004_tracking_data.json
# 95                 year_2019_SM009_tracking_data.json
# 96                 year_2020_SM026_tracking_data.json
# 97             wta_year_2019_SD016_tracking_data.json
# 98                 year_2020_SM007_tracking_data.json
# 99                 year_2020_SM064_tracking_data.json
# 100                year_2019_SM080_tracking_data.json
# 101            wta_year_2020_SD005_tracking_data.json
# 102            wta_year_2020_SD008_tracking_data.json
# 103    doubles_men_year_2019_DM002_tracking_data.json
# 104                year_2020_SM079_tracking_data.json
# 105                year_2019_SM056_tracking_data.json
# 106            wta_year_2019_SD112_tracking_data.json
# 107                year_2019_SM005_tracking_data.json
# 108                year_2020_SM027_tracking_data.json
# 109                year_2020_SM044_tracking_data.json
# 110                year_2019_SM008_tracking_data.json
# 111                year_2020_SM112_tracking_data.json
# 112                year_2019_SM018_tracking_data.json
# 113                year_2019_SM015_tracking_data.json
# 114            wta_year_2020_SD080_tracking_data.json
# 115            wta_year_2019_SD064_tracking_data.json
# 116            wta_year_2020_SD028_tracking_data.json
# 117            wta_year_2019_SD007_tracking_data.json
# 118            wta_year_2020_SD025_tracking_data.json
# 119                year_2019_SM016_tracking_data.json
# 120                year_2020_SM039_tracking_data.json
# 121            wta_year_2020_SD026_tracking_data.json
# 122            wta_year_2019_SD009_tracking_data.json
# 123                year_2020_SM101_tracking_data.json
# 124            wta_year_2019_SD004_tracking_data.json
# 125                year_2020_SM047_tracking_data.json
# 126                year_2019_SM006_tracking_data.json
# 127            wta_year_2019_SD014_tracking_data.json
# 128                year_2020_SM111_tracking_data.json
# 129            wta_year_2020_SD055_tracking_data.json
# 130            wta_year_2019_SD019_tracking_data.json
# 131    doubles_men_year_2019_DM001_tracking_data.json
# 132            wta_year_2019_SD024_tracking_data.json
# 133            wta_year_2020_SD006_tracking_data.json
# 134            wta_year_2019_SD029_tracking_data.json
# 135                year_2019_SM103_tracking_data.json
# 136            wta_year_2019_SD111_tracking_data.json
# 137                year_2020_SM014_tracking_data.json
# 138                year_2020_SM019_tracking_data.json
# 139                year_2019_SM055_tracking_data.json
# 140                year_2019_SM113_tracking_data.json
# 141            wta_year_2020_SD016_tracking_data.json
# 142            wta_year_2019_SD034_tracking_data.json
# 143                year_2020_SM009_tracking_data.json
# 144                year_2019_SM045_tracking_data.json
# 145                year_2020_SM004_tracking_data.json
# 146                year_2020_SM012_tracking_data.json
# 147                year_2019_SM095_tracking_data.json
# 148                year_2020_SM127_tracking_data.json
# 149  doubles_women_year_2019_DD003_tracking_data.json
# 150            wta_year_2020_SD063_tracking_data.json
# 151                year_2019_SM020_tracking_data.json
# 152                year_2019_SM043_tracking_data.json
# 153                year_2020_SM002_tracking_data.json
# 154            wta_year_2020_SD010_tracking_data.json
# 155            wta_year_2019_SD032_tracking_data.json
# 156            wta_year_2020_SD020_tracking_data.json
# 157            wta_year_2020_SD088_tracking_data.json
# 158            wta_year_2019_SD002_tracking_data.json
# 159  doubles_women_year_2020_DD001_tracking_data.json
# 160                year_2019_SM010_tracking_data.json
# 161                year_2020_SM032_tracking_data.json
# 162            wta_year_2020_SD118_tracking_data.json
# 163            wta_year_2020_SD095_tracking_data.json
# 164            wta_year_2019_SD071_tracking_data.json
# 165            wta_year_2019_SD012_tracking_data.json
# 166            wta_year_2019_SD127_tracking_data.json
# 167                year_2019_SM063_tracking_data.json
# 168            wta_year_2020_SD033_tracking_data.json
# 169                year_2020_SM119_tracking_data.json
# 170            wta_year_2019_SD072_tracking_data.json
# 171            wta_year_2020_SD096_tracking_data.json
# 172                year_2019_SM003_tracking_data.json
# 173            wta_year_2019_SD001_tracking_data.json
# 174            wta_year_2020_SD086_tracking_data.json
# 175            wta_year_2019_SD062_tracking_data.json
# 176                year_2020_SM104_tracking_data.json
# 177            wta_year_2020_SD040_tracking_data.json
# 178                year_2020_SM031_tracking_data.json
# 179                year_2020_SM052_tracking_data.json
# 180                year_2019_SM013_tracking_data.json
# 181                year_2020_SM001_tracking_data.json
# 182                year_2019_SM040_tracking_data.json
# 183            wta_year_2019_SD052_tracking_data.json
# 184            wta_year_2019_SD031_tracking_data.json
# 185            wta_year_2020_SD013_tracking_data.json
# 186    doubles_men_year_2020_DM055_tracking_data.json
# 187                year_2020_SM011_tracking_data.json
# 188                year_2019_SM096_tracking_data.json
# 189            wta_year_2020_SD003_tracking_data.json
# 190       qual_men_year_2020_QM020_tracking_data.json

# %%
summary_points_avail_df.to_csv('summary_points_avail_df.csv', index=False)
