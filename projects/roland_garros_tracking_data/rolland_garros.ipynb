# %% [markdown]
# This script was used to scrape all available tracking data from Roland Garros's Court Vision Feature.
#
# The data collected include:
#
# * Few Data from 2018
# * Reliable (ish?) data from 2019
# * Good data from 2020

# %%
import pandas as pd
pd.set_option('display.max_rows', 1000)
import json
import requests

# %%
import json
import requests

def save_tracking_data_roland_garros(year, num_matches = 20):
    '''
    Args:
    -----
    tournament_id [int]
    year: [int]
    '''

    for i in range(1,num_matches):
        if i < 10:
            match_num = '0' + str(i)
            match_id = 'SM0' + match_num
        elif ( i >= 10) & (i < 100):
            match_num = str(i)
            match_id = 'SM0' + match_num
        else:
            match_num = str(i)
            match_id = 'SM' + match_num

        

        #print(match_id)

        api_url = 'https://itp.infosys-platforms.com/api/rg/court-vision/year/' + str(year) + '/eventId/520/matchId/' + match_id +'/pointId/0_0_0'
        get_json_file = requests.get(api_url)

        try:
            tracking_data_json = get_json_file.json()

        except ValueError:

            print('The Match {0} does not exist!'.format(match_id))

            continue
            
        if not tracking_data_json['courtVisionData']:
            print('The Match {0} is empty!'.format(match_id))
            
            continue

        file_name = 'year_' + str(year)  + '_' + match_id + '_tracking_data.json'

        with open(file_name, 'w') as json_file:
            json.dump(tracking_data_json, json_file)

# %%
save_tracking_data_roland_garros(year = 2020, num_matches=200)
# Out:
# The Match SM017 is empty!
# The Match SM020 is empty!
# The Match SM021 is empty!
# The Match SM022 is empty!
# The Match SM024 is empty!
# The Match SM025 is empty!
# The Match SM029 is empty!
# The Match SM030 is empty!
# The Match SM033 is empty!
# The Match SM034 is empty!
# The Match SM035 is empty!
# The Match SM036 is empty!
# The Match SM037 is empty!
# The Match SM038 is empty!
# The Match SM040 is empty!
# The Match SM041 is empty!
# The Match SM042 is empty!
# The Match SM043 is empty!
# The Match SM045 is empty!
# The Match SM046 is empty!
# The Match SM048 is empty!
# The Match SM049 is empty!
# The Match SM050 is empty!
# The Match SM051 is empty!
# The Match SM053 is empty!
# The Match SM054 is empty!
# The Match SM057 is empty!
# The Match SM058 is empty!
# The Match SM059 is empty!
# The Match SM060 is empty!
# The Match SM061 is empty!
# The Match SM062 is empty!
# The Match SM065 is empty!
# The Match SM066 is empty!
# The Match SM067 is empty!
# The Match SM068 is empty!
# The Match SM069 is empty!
# The Match SM070 is empty!
# The Match SM071 is empty!
# The Match SM072 is empty!
# The Match SM073 is empty!
# The Match SM074 is empty!
# The Match SM075 is empty!
# The Match SM076 is empty!
# The Match SM077 is empty!
# The Match SM078 is empty!
# The Match SM081 is empty!
# The Match SM082 is empty!
# The Match SM083 is empty!
# The Match SM084 is empty!
# The Match SM085 is empty!
# The Match SM086 is empty!
# The Match SM087 is empty!
# The Match SM089 is empty!
# The Match SM090 is empty!
# The Match SM091 is empty!
# The Match SM092 is empty!
# The Match SM093 is empty!
# The Match SM094 is empty!
# The Match SM097 is empty!
# The Match SM098 is empty!
# The Match SM099 is empty!
# The Match SM102 is empty!
# The Match SM105 is empty!
# The Match SM106 is empty!
# The Match SM107 is empty!
# The Match SM108 is empty!
# The Match SM109 is empty!
# The Match SM110 is empty!
# The Match SM113 is empty!
# The Match SM114 is empty!
# The Match SM115 is empty!
# The Match SM117 is empty!
# The Match SM118 is empty!
# The Match SM120 is empty!
# The Match SM121 is empty!
# The Match SM122 is empty!
# The Match SM124 is empty!
# The Match SM125 is empty!
# The Match SM126 is empty!
# The Match SM128 is empty!
# The Match SM129 is empty!
# The Match SM130 is empty!
# The Match SM131 is empty!
# The Match SM132 is empty!
# The Match SM133 is empty!
# The Match SM134 is empty!
# The Match SM135 is empty!
# The Match SM136 is empty!
# The Match SM137 is empty!
# The Match SM138 is empty!
# The Match SM139 is empty!
# The Match SM140 is empty!
# The Match SM141 is empty!
# The Match SM142 is empty!
# The Match SM143 is empty!
# The Match SM144 is empty!
# The Match SM145 is empty!
# The Match SM146 is empty!
# The Match SM147 is empty!
# The Match SM148 is empty!
# The Match SM149 is empty!
# The Match SM150 is empty!
# The Match SM151 is empty!
# The Match SM152 is empty!
# The Match SM153 is empty!
# The Match SM154 is empty!
# The Match SM155 is empty!
# The Match SM156 is empty!
# The Match SM157 is empty!
# The Match SM158 is empty!
# The Match SM159 is empty!
# The Match SM160 is empty!
# The Match SM161 is empty!
# The Match SM162 is empty!
# The Match SM163 is empty!
# The Match SM164 is empty!
# The Match SM165 is empty!
# The Match SM166 is empty!
# The Match SM167 is empty!
# The Match SM168 is empty!
# The Match SM169 is empty!
# The Match SM170 is empty!
# The Match SM171 is empty!
# The Match SM172 is empty!
# The Match SM173 is empty!
# The Match SM174 is empty!
# The Match SM175 is empty!
# The Match SM176 is empty!
# The Match SM177 is empty!
# The Match SM178 is empty!
# The Match SM179 is empty!
# The Match SM180 is empty!
# The Match SM181 is empty!
# The Match SM182 is empty!
# The Match SM183 is empty!
# The Match SM184 is empty!
# The Match SM185 is empty!
# The Match SM186 is empty!
# The Match SM187 is empty!
# The Match SM188 is empty!
# The Match SM189 is empty!
# The Match SM190 is empty!
# The Match SM191 is empty!
# The Match SM192 is empty!
# The Match SM193 is empty!
# The Match SM194 is empty!
# The Match SM195 is empty!
# The Match SM196 is empty!
# The Match SM197 is empty!
# The Match SM198 is empty!
# The Match SM199 is empty!

# %%
save_tracking_data_roland_garros(year = 2019, num_matches=200)
# Out:
# The Match SM017 is empty!
# The Match SM019 is empty!
# The Match SM022 is empty!
# The Match SM023 is empty!
# The Match SM025 is empty!
# The Match SM026 is empty!
# The Match SM028 is empty!
# The Match SM029 is empty!
# The Match SM030 is empty!
# The Match SM033 is empty!
# The Match SM034 is empty!
# The Match SM035 is empty!
# The Match SM036 is empty!
# The Match SM037 is empty!
# The Match SM038 is empty!
# The Match SM039 is empty!
# The Match SM041 is empty!
# The Match SM042 is empty!
# The Match SM044 is empty!
# The Match SM046 is empty!
# The Match SM047 is empty!
# The Match SM048 is empty!
# The Match SM049 is empty!
# The Match SM050 is empty!
# The Match SM051 is empty!
# The Match SM052 is empty!
# The Match SM053 is empty!
# The Match SM054 is empty!
# The Match SM057 is empty!
# The Match SM058 is empty!
# The Match SM060 is empty!
# The Match SM061 is empty!
# The Match SM062 is empty!
# The Match SM065 is empty!
# The Match SM066 is empty!
# The Match SM067 is empty!
# The Match SM068 is empty!
# The Match SM069 is empty!
# The Match SM070 is empty!
# The Match SM071 is empty!
# The Match SM072 is empty!
# The Match SM073 is empty!
# The Match SM074 is empty!
# The Match SM075 is empty!
# The Match SM076 is empty!
# The Match SM077 is empty!
# The Match SM078 is empty!
# The Match SM081 is empty!
# The Match SM082 is empty!
# The Match SM083 is empty!
# The Match SM084 is empty!
# The Match SM085 is empty!
# The Match SM086 is empty!
# The Match SM088 is empty!
# The Match SM089 is empty!
# The Match SM090 is empty!
# The Match SM092 is empty!
# The Match SM093 is empty!
# The Match SM094 is empty!
# The Match SM097 is empty!
# The Match SM098 is empty!
# The Match SM099 is empty!
# The Match SM100 is empty!
# The Match SM101 is empty!
# The Match SM102 is empty!
# The Match SM104 is empty!
# The Match SM105 is empty!
# The Match SM106 is empty!
# The Match SM107 is empty!
# The Match SM108 is empty!
# The Match SM109 is empty!
# The Match SM110 is empty!
# The Match SM114 is empty!
# The Match SM115 is empty!
# The Match SM116 is empty!
# The Match SM117 is empty!
# The Match SM118 is empty!
# The Match SM119 is empty!
# The Match SM120 is empty!
# The Match SM121 is empty!
# The Match SM122 is empty!
# The Match SM123 is empty!
# The Match SM124 is empty!
# The Match SM125 is empty!
# The Match SM126 is empty!
# The Match SM128 is empty!
# The Match SM129 is empty!
# The Match SM130 is empty!
# The Match SM131 is empty!
# The Match SM132 is empty!
# The Match SM133 is empty!
# The Match SM134 is empty!
# The Match SM135 is empty!
# The Match SM136 is empty!
# The Match SM137 is empty!
# The Match SM138 is empty!
# The Match SM139 is empty!
# The Match SM140 is empty!
# The Match SM141 is empty!
# The Match SM142 is empty!
# The Match SM143 is empty!
# The Match SM144 is empty!
# The Match SM145 is empty!
# The Match SM146 is empty!
# The Match SM147 is empty!
# The Match SM148 is empty!
# The Match SM149 is empty!
# The Match SM150 is empty!
# The Match SM151 is empty!
# The Match SM152 is empty!
# The Match SM153 is empty!
# The Match SM154 is empty!
# The Match SM155 is empty!
# The Match SM156 is empty!
# The Match SM157 is empty!
# The Match SM158 is empty!
# The Match SM159 is empty!
# The Match SM160 is empty!
# The Match SM161 is empty!
# The Match SM162 is empty!
# The Match SM163 is empty!
# The Match SM164 is empty!
# The Match SM165 is empty!
# The Match SM166 is empty!
# The Match SM167 is empty!
# The Match SM168 is empty!
# The Match SM169 is empty!
# The Match SM170 is empty!
# The Match SM171 is empty!
# The Match SM172 is empty!
# The Match SM173 is empty!
# The Match SM174 is empty!
# The Match SM175 is empty!
# The Match SM176 is empty!
# The Match SM177 is empty!
# The Match SM178 is empty!
# The Match SM179 is empty!
# The Match SM180 is empty!
# The Match SM181 is empty!
# The Match SM182 is empty!
# The Match SM183 is empty!
# The Match SM184 is empty!
# The Match SM185 is empty!
# The Match SM186 is empty!
# The Match SM187 is empty!
# The Match SM188 is empty!
# The Match SM189 is empty!
# The Match SM190 is empty!
# The Match SM191 is empty!
# The Match SM192 is empty!
# The Match SM193 is empty!
# The Match SM194 is empty!
# The Match SM195 is empty!
# The Match SM196 is empty!
# The Match SM197 is empty!
# The Match SM198 is empty!
# The Match SM199 is empty!

# %%
save_tracking_data_roland_garros(year = 2018, num_matches=200)
# Out:
# The Match SM004 is empty!
# The Match SM005 is empty!
# The Match SM006 is empty!
# The Match SM007 is empty!
# The Match SM008 is empty!
# The Match SM009 is empty!
# The Match SM010 is empty!
# The Match SM011 is empty!
# The Match SM012 is empty!
# The Match SM013 is empty!
# The Match SM014 is empty!
# The Match SM015 is empty!
# The Match SM016 is empty!
# The Match SM017 is empty!
# The Match SM018 is empty!
# The Match SM019 is empty!
# The Match SM020 is empty!
# The Match SM021 is empty!
# The Match SM022 is empty!
# The Match SM023 is empty!
# The Match SM024 is empty!
# The Match SM025 is empty!
# The Match SM026 is empty!
# The Match SM027 is empty!
# The Match SM028 is empty!
# The Match SM029 is empty!
# The Match SM030 is empty!
# The Match SM031 is empty!
# The Match SM032 is empty!
# The Match SM033 is empty!
# The Match SM034 is empty!
# The Match SM035 is empty!
# The Match SM036 is empty!
# The Match SM037 is empty!
# The Match SM038 is empty!
# The Match SM039 is empty!
# The Match SM040 is empty!
# The Match SM041 is empty!
# The Match SM042 is empty!
# The Match SM043 is empty!
# The Match SM044 is empty!
# The Match SM045 is empty!
# The Match SM046 is empty!
# The Match SM047 is empty!
# The Match SM048 is empty!
# The Match SM049 is empty!
# The Match SM050 is empty!
# The Match SM051 is empty!
# The Match SM052 is empty!
# The Match SM053 is empty!
# The Match SM054 is empty!
# The Match SM055 is empty!
# The Match SM056 is empty!
# The Match SM057 is empty!
# The Match SM058 is empty!
# The Match SM059 is empty!
# The Match SM060 is empty!
# The Match SM061 is empty!
# The Match SM062 is empty!
# The Match SM063 is empty!
# The Match SM064 is empty!
# The Match SM065 is empty!
# The Match SM066 is empty!
# The Match SM067 is empty!
# The Match SM068 is empty!
# The Match SM069 is empty!
# The Match SM070 is empty!
# The Match SM071 is empty!
# The Match SM072 is empty!
# The Match SM073 is empty!
# The Match SM074 is empty!
# The Match SM075 is empty!
# The Match SM076 is empty!
# The Match SM077 is empty!
# The Match SM078 is empty!
# The Match SM079 is empty!
# The Match SM080 is empty!
# The Match SM081 is empty!
# The Match SM082 is empty!
# The Match SM083 is empty!
# The Match SM084 is empty!
# The Match SM085 is empty!
# The Match SM086 is empty!
# The Match SM087 is empty!
# The Match SM088 is empty!
# The Match SM089 is empty!
# The Match SM090 is empty!
# The Match SM091 is empty!
# The Match SM092 is empty!
# The Match SM093 is empty!
# The Match SM094 is empty!
# The Match SM095 is empty!
# The Match SM096 is empty!
# The Match SM097 is empty!
# The Match SM098 is empty!
# The Match SM099 is empty!
# The Match SM100 is empty!
# The Match SM101 is empty!
# The Match SM102 is empty!
# The Match SM103 is empty!
# The Match SM104 is empty!
# The Match SM105 is empty!
# The Match SM106 is empty!
# The Match SM107 is empty!
# The Match SM108 is empty!
# The Match SM109 is empty!
# The Match SM110 is empty!
# The Match SM111 is empty!
# The Match SM112 is empty!
# The Match SM113 is empty!
# The Match SM114 is empty!
# The Match SM115 is empty!
# The Match SM116 is empty!
# The Match SM117 is empty!
# The Match SM118 is empty!
# The Match SM119 is empty!
# The Match SM120 is empty!
# The Match SM121 is empty!
# The Match SM122 is empty!
# The Match SM123 is empty!
# The Match SM124 is empty!
# The Match SM125 is empty!
# The Match SM126 is empty!
# The Match SM127 is empty!
# The Match SM128 is empty!
# The Match SM129 is empty!
# The Match SM130 is empty!
# The Match SM131 is empty!
# The Match SM132 is empty!
# The Match SM133 is empty!
# The Match SM134 is empty!
# The Match SM135 is empty!
# The Match SM136 is empty!
# The Match SM137 is empty!
# The Match SM138 is empty!
# The Match SM139 is empty!
# The Match SM140 is empty!
# The Match SM141 is empty!
# The Match SM142 is empty!
# The Match SM143 is empty!
# The Match SM144 is empty!
# The Match SM145 is empty!
# The Match SM146 is empty!
# The Match SM147 is empty!
# The Match SM148 is empty!
# The Match SM149 is empty!
# The Match SM150 is empty!
# The Match SM151 is empty!
# The Match SM152 is empty!
# The Match SM153 is empty!
# The Match SM154 is empty!
# The Match SM155 is empty!
# The Match SM156 is empty!
# The Match SM157 is empty!
# The Match SM158 is empty!
# The Match SM159 is empty!
# The Match SM160 is empty!
# The Match SM161 is empty!
# The Match SM162 is empty!
# The Match SM163 is empty!
# The Match SM164 is empty!
# The Match SM165 is empty!
# The Match SM166 is empty!
# The Match SM167 is empty!
# The Match SM168 is empty!
# The Match SM169 is empty!
# The Match SM170 is empty!
# The Match SM171 is empty!
# The Match SM172 is empty!
# The Match SM173 is empty!
# The Match SM174 is empty!
# The Match SM175 is empty!
# The Match SM176 is empty!
# The Match SM177 is empty!
# The Match SM178 is empty!
# The Match SM179 is empty!
# The Match SM180 is empty!
# The Match SM181 is empty!
# The Match SM182 is empty!
# The Match SM183 is empty!
# The Match SM184 is empty!
# The Match SM185 is empty!
# The Match SM186 is empty!
# The Match SM187 is empty!
# The Match SM188 is empty!
# The Match SM189 is empty!
# The Match SM190 is empty!
# The Match SM191 is empty!
# The Match SM192 is empty!
# The Match SM193 is empty!
# The Match SM194 is empty!
# The Match SM195 is empty!
# The Match SM196 is empty!
# The Match SM197 is empty!
# The Match SM198 is empty!
# The Match SM199 is empty!

# %%
year = 2020
match_id = 'SM028'
api_url = 'https://itp.infosys-platforms.com/api/rg/court-vision/year/' + str(year) + '/eventId/520/matchId/' + match_id +'/pointId/0_0_0'
get_json_file = requests.get(api_url)

not get_json_file.json()['courtVisionData']
# Out:
# False

# %%
with open('./year_2020_SM001_tracking_data.json') as file_name:
    pbp = json.load(file_name)

# %%
pbp['courtVisionData'][0].keys()
# Out:
# [u'pointsData',
#  u'eventType',
#  u'matchStatus',
#  u'playersData',
#  u'pointId',
#  u'courtId',
#  u'statsData',
#  u'courtName',
#  u'isMatchComplete',
#  u'setsCompleted']

# %%
len(pbp['courtVisionData'][0]['pointsData'].keys())
# Out:
# 239

# %% [markdown]
# WTA

# %%
def save_tracking_data_roland_garros_wta(year, num_matches = 20):
    '''
    Args:
    -----
    tournament_id [int]
    year: [int]
    '''

    for i in range(1,num_matches):
        if i < 10:
            match_num = '0' + str(i)
            match_id = 'SD0' + match_num
        elif ( i >= 10) & (i < 100):
            match_num = str(i)
            match_id = 'SD0' + match_num
        else:
            match_num = str(i)
            match_id = 'SD' + match_num

        
        
        #print(match_id)

        api_url = 'https://itp.infosys-platforms.com/api/rg/court-vision/year/' + str(year) + '/eventId/520/matchId/' + match_id +'/pointId/0_0_0'
        get_json_file = requests.get(api_url)

        try:
            tracking_data_json = get_json_file.json()

        except ValueError:

            print('The Match {0} does not exist!'.format(match_id))

            continue
            
        if not tracking_data_json['courtVisionData']:
            print('The Match {0} is empty!'.format(match_id))
            
            continue

        file_name = 'wta_year_' + str(year)  + '_' + match_id + '_tracking_data.json'

        with open(file_name, 'w') as json_file:
            json.dump(tracking_data_json, json_file)

# %%
save_tracking_data_roland_garros_wta(year = 2020, num_matches=200)
# Out:
# The Match SD011 is empty!
# The Match SD015 is empty!
# The Match SD017 is empty!
# The Match SD018 is empty!
# The Match SD022 is empty!
# The Match SD023 is empty!
# The Match SD024 is empty!
# The Match SD029 is empty!
# The Match SD030 is empty!
# The Match SD031 is empty!
# The Match SD034 is empty!
# The Match SD035 is empty!
# The Match SD036 is empty!
# The Match SD037 is empty!
# The Match SD038 is empty!
# The Match SD039 is empty!
# The Match SD041 is empty!
# The Match SD043 is empty!
# The Match SD044 is empty!
# The Match SD045 is empty!
# The Match SD046 is empty!
# The Match SD047 is empty!
# The Match SD048 is empty!
# The Match SD049 is empty!
# The Match SD050 is empty!
# The Match SD053 is empty!
# The Match SD054 is empty!
# The Match SD056 is empty!
# The Match SD057 is empty!
# The Match SD058 is empty!
# The Match SD059 is empty!
# The Match SD060 is empty!
# The Match SD061 is empty!
# The Match SD062 is empty!
# The Match SD065 is empty!
# The Match SD066 is empty!
# The Match SD067 is empty!
# The Match SD068 is empty!
# The Match SD070 is empty!
# The Match SD071 is empty!
# The Match SD073 is empty!
# The Match SD074 is empty!
# The Match SD075 is empty!
# The Match SD076 is empty!
# The Match SD077 is empty!
# The Match SD078 is empty!
# The Match SD081 is empty!
# The Match SD082 is empty!
# The Match SD083 is empty!
# The Match SD085 is empty!
# The Match SD090 is empty!
# The Match SD091 is empty!
# The Match SD092 is empty!
# The Match SD093 is empty!
# The Match SD094 is empty!
# The Match SD097 is empty!
# The Match SD098 is empty!
# The Match SD099 is empty!
# The Match SD100 is empty!
# The Match SD101 is empty!
# The Match SD102 is empty!
# The Match SD103 is empty!
# The Match SD104 is empty!
# The Match SD105 is empty!
# The Match SD106 is empty!
# The Match SD107 is empty!
# The Match SD108 is empty!
# The Match SD109 is empty!
# The Match SD110 is empty!
# The Match SD113 is empty!
# The Match SD114 is empty!
# The Match SD115 is empty!
# The Match SD116 is empty!
# The Match SD117 is empty!
# The Match SD119 is empty!
# The Match SD120 is empty!
# The Match SD121 is empty!
# The Match SD123 is empty!
# The Match SD124 is empty!
# The Match SD125 is empty!
# The Match SD126 is empty!
# The Match SD128 is empty!
# The Match SD129 is empty!
# The Match SD130 is empty!
# The Match SD131 is empty!
# The Match SD132 is empty!
# The Match SD133 is empty!
# The Match SD134 is empty!
# The Match SD135 is empty!
# The Match SD136 is empty!
# The Match SD137 is empty!
# The Match SD138 is empty!
# The Match SD139 is empty!
# The Match SD140 is empty!
# The Match SD141 is empty!
# The Match SD142 is empty!
# The Match SD143 is empty!
# The Match SD144 is empty!
# The Match SD145 is empty!
# The Match SD146 is empty!
# The Match SD147 is empty!
# The Match SD148 is empty!
# The Match SD149 is empty!
# The Match SD150 is empty!
# The Match SD151 is empty!
# The Match SD152 is empty!
# The Match SD153 is empty!
# The Match SD154 is empty!
# The Match SD155 is empty!
# The Match SD156 is empty!
# The Match SD157 is empty!
# The Match SD158 is empty!
# The Match SD159 is empty!
# The Match SD160 is empty!
# The Match SD161 is empty!
# The Match SD162 is empty!
# The Match SD163 is empty!
# The Match SD164 is empty!
# The Match SD165 is empty!
# The Match SD166 is empty!
# The Match SD167 is empty!
# The Match SD168 is empty!
# The Match SD169 is empty!
# The Match SD170 is empty!
# The Match SD171 is empty!
# The Match SD172 is empty!
# The Match SD173 is empty!
# The Match SD174 is empty!
# The Match SD175 is empty!
# The Match SD176 is empty!
# The Match SD177 is empty!
# The Match SD178 is empty!
# The Match SD179 is empty!
# The Match SD180 is empty!
# The Match SD181 is empty!
# The Match SD182 is empty!
# The Match SD183 is empty!
# The Match SD184 is empty!
# The Match SD185 is empty!
# The Match SD186 is empty!
# The Match SD187 is empty!
# The Match SD188 is empty!
# The Match SD189 is empty!
# The Match SD190 is empty!
# The Match SD191 is empty!
# The Match SD192 is empty!
# The Match SD193 is empty!
# The Match SD194 is empty!
# The Match SD195 is empty!
# The Match SD196 is empty!
# The Match SD197 is empty!
# The Match SD198 is empty!
# The Match SD199 is empty!

# %%
save_tracking_data_roland_garros_wta(year = 2019, num_matches=200)
# Out:
# The Match SD003 is empty!
# The Match SD011 is empty!
# The Match SD017 is empty!
# The Match SD021 is empty!
# The Match SD022 is empty!
# The Match SD023 is empty!
# The Match SD026 is empty!
# The Match SD027 is empty!
# The Match SD028 is empty!
# The Match SD030 is empty!
# The Match SD033 is empty!
# The Match SD035 is empty!
# The Match SD037 is empty!
# The Match SD038 is empty!
# The Match SD039 is empty!
# The Match SD041 is empty!
# The Match SD042 is empty!
# The Match SD043 is empty!
# The Match SD044 is empty!
# The Match SD045 is empty!
# The Match SD046 is empty!
# The Match SD047 is empty!
# The Match SD049 is empty!
# The Match SD051 is empty!
# The Match SD053 is empty!
# The Match SD054 is empty!
# The Match SD056 is empty!
# The Match SD057 is empty!
# The Match SD058 is empty!
# The Match SD059 is empty!
# The Match SD060 is empty!
# The Match SD061 is empty!
# The Match SD063 is empty!
# The Match SD065 is empty!
# The Match SD066 is empty!
# The Match SD067 is empty!
# The Match SD069 is empty!
# The Match SD070 is empty!
# The Match SD073 is empty!
# The Match SD074 is empty!
# The Match SD075 is empty!
# The Match SD076 is empty!
# The Match SD077 is empty!
# The Match SD078 is empty!
# The Match SD079 is empty!
# The Match SD081 is empty!
# The Match SD082 is empty!
# The Match SD083 is empty!
# The Match SD084 is empty!
# The Match SD085 is empty!
# The Match SD086 is empty!
# The Match SD087 is empty!
# The Match SD088 is empty!
# The Match SD089 is empty!
# The Match SD090 is empty!
# The Match SD091 is empty!
# The Match SD092 is empty!
# The Match SD093 is empty!
# The Match SD094 is empty!
# The Match SD097 is empty!
# The Match SD098 is empty!
# The Match SD099 is empty!
# The Match SD100 is empty!
# The Match SD101 is empty!
# The Match SD102 is empty!
# The Match SD103 is empty!
# The Match SD104 is empty!
# The Match SD105 is empty!
# The Match SD106 is empty!
# The Match SD107 is empty!
# The Match SD108 is empty!
# The Match SD109 is empty!
# The Match SD110 is empty!
# The Match SD113 is empty!
# The Match SD114 is empty!
# The Match SD115 is empty!
# The Match SD116 is empty!
# The Match SD117 is empty!
# The Match SD118 is empty!
# The Match SD119 is empty!
# The Match SD121 is empty!
# The Match SD122 is empty!
# The Match SD123 is empty!
# The Match SD124 is empty!
# The Match SD126 is empty!
# The Match SD128 is empty!
# The Match SD129 is empty!
# The Match SD130 is empty!
# The Match SD131 is empty!
# The Match SD132 is empty!
# The Match SD133 is empty!
# The Match SD134 is empty!
# The Match SD135 is empty!
# The Match SD136 is empty!
# The Match SD137 is empty!
# The Match SD138 is empty!
# The Match SD139 is empty!
# The Match SD140 is empty!
# The Match SD141 is empty!
# The Match SD142 is empty!
# The Match SD143 is empty!
# The Match SD144 is empty!
# The Match SD145 is empty!
# The Match SD146 is empty!
# The Match SD147 is empty!
# The Match SD148 is empty!
# The Match SD149 is empty!
# The Match SD150 is empty!
# The Match SD151 is empty!
# The Match SD152 is empty!
# The Match SD153 is empty!
# The Match SD154 is empty!
# The Match SD155 is empty!
# The Match SD156 is empty!
# The Match SD157 is empty!
# The Match SD158 is empty!
# The Match SD159 is empty!
# The Match SD160 is empty!
# The Match SD161 is empty!
# The Match SD162 is empty!
# The Match SD163 is empty!
# The Match SD164 is empty!
# The Match SD165 is empty!
# The Match SD166 is empty!
# The Match SD167 is empty!
# The Match SD168 is empty!
# The Match SD169 is empty!
# The Match SD170 is empty!
# The Match SD171 is empty!
# The Match SD172 is empty!
# The Match SD173 is empty!
# The Match SD174 is empty!
# The Match SD175 is empty!
# The Match SD176 is empty!
# The Match SD177 is empty!
# The Match SD178 is empty!
# The Match SD179 is empty!
# The Match SD180 is empty!
# The Match SD181 is empty!
# The Match SD182 is empty!
# The Match SD183 is empty!
# The Match SD184 is empty!
# The Match SD185 is empty!
# The Match SD186 is empty!
# The Match SD187 is empty!
# The Match SD188 is empty!
# The Match SD189 is empty!
# The Match SD190 is empty!
# The Match SD191 is empty!
# The Match SD192 is empty!
# The Match SD193 is empty!
# The Match SD194 is empty!
# The Match SD195 is empty!
# The Match SD196 is empty!
# The Match SD197 is empty!
# The Match SD198 is empty!
# The Match SD199 is empty!

# %%
save_tracking_data_roland_garros_wta(year = 2017, num_matches=200)
# Out:
# The Match SD001 is empty!
# The Match SD002 is empty!
# The Match SD003 is empty!
# The Match SD004 is empty!
# The Match SD005 is empty!
# The Match SD006 is empty!
# The Match SD007 is empty!
# The Match SD008 is empty!
# The Match SD009 is empty!
# The Match SD010 is empty!
# The Match SD011 is empty!
# The Match SD012 is empty!
# The Match SD013 is empty!
# The Match SD014 is empty!
# The Match SD015 is empty!
# The Match SD016 is empty!
# The Match SD017 is empty!
# The Match SD018 is empty!
# The Match SD019 is empty!
# The Match SD020 is empty!
# The Match SD021 is empty!
# The Match SD022 is empty!
# The Match SD023 is empty!
# The Match SD024 is empty!
# The Match SD025 is empty!
# The Match SD026 is empty!
# The Match SD027 is empty!
# The Match SD028 is empty!
# The Match SD029 is empty!
# The Match SD030 is empty!
# The Match SD031 is empty!
# The Match SD032 is empty!
# The Match SD033 is empty!
# The Match SD034 is empty!
# The Match SD035 is empty!
# The Match SD036 is empty!
# The Match SD037 is empty!
# The Match SD038 is empty!
# The Match SD039 is empty!
# The Match SD040 is empty!
# The Match SD041 is empty!
# The Match SD042 is empty!
# The Match SD043 is empty!
# The Match SD044 is empty!
# The Match SD045 is empty!
# The Match SD046 is empty!
# The Match SD047 is empty!
# The Match SD048 is empty!
# The Match SD049 is empty!
# The Match SD050 is empty!
# The Match SD051 is empty!
# The Match SD052 is empty!
# The Match SD053 is empty!
# The Match SD054 is empty!
# The Match SD055 is empty!
# The Match SD056 is empty!
# The Match SD057 is empty!
# The Match SD058 is empty!
# The Match SD059 is empty!
# The Match SD060 is empty!
# The Match SD061 is empty!
# The Match SD062 is empty!
# The Match SD063 is empty!
# The Match SD064 is empty!
# The Match SD065 is empty!
# The Match SD066 is empty!
# The Match SD067 is empty!
# The Match SD068 is empty!
# The Match SD069 is empty!
# The Match SD070 is empty!
# The Match SD071 is empty!
# The Match SD072 is empty!
# The Match SD073 is empty!
# The Match SD074 is empty!
# The Match SD075 is empty!
# The Match SD076 is empty!
# The Match SD077 is empty!
# The Match SD078 is empty!
# The Match SD079 is empty!
# The Match SD080 is empty!
# The Match SD081 is empty!
# The Match SD082 is empty!
# The Match SD083 is empty!
# The Match SD084 is empty!
# The Match SD085 is empty!
# The Match SD086 is empty!
# The Match SD087 is empty!
# The Match SD088 is empty!
# The Match SD089 is empty!
# The Match SD090 is empty!
# The Match SD091 is empty!
# The Match SD092 is empty!
# The Match SD093 is empty!
# The Match SD094 is empty!
# The Match SD095 is empty!
# The Match SD096 is empty!
# The Match SD097 is empty!
# The Match SD098 is empty!
# The Match SD099 is empty!
# The Match SD100 is empty!
# The Match SD101 is empty!
# The Match SD102 is empty!
# The Match SD103 is empty!
# The Match SD104 is empty!
# The Match SD105 is empty!
# The Match SD106 is empty!
# The Match SD107 is empty!
# The Match SD108 is empty!
# The Match SD109 is empty!
# The Match SD110 is empty!
# The Match SD111 is empty!
# The Match SD112 is empty!
# The Match SD113 is empty!
# The Match SD114 is empty!
# The Match SD115 is empty!
# The Match SD116 is empty!
# The Match SD117 is empty!
# The Match SD118 is empty!
# The Match SD119 is empty!
# The Match SD120 is empty!
# The Match SD121 is empty!
# The Match SD122 is empty!
# The Match SD123 is empty!
# The Match SD124 is empty!
# The Match SD125 is empty!
# The Match SD126 is empty!
# The Match SD127 is empty!
# The Match SD128 is empty!
# The Match SD129 is empty!
# The Match SD130 is empty!
# The Match SD131 is empty!
# The Match SD132 is empty!
# The Match SD133 is empty!
# The Match SD134 is empty!
# The Match SD135 is empty!
# The Match SD136 is empty!
# The Match SD137 is empty!
# The Match SD138 is empty!
# The Match SD139 is empty!
# The Match SD140 is empty!
# The Match SD141 is empty!
# The Match SD142 is empty!
# The Match SD143 is empty!
# The Match SD144 is empty!
# The Match SD145 is empty!
# The Match SD146 is empty!
# The Match SD147 is empty!
# The Match SD148 is empty!
# The Match SD149 is empty!
# The Match SD150 is empty!
# The Match SD151 is empty!
# The Match SD152 is empty!
# The Match SD153 is empty!
# The Match SD154 is empty!
# The Match SD155 is empty!
# The Match SD156 is empty!
# The Match SD157 is empty!
# The Match SD158 is empty!
# The Match SD159 is empty!
# The Match SD160 is empty!
# The Match SD161 is empty!
# The Match SD162 is empty!
# The Match SD163 is empty!
# The Match SD164 is empty!
# The Match SD165 is empty!
# The Match SD166 is empty!
# The Match SD167 is empty!
# The Match SD168 is empty!
# The Match SD169 is empty!
# The Match SD170 is empty!
# The Match SD171 is empty!
# The Match SD172 is empty!
# The Match SD173 is empty!
# The Match SD174 is empty!
# The Match SD175 is empty!
# The Match SD176 is empty!
# The Match SD177 is empty!
# The Match SD178 is empty!
# The Match SD179 is empty!
# The Match SD180 is empty!
# The Match SD181 is empty!
# The Match SD182 is empty!
# The Match SD183 is empty!
# The Match SD184 is empty!
# The Match SD185 is empty!
# The Match SD186 is empty!
# The Match SD187 is empty!
# The Match SD188 is empty!
# The Match SD189 is empty!
# The Match SD190 is empty!
# The Match SD191 is empty!
# The Match SD192 is empty!
# The Match SD193 is empty!
# The Match SD194 is empty!
# The Match SD195 is empty!
# The Match SD196 is empty!
# The Match SD197 is empty!
# The Match SD198 is empty!
# The Match SD199 is empty!

# %% [markdown]
# ### Qualifying matches

# %%
def save_tracking_data_roland_garros_qual_men(year, num_matches = 20):
    '''
    Args:
    -----
    tournament_id [int]
    year: [int]
    '''

    for i in range(1,num_matches):
        if i < 10:
            match_num = '0' + str(i)
            match_id = 'QM0' + match_num
        elif ( i >= 10) & (i < 100):
            match_num = str(i)
            match_id = 'QM0' + match_num
        else:
            match_num = str(i)
            match_id = 'QM' + match_num

        
        
        #print(match_id)

        api_url = 'https://itp.infosys-platforms.com/api/rg/court-vision/year/' + str(year) + '/eventId/520/matchId/' + match_id +'/pointId/0_0_0'
        get_json_file = requests.get(api_url)

        try:
            tracking_data_json = get_json_file.json()

        except ValueError:

            #print('The Match {0} does not exist!'.format(match_id))

            continue
            
        if not tracking_data_json['courtVisionData']:
            #print('The Match {0} is empty!'.format(match_id))
            
            continue

        file_name = 'qual_men_year_' + str(year)  + '_' + match_id + '_tracking_data.json'

        with open(file_name, 'w') as json_file:
            json.dump(tracking_data_json, json_file)
            
            
            

def save_tracking_data_roland_garros_qual_women(year, num_matches = 20):
    '''
    Args:
    -----
    tournament_id [int]
    year: [int]
    '''

    for i in range(1,num_matches):
        if i < 10:
            match_num = '0' + str(i)
            match_id = 'QD0' + match_num
        elif ( i >= 10) & (i < 100):
            match_num = str(i)
            match_id = 'QD0' + match_num
        else:
            match_num = str(i)
            match_id = 'QD' + match_num

        
        
        #print(match_id)

        api_url = 'https://itp.infosys-platforms.com/api/rg/court-vision/year/' + str(year) + '/eventId/520/matchId/' + match_id +'/pointId/0_0_0'
        get_json_file = requests.get(api_url)

        try:
            tracking_data_json = get_json_file.json()

        except ValueError:

            #print('The Match {0} does not exist!'.format(match_id))

            continue
            
        if not tracking_data_json['courtVisionData']:
            #print('The Match {0} is empty!'.format(match_id))
            
            continue

        file_name = 'qual_women_year_' + str(year)  + '_' + match_id + '_tracking_data.json'

        with open(file_name, 'w') as json_file:
            json.dump(tracking_data_json, json_file)

# %%
save_tracking_data_roland_garros_qual_men(year = 2020, num_matches=200)

# %%
save_tracking_data_roland_garros_qual_men(year = 2019, num_matches=200)

save_tracking_data_roland_garros_qual_women(year = 2020, num_matches=200)
save_tracking_data_roland_garros_qual_women(year = 2019, num_matches=200)

# %% [markdown]
# ### Save Doubles Matches

# %%
def save_tracking_data_roland_garros_doubles_men(year, num_matches = 20):
    '''
    Args:
    -----
    tournament_id [int]
    year: [int]
    '''

    for i in range(1,num_matches):
        if i < 10:
            match_num = '0' + str(i)
            match_id = 'DM0' + match_num
        elif ( i >= 10) & (i < 100):
            match_num = str(i)
            match_id = 'DM0' + match_num
        else:
            match_num = str(i)
            match_id = 'DM' + match_num

        
        
        #print(match_id)

        api_url = 'https://itp.infosys-platforms.com/api/rg/court-vision/year/' + str(year) + '/eventId/520/matchId/' + match_id +'/pointId/0_0_0'
        get_json_file = requests.get(api_url)

        try:
            tracking_data_json = get_json_file.json()

        except ValueError:

            #print('The Match {0} does not exist!'.format(match_id))

            continue
            
        if not tracking_data_json['courtVisionData']:
            #print('The Match {0} is empty!'.format(match_id))
            
            continue

        file_name = 'doubles_men_year_' + str(year)  + '_' + match_id + '_tracking_data.json'

        with open(file_name, 'w') as json_file:
            json.dump(tracking_data_json, json_file)
            
            
            

def save_tracking_data_roland_garros_doubles_women(year, num_matches = 20):
    '''
    Args:
    -----
    tournament_id [int]
    year: [int]
    '''

    for i in range(1,num_matches):
        if i < 10:
            match_num = '0' + str(i)
            match_id = 'DD0' + match_num
        elif ( i >= 10) & (i < 100):
            match_num = str(i)
            match_id = 'DD0' + match_num
        else:
            match_num = str(i)
            match_id = 'DD' + match_num

        
        
        #print(match_id)

        api_url = 'https://itp.infosys-platforms.com/api/rg/court-vision/year/' + str(year) + '/eventId/520/matchId/' + match_id +'/pointId/0_0_0'
        get_json_file = requests.get(api_url)

        try:
            tracking_data_json = get_json_file.json()

        except ValueError:

            #print('The Match {0} does not exist!'.format(match_id))

            continue
            
        if not tracking_data_json['courtVisionData']:
            #print('The Match {0} is empty!'.format(match_id))
            
            continue

        file_name = 'doubles_women_year_' + str(year)  + '_' + match_id + '_tracking_data.json'

        with open(file_name, 'w') as json_file:
            json.dump(tracking_data_json, json_file)

# %%
save_tracking_data_roland_garros_doubles_men(year = 2020, num_matches=200)
save_tracking_data_roland_garros_doubles_men(year = 2019, num_matches=200)

save_tracking_data_roland_garros_doubles_women(year = 2020, num_matches=200)
save_tracking_data_roland_garros_doubles_women(year = 2019, num_matches=200)
