# %% [markdown]
# This script was used to scrape all available tracking data from Roland Garros's Court Vision Feature.
#
# The data collected include:
#
# * Few Data from 2018
# * Reliable (ish?) data from 2019
# * Good data from 2020

# %%
import pandas as pd
pd.set_option('display.max_rows', 1000)
import json
import requests

# %%
import json
import requests

def save_tracking_data_roland_garros(year, num_matches = 20):
    '''
    Args:
    -----
    tournament_id [int]
    year: [int]
    '''

    for i in range(1,num_matches):
        if i < 10:
            match_num = '0' + str(i)
        else:
            match_num = str(i)

        match_id = 'SM0' + match_num

        print(match_id)

        api_url = 'https://itp.infosys-platforms.com/api/rg/court-vision/year/' + str(year) + '/eventId/520/matchId/' + match_id +'/pointId/0_0_0'
        get_json_file = requests.get(api_url)

        try:
            tracking_data_json = get_json_file.json()

        except ValueError:

            print('The Match {0} does not exist!'.format(match_id))

            continue
            
        if not tracking_data_json['courtVisionData']:
            print('The Match {0} is empty!'.format(match_id))
            
            continue

        file_name = 'year_' + str(year)  + '_' + match_id + '_tracking_data.json'

        with open(file_name, 'w') as json_file:
            json.dump(tracking_data_json, json_file)

# %%
save_tracking_data_roland_garros(year = 2020, num_matches=200)
# Out:
# SM001
# SM002
# SM003
# SM004
# SM005
# SM006
# SM007
# SM008
# SM009
# SM010
# SM011
# SM012
# SM013
# SM014
# SM015
# SM016
# SM017
# The Match SM017 is empty!
# SM018
# SM019
# SM020
# The Match SM020 is empty!
# SM021
# The Match SM021 is empty!
# SM022
# The Match SM022 is empty!
# SM023
# SM024
# The Match SM024 is empty!
# SM025
# The Match SM025 is empty!
# SM026
# SM027
# SM028
# SM029
# The Match SM029 is empty!
# SM030
# The Match SM030 is empty!
# SM031
# SM032
# SM033
# The Match SM033 is empty!
# SM034
# The Match SM034 is empty!
# SM035
# The Match SM035 is empty!
# SM036
# The Match SM036 is empty!
# SM037
# The Match SM037 is empty!
# SM038
# The Match SM038 is empty!
# SM039
# SM040
# The Match SM040 is empty!
# SM041
# The Match SM041 is empty!
# SM042
# The Match SM042 is empty!
# SM043
# The Match SM043 is empty!
# SM044
# SM045
# The Match SM045 is empty!
# SM046
# The Match SM046 is empty!
# SM047
# SM048
# The Match SM048 is empty!
# SM049
# The Match SM049 is empty!
# SM050
# The Match SM050 is empty!
# SM051
# The Match SM051 is empty!
# SM052
# SM053
# The Match SM053 is empty!
# SM054
# The Match SM054 is empty!
# SM055
# SM056
# SM057
# The Match SM057 is empty!
# SM058
# The Match SM058 is empty!
# SM059
# The Match SM059 is empty!
# SM060
# The Match SM060 is empty!
# SM061
# The Match SM061 is empty!
# SM062
# The Match SM062 is empty!
# SM063
# SM064
# SM065
# The Match SM065 is empty!
# SM066
# The Match SM066 is empty!
# SM067
# The Match SM067 is empty!
# SM068
# The Match SM068 is empty!
# SM069
# The Match SM069 is empty!
# SM070
# The Match SM070 is empty!
# SM071
# The Match SM071 is empty!
# SM072
# The Match SM072 is empty!
# SM073
# The Match SM073 is empty!
# SM074
# The Match SM074 is empty!
# SM075
# The Match SM075 is empty!
# SM076
# The Match SM076 is empty!
# SM077
# The Match SM077 is empty!
# SM078
# The Match SM078 is empty!
# SM079
# SM080
# SM081
# The Match SM081 is empty!
# SM082
# The Match SM082 is empty!
# SM083
# The Match SM083 is empty!
# SM084
# The Match SM084 is empty!
# SM085
# The Match SM085 is empty!
# SM086
# The Match SM086 is empty!
# SM087
# The Match SM087 is empty!
# SM088
# SM089
# The Match SM089 is empty!
# SM090
# The Match SM090 is empty!
# SM091
# The Match SM091 is empty!
# SM092
# The Match SM092 is empty!
# SM093
# The Match SM093 is empty!
# SM094
# The Match SM094 is empty!
# SM095
# SM096
# SM097
# The Match SM097 is empty!
# SM098
# The Match SM098 is empty!
# SM099
# The Match SM099 is empty!
# SM0100
# The Match SM0100 does not exist!
# SM0101
# The Match SM0101 does not exist!
# SM0102
# The Match SM0102 does not exist!
# SM0103
# The Match SM0103 does not exist!
# SM0104
# The Match SM0104 does not exist!
# SM0105
# The Match SM0105 does not exist!
# SM0106
# The Match SM0106 does not exist!
# SM0107
# The Match SM0107 does not exist!
# SM0108
# The Match SM0108 does not exist!
# SM0109
# The Match SM0109 does not exist!
# SM0110
# The Match SM0110 does not exist!
# SM0111
# The Match SM0111 does not exist!
# SM0112
# The Match SM0112 does not exist!
# SM0113
# The Match SM0113 does not exist!
# SM0114
# The Match SM0114 does not exist!
# SM0115
# The Match SM0115 does not exist!
# SM0116
# The Match SM0116 does not exist!
# SM0117
# The Match SM0117 does not exist!
# SM0118
# The Match SM0118 does not exist!
# SM0119
# The Match SM0119 does not exist!
# SM0120
# The Match SM0120 does not exist!
# SM0121
# The Match SM0121 does not exist!
# SM0122
# The Match SM0122 does not exist!
# SM0123
# The Match SM0123 does not exist!
# SM0124
# The Match SM0124 does not exist!
# SM0125
# The Match SM0125 does not exist!
# SM0126
# The Match SM0126 does not exist!
# SM0127
# The Match SM0127 does not exist!
# SM0128
# The Match SM0128 does not exist!
# SM0129
# The Match SM0129 does not exist!
# SM0130
# The Match SM0130 does not exist!
# SM0131
# The Match SM0131 does not exist!
# SM0132
# The Match SM0132 does not exist!
# SM0133
# The Match SM0133 does not exist!
# SM0134
# The Match SM0134 does not exist!
# SM0135
# The Match SM0135 does not exist!
# SM0136
# The Match SM0136 does not exist!
# SM0137
# The Match SM0137 does not exist!
# SM0138
# The Match SM0138 does not exist!
# SM0139
# The Match SM0139 does not exist!
# SM0140
# The Match SM0140 does not exist!
# SM0141
# The Match SM0141 does not exist!
# SM0142
# The Match SM0142 does not exist!
# SM0143
# The Match SM0143 does not exist!
# SM0144
# The Match SM0144 does not exist!
# SM0145
# The Match SM0145 does not exist!
# SM0146
# The Match SM0146 does not exist!
# SM0147
# The Match SM0147 does not exist!
# SM0148
# The Match SM0148 does not exist!
# SM0149
# The Match SM0149 does not exist!
# SM0150
# The Match SM0150 does not exist!
# SM0151
# The Match SM0151 does not exist!
# SM0152
# The Match SM0152 does not exist!
# SM0153
# The Match SM0153 does not exist!
# SM0154
# The Match SM0154 does not exist!
# SM0155
# The Match SM0155 does not exist!
# SM0156
# The Match SM0156 does not exist!
# SM0157
# The Match SM0157 does not exist!
# SM0158
# The Match SM0158 does not exist!
# SM0159
# The Match SM0159 does not exist!
# SM0160
# The Match SM0160 does not exist!
# SM0161
# The Match SM0161 does not exist!
# SM0162
# The Match SM0162 does not exist!
# SM0163
# The Match SM0163 does not exist!
# SM0164
# The Match SM0164 does not exist!
# SM0165
# The Match SM0165 does not exist!
# SM0166
# The Match SM0166 does not exist!
# SM0167
# The Match SM0167 does not exist!
# SM0168
# The Match SM0168 does not exist!
# SM0169
# The Match SM0169 does not exist!
# SM0170
# The Match SM0170 does not exist!
# SM0171
# The Match SM0171 does not exist!
# SM0172
# The Match SM0172 does not exist!
# SM0173
# The Match SM0173 does not exist!
# SM0174
# The Match SM0174 does not exist!
# SM0175
# The Match SM0175 does not exist!
# SM0176
# The Match SM0176 does not exist!
# SM0177
# The Match SM0177 does not exist!
# SM0178
# The Match SM0178 does not exist!
# SM0179
# The Match SM0179 does not exist!
# SM0180
# The Match SM0180 does not exist!
# SM0181
# The Match SM0181 does not exist!
# SM0182
# The Match SM0182 does not exist!
# SM0183
# The Match SM0183 does not exist!
# SM0184
# The Match SM0184 does not exist!
# SM0185
# The Match SM0185 does not exist!
# SM0186
# The Match SM0186 does not exist!
# SM0187
# The Match SM0187 does not exist!
# SM0188
# The Match SM0188 does not exist!
# SM0189
# The Match SM0189 does not exist!
# SM0190
# The Match SM0190 does not exist!
# SM0191
# The Match SM0191 does not exist!
# SM0192
# The Match SM0192 does not exist!
# SM0193
# The Match SM0193 does not exist!
# SM0194
# The Match SM0194 does not exist!
# SM0195
# The Match SM0195 does not exist!
# SM0196
# The Match SM0196 does not exist!
# SM0197
# The Match SM0197 does not exist!
# SM0198
# The Match SM0198 does not exist!
# SM0199
# The Match SM0199 does not exist!

# %%
save_tracking_data_roland_garros(year = 2017, num_matches=50)
# Out:
# SM001
# The Match SM001 is empty!
# SM002
# The Match SM002 is empty!
# SM003
# The Match SM003 is empty!
# SM004
# The Match SM004 is empty!
# SM005
# The Match SM005 is empty!
# SM006
# The Match SM006 is empty!
# SM007
# The Match SM007 is empty!
# SM008
# The Match SM008 is empty!
# SM009
# The Match SM009 is empty!
# SM010
# The Match SM010 is empty!
# SM011
# The Match SM011 is empty!
# SM012
# The Match SM012 is empty!
# SM013
# The Match SM013 is empty!
# SM014
# The Match SM014 is empty!
# SM015
# The Match SM015 is empty!
# SM016
# The Match SM016 is empty!
# SM017
# The Match SM017 is empty!
# SM018
# The Match SM018 is empty!
# SM019
# The Match SM019 is empty!
# SM020
# The Match SM020 is empty!
# SM021
# The Match SM021 is empty!
# SM022
# The Match SM022 is empty!
# SM023
# The Match SM023 is empty!
# SM024
# The Match SM024 is empty!
# SM025
# The Match SM025 is empty!
# SM026
# The Match SM026 is empty!
# SM027
# The Match SM027 is empty!
# SM028
# The Match SM028 is empty!
# SM029
# The Match SM029 is empty!
# SM030
# The Match SM030 is empty!
# SM031
# The Match SM031 is empty!
# SM032
# The Match SM032 is empty!
# SM033
# The Match SM033 is empty!
# SM034
# The Match SM034 is empty!
# SM035
# The Match SM035 is empty!
# SM036
# The Match SM036 is empty!
# SM037
# The Match SM037 is empty!
# SM038
# The Match SM038 is empty!
# SM039
# The Match SM039 is empty!
# SM040
# The Match SM040 is empty!
# SM041
# The Match SM041 is empty!
# SM042
# The Match SM042 is empty!
# SM043
# The Match SM043 is empty!
# SM044
# The Match SM044 is empty!
# SM045
# The Match SM045 is empty!
# SM046
# The Match SM046 is empty!
# SM047
# The Match SM047 is empty!
# SM048
# The Match SM048 is empty!
# SM049
# The Match SM049 is empty!

# %%
year = 2020
match_id = 'SM028'
api_url = 'https://itp.infosys-platforms.com/api/rg/court-vision/year/' + str(year) + '/eventId/520/matchId/' + match_id +'/pointId/0_0_0'
get_json_file = requests.get(api_url)

not get_json_file.json()['courtVisionData']
# Out:
# False

# %%
with open('./year_2020_SM001_tracking_data.json') as file_name:
    pbp = json.load(file_name)

# %%
pbp['courtVisionData'][0].keys()
# Out:
# [u'pointsData',
#  u'eventType',
#  u'matchStatus',
#  u'playersData',
#  u'pointId',
#  u'courtId',
#  u'statsData',
#  u'courtName',
#  u'isMatchComplete',
#  u'setsCompleted']

# %%
len(pbp['courtVisionData'][0]['pointsData'].keys())
# Out:
# 239

# %% [markdown]
# WTA

# %%
def save_tracking_data_roland_garros_wta(year, num_matches = 20):
    '''
    Args:
    -----
    tournament_id [int]
    year: [int]
    '''

    for i in range(1,num_matches):
        if i < 10:
            match_num = '0' + str(i)
        else:
            match_num = str(i)

        match_id = 'SD0' + match_num

        print(match_id)

        api_url = 'https://itp.infosys-platforms.com/api/rg/court-vision/year/' + str(year) + '/eventId/520/matchId/' + match_id +'/pointId/0_0_0'
        get_json_file = requests.get(api_url)

        try:
            tracking_data_json = get_json_file.json()

        except ValueError:

            print('The Match {0} does not exist!'.format(match_id))

            continue
            
        if not tracking_data_json['courtVisionData']:
            print('The Match {0} is empty!'.format(match_id))
            
            continue

        file_name = 'wta_year_' + str(year)  + '_' + match_id + '_tracking_data.json'

        with open(file_name, 'w') as json_file:
            json.dump(tracking_data_json, json_file)

# %%
save_tracking_data_roland_garros_wta(year = 2020, num_matches=200)
# Out:
# SD001
# SD002
# SD003
# SD004
# SD005
# SD006
# SD007
# SD008
# SD009
# SD010
# SD011
# The Match SD011 is empty!
# SD012
# SD013
# SD014
# SD015
# The Match SD015 is empty!
# SD016
# SD017
# The Match SD017 is empty!
# SD018
# The Match SD018 is empty!
# SD019
# SD020
# SD021
# SD022
# The Match SD022 is empty!
# SD023
# The Match SD023 is empty!
# SD024
# The Match SD024 is empty!
# SD025
# SD026
# SD027
# SD028
# SD029
# The Match SD029 is empty!
# SD030
# The Match SD030 is empty!
# SD031
# The Match SD031 is empty!
# SD032
# SD033
# SD034
# The Match SD034 is empty!
# SD035
# The Match SD035 is empty!
# SD036
# The Match SD036 is empty!
# SD037
# The Match SD037 is empty!
# SD038
# The Match SD038 is empty!
# SD039
# The Match SD039 is empty!
# SD040
# SD041
# The Match SD041 is empty!
# SD042
# SD043
# The Match SD043 is empty!
# SD044
# The Match SD044 is empty!
# SD045
# The Match SD045 is empty!
# SD046
# The Match SD046 is empty!
# SD047
# The Match SD047 is empty!
# SD048
# The Match SD048 is empty!
# SD049
# The Match SD049 is empty!
# SD050
# The Match SD050 is empty!
# SD051
# SD052
# SD053
# The Match SD053 is empty!
# SD054
# The Match SD054 is empty!
# SD055
# SD056
# The Match SD056 is empty!
# SD057
# The Match SD057 is empty!
# SD058
# The Match SD058 is empty!
# SD059
# The Match SD059 is empty!
# SD060
# The Match SD060 is empty!
# SD061
# The Match SD061 is empty!
# SD062
# The Match SD062 is empty!
# SD063
# SD064
# SD065
# The Match SD065 is empty!
# SD066
# The Match SD066 is empty!
# SD067
# The Match SD067 is empty!
# SD068
# The Match SD068 is empty!
# SD069
# SD070
# The Match SD070 is empty!
# SD071
# The Match SD071 is empty!
# SD072
# SD073
# The Match SD073 is empty!
# SD074
# The Match SD074 is empty!
# SD075
# The Match SD075 is empty!
# SD076
# The Match SD076 is empty!
# SD077
# The Match SD077 is empty!
# SD078
# The Match SD078 is empty!
# SD079
# SD080
# SD081
# The Match SD081 is empty!
# SD082
# The Match SD082 is empty!
# SD083
# The Match SD083 is empty!
# SD084
# SD085
# The Match SD085 is empty!
# SD086
# SD087
# SD088
# SD089
# SD090
# The Match SD090 is empty!
# SD091
# The Match SD091 is empty!
# SD092
# The Match SD092 is empty!
# SD093
# The Match SD093 is empty!
# SD094
# The Match SD094 is empty!
# SD095
# SD096
# SD097
# The Match SD097 is empty!
# SD098
# The Match SD098 is empty!
# SD099
# The Match SD099 is empty!
# SD0100
# The Match SD0100 does not exist!
# SD0101
# The Match SD0101 does not exist!
# SD0102
# The Match SD0102 does not exist!
# SD0103
# The Match SD0103 does not exist!
# SD0104
# The Match SD0104 does not exist!
# SD0105
# The Match SD0105 does not exist!
# SD0106
# The Match SD0106 does not exist!
# SD0107
# The Match SD0107 does not exist!
# SD0108
# The Match SD0108 does not exist!
# SD0109
# The Match SD0109 does not exist!
# SD0110
# The Match SD0110 does not exist!
# SD0111
# The Match SD0111 does not exist!
# SD0112
# The Match SD0112 does not exist!
# SD0113
# The Match SD0113 does not exist!
# SD0114
# The Match SD0114 does not exist!
# SD0115
# The Match SD0115 does not exist!
# SD0116
# The Match SD0116 does not exist!
# SD0117
# The Match SD0117 does not exist!
# SD0118
# The Match SD0118 does not exist!
# SD0119
# The Match SD0119 does not exist!
# SD0120
# The Match SD0120 does not exist!
# SD0121
# The Match SD0121 does not exist!
# SD0122
# The Match SD0122 does not exist!
# SD0123
# The Match SD0123 does not exist!
# SD0124
# The Match SD0124 does not exist!
# SD0125
# The Match SD0125 does not exist!
# SD0126
# The Match SD0126 does not exist!
# SD0127
# The Match SD0127 does not exist!
# SD0128
# The Match SD0128 does not exist!
# SD0129
# The Match SD0129 does not exist!
# SD0130
# The Match SD0130 does not exist!
# SD0131
# The Match SD0131 does not exist!
# SD0132
# The Match SD0132 does not exist!
# SD0133
# The Match SD0133 does not exist!
# SD0134
# The Match SD0134 does not exist!
# SD0135
# The Match SD0135 does not exist!
# SD0136
# The Match SD0136 does not exist!
# SD0137
# The Match SD0137 does not exist!
# SD0138
# The Match SD0138 does not exist!
# SD0139
# The Match SD0139 does not exist!
# SD0140
# The Match SD0140 does not exist!
# SD0141
# The Match SD0141 does not exist!
# SD0142
# The Match SD0142 does not exist!
# SD0143
# The Match SD0143 does not exist!
# SD0144
# The Match SD0144 does not exist!
# SD0145
# The Match SD0145 does not exist!
# SD0146
# The Match SD0146 does not exist!
# SD0147
# The Match SD0147 does not exist!
# SD0148
# The Match SD0148 does not exist!
# SD0149
# The Match SD0149 does not exist!
# SD0150
# The Match SD0150 does not exist!
# SD0151
# The Match SD0151 does not exist!
# SD0152
# The Match SD0152 does not exist!
# SD0153
# The Match SD0153 does not exist!
# SD0154
# The Match SD0154 does not exist!
# SD0155
# The Match SD0155 does not exist!
# SD0156
# The Match SD0156 does not exist!
# SD0157
# The Match SD0157 does not exist!
# SD0158
# The Match SD0158 does not exist!
# SD0159
# The Match SD0159 does not exist!
# SD0160
# The Match SD0160 does not exist!
# SD0161
# The Match SD0161 does not exist!
# SD0162
# The Match SD0162 does not exist!
# SD0163
# The Match SD0163 does not exist!
# SD0164
# The Match SD0164 does not exist!
# SD0165
# The Match SD0165 does not exist!
# SD0166
# The Match SD0166 does not exist!
# SD0167
# The Match SD0167 does not exist!
# SD0168
# The Match SD0168 does not exist!
# SD0169
# The Match SD0169 does not exist!
# SD0170
# The Match SD0170 does not exist!
# SD0171
# The Match SD0171 does not exist!
# SD0172
# The Match SD0172 does not exist!
# SD0173
# The Match SD0173 does not exist!
# SD0174
# The Match SD0174 does not exist!
# SD0175
# The Match SD0175 does not exist!
# SD0176
# The Match SD0176 does not exist!
# SD0177
# The Match SD0177 does not exist!
# SD0178
# The Match SD0178 does not exist!
# SD0179
# The Match SD0179 does not exist!
# SD0180
# The Match SD0180 does not exist!
# SD0181
# The Match SD0181 does not exist!
# SD0182
# The Match SD0182 does not exist!
# SD0183
# The Match SD0183 does not exist!
# SD0184
# The Match SD0184 does not exist!
# SD0185
# The Match SD0185 does not exist!
# SD0186
# The Match SD0186 does not exist!
# SD0187
# The Match SD0187 does not exist!
# SD0188
# The Match SD0188 does not exist!
# SD0189
# The Match SD0189 does not exist!
# SD0190
# The Match SD0190 does not exist!
# SD0191
# The Match SD0191 does not exist!
# SD0192
# The Match SD0192 does not exist!
# SD0193
# The Match SD0193 does not exist!
# SD0194
# The Match SD0194 does not exist!
# SD0195
# The Match SD0195 does not exist!
# SD0196
# The Match SD0196 does not exist!
# SD0197
# The Match SD0197 does not exist!
# SD0198
# The Match SD0198 does not exist!
# SD0199
# The Match SD0199 does not exist!
