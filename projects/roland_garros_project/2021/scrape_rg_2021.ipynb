# %% [markdown]
# ## 2021 Roland Garros

# %%
import pandas as pd
import numpy as np
import json
import requests
import os

pd.set_option('display.max_rows', 500)

# --> Import functions from "process" script
import sys
sys.path.append('../src')

from process import categorise_serve_direction, get_point_level_info, get_match_point_level_info, add_server_and_returner_scores, add_cum_games_and_sets, collect_serve_return_locations

# %%
# Save JSON Data

def save_tracking_data_roland_garros_2021(year, num_matches = 20):
    '''
    Args:
    -----
    tournament_id [int]
    year: [int]
    '''

    for i in range(1,num_matches):
        if i < 10:
            match_num = '0' + str(i)
            match_id = 'SM0' + match_num
        elif ( i >= 10) & (i < 100):
            match_num = str(i)
            match_id = 'SM0' + match_num
        else:
            match_num = str(i)
            match_id = 'SM' + match_num

        

        #print(match_id)

        api_url = 'https://itp-rg-sls.infosys-platforms.com/prod/api/court-vision/year/' + str(year) + '/eventId/520/matchId/' + match_id +'/pointId/0_0_0'
        get_json_file = requests.get(api_url)

        try:
            tracking_data_json = get_json_file.json()

        except ValueError:

            #print('The Match {0} does not exist!'.format(match_id))

            continue
            
        if not tracking_data_json['courtVisionData']:
            #print('The Match {0} is empty!'.format(match_id))
            
            continue

        file_name = 'year_' + str(year)  + '_' + match_id + '_tracking_data.json'

        with open(file_name, 'w') as json_file:
            json.dump(tracking_data_json, json_file)
            
            
def save_tracking_data_roland_garros_wta_2021(year, num_matches = 20):
    '''
    Args:
    -----
    tournament_id [int]
    year: [int]
    '''

    for i in range(1,num_matches):
        if i < 10:
            match_num = '0' + str(i)
            match_id = 'SD0' + match_num
        elif ( i >= 10) & (i < 100):
            match_num = str(i)
            match_id = 'SD0' + match_num
        else:
            match_num = str(i)
            match_id = 'SD' + match_num

        
        
        #print(match_id)
        #https://itp-rg-sls.infosys-platforms.com/prod/api/court-vision/year/2021/eventId/520/matchId/SD103/pointId/0_0_0

        api_url = 'https://itp-rg-sls.infosys-platforms.com/prod/api/court-vision/year/' + str(year) + '/eventId/520/matchId/' + match_id +'/pointId/0_0_0'
        get_json_file = requests.get(api_url)

        try:
            tracking_data_json = get_json_file.json()

        except ValueError:

            print('The Match {0} does not exist!'.format(match_id))

            continue
            
        if not tracking_data_json['courtVisionData']:
            print('The Match {0} is empty!'.format(match_id))
            
            continue

        file_name = 'wta_year_' + str(year)  + '_' + match_id + '_tracking_data.json'

        with open(file_name, 'w') as json_file:
            json.dump(tracking_data_json, json_file)

# %%
# %%capture 
save_tracking_data_roland_garros_2021(year = 2021, num_matches=200)

# %%
save_tracking_data_roland_garros_wta_2021(year = 2021, num_matches=200)
# Out:
# The Match SD001 is empty!
# The Match SD002 is empty!
# The Match SD003 is empty!
# The Match SD004 is empty!
# The Match SD005 is empty!
# The Match SD006 is empty!
# The Match SD007 is empty!
# The Match SD008 is empty!
# The Match SD009 is empty!
# The Match SD010 is empty!
# The Match SD011 is empty!
# The Match SD016 is empty!
# The Match SD022 is empty!
# The Match SD028 is empty!
# The Match SD029 is empty!
# The Match SD033 is empty!
# The Match SD034 is empty!
# The Match SD037 is empty!
# The Match SD038 is empty!
# The Match SD040 is empty!
# The Match SD041 is empty!
# The Match SD042 is empty!
# The Match SD043 is empty!
# The Match SD044 is empty!
# The Match SD045 is empty!
# The Match SD049 is empty!
# The Match SD050 is empty!
# The Match SD051 is empty!
# The Match SD053 is empty!
# The Match SD054 is empty!
# The Match SD056 is empty!
# The Match SD057 is empty!
# The Match SD058 is empty!
# The Match SD062 is empty!
# The Match SD063 is empty!
# The Match SD065 is empty!
# The Match SD066 is empty!
# The Match SD067 is empty!
# The Match SD068 is empty!
# The Match SD069 is empty!
# The Match SD071 is empty!
# The Match SD074 is empty!
# The Match SD075 is empty!
# The Match SD076 is empty!
# The Match SD077 is empty!
# The Match SD078 is empty!
# The Match SD081 is empty!
# The Match SD082 is empty!
# The Match SD083 is empty!
# The Match SD084 is empty!
# The Match SD085 is empty!
# The Match SD086 is empty!
# The Match SD087 is empty!
# The Match SD089 is empty!
# The Match SD090 is empty!
# The Match SD091 is empty!
# The Match SD092 is empty!
# The Match SD094 is empty!
# The Match SD097 is empty!
# The Match SD098 is empty!
# The Match SD099 is empty!
# The Match SD100 is empty!
# The Match SD101 is empty!
# The Match SD102 is empty!
# The Match SD105 is empty!
# The Match SD106 is empty!
# The Match SD108 is empty!
# The Match SD109 is empty!
# The Match SD110 is empty!
# The Match SD112 is empty!
# The Match SD113 is empty!
# The Match SD114 is empty!
# The Match SD115 is empty!
# The Match SD116 is empty!
# The Match SD117 is empty!
# The Match SD118 is empty!
# The Match SD119 is empty!
# The Match SD120 is empty!
# The Match SD123 is empty!
# The Match SD124 is empty!
# The Match SD126 is empty!
# The Match SD128 is empty!
# The Match SD129 is empty!
# The Match SD130 is empty!
# The Match SD131 is empty!
# The Match SD132 is empty!
# The Match SD133 is empty!
# The Match SD134 is empty!
# The Match SD135 is empty!
# The Match SD136 is empty!
# The Match SD137 is empty!
# The Match SD138 is empty!
# The Match SD139 is empty!
# The Match SD140 is empty!
# The Match SD141 is empty!
# The Match SD142 is empty!
# The Match SD143 is empty!
# The Match SD144 is empty!
# The Match SD145 is empty!
# The Match SD146 is empty!
# The Match SD147 is empty!
# The Match SD148 is empty!
# The Match SD149 is empty!
# The Match SD150 is empty!
# The Match SD151 is empty!
# The Match SD152 is empty!
# The Match SD153 is empty!
# The Match SD154 is empty!
# The Match SD155 is empty!
# The Match SD156 is empty!
# The Match SD157 is empty!
# The Match SD158 is empty!
# The Match SD159 is empty!
# The Match SD160 is empty!
# The Match SD161 is empty!
# The Match SD162 is empty!
# The Match SD163 is empty!
# The Match SD164 is empty!
# The Match SD165 is empty!
# The Match SD166 is empty!
# The Match SD167 is empty!
# The Match SD168 is empty!
# The Match SD169 is empty!
# The Match SD170 is empty!
# The Match SD171 is empty!
# The Match SD172 is empty!
# The Match SD173 is empty!
# The Match SD174 is empty!
# The Match SD175 is empty!
# The Match SD176 is empty!
# The Match SD177 is empty!
# The Match SD178 is empty!
# The Match SD179 is empty!
# The Match SD180 is empty!
# The Match SD181 is empty!
# The Match SD182 is empty!
# The Match SD183 is empty!
# The Match SD184 is empty!
# The Match SD185 is empty!
# The Match SD186 is empty!
# The Match SD187 is empty!
# The Match SD188 is empty!
# The Match SD189 is empty!
# The Match SD190 is empty!
# The Match SD191 is empty!
# The Match SD192 is empty!
# The Match SD193 is empty!
# The Match SD194 is empty!
# The Match SD195 is empty!
# The Match SD196 is empty!
# The Match SD197 is empty!
# The Match SD198 is empty!
# The Match SD199 is empty!

# %%
# %%capture 
# Supresses print message

rg_2021_data_frame = pd.DataFrame([])
for match_filename in os.listdir("./rg_2021_json_data"):
    
    if match_filename.endswith(".json"):
    
        with open('/Users/petertea/tennis_analytics/projects/roland_garros_project/2021/rg_2021_json_data/' + match_filename) as filename:
            tracking_data_json = json.load(filename)

        print(filename)

        data_to_add = get_match_point_level_info(tracking_data_json)
        data_to_add['match_id'] = match_filename

        year = [int(s) for s in match_filename.split('_') if s.isdigit()][0]
        is_wta = match_filename[0:3] == 'wta'
        data_to_add['year'] = year
        data_to_add['is_wta'] = is_wta
        rg_2021_data_frame = rg_2021_data_frame.append( data_to_add )

# %%
rg_2021_data_frame.to_csv('roland_garros_2021.csv', index=False)

# %%
# PLAYER IDS
def get_match_level_info(tracking_data_json, year):
    '''
    Args:
    -----
    year: match year
    tracking_data_json [json]: Json file
    
    Returns:
    --------
    dict of row to append into a dataframe
    
    
    Returns basic information from a match (player names, seed, court name)
    '''
    
    # Get to the crux of the information
    tracking_data_dict = tracking_data_json['courtVisionData'][0]
    
    #atp_tracking_data_dict['isMatchComplete']


    # -----------------------------
    # Player information
    # -----------------------------
    player1_info = tracking_data_dict['playersData']['playerTeam']
    player2_info = tracking_data_dict['playersData']['opponentTeam']

    
    match_dict = dict(
        year = year,
        player1 = player1_info[0]['name'],
        player2 = player2_info[0]['name'],
        player1_id = player1_info[0]['id'],
        player1_country = player1_info[0]['country'],
        player1_seed = player1_info[0]['seed'],
        player2_id = player2_info[0]['id'],
        player2_country = player2_info[0]['country'],
        player2_seed = player2_info[0]['seed'],
        
    # -------------------------------
    # - I have no idea what this is
    # -------------------------------
        point_id = tracking_data_dict['pointId'],
        court_name = tracking_data_dict['courtName'],
        court_id = tracking_data_dict['courtId'],
        num_sets_completed = tracking_data_dict['setsCompleted'],
        
        # Mens/Womens Singles
        match_type = tracking_data_dict['eventType'],

        # Complete status?
        match_status = tracking_data_dict['matchStatus']
        
        
    )
    
    return match_dict

# %%
### Loop through all json files in directory
data_list = []

for filename in os.listdir('./rg_2021_json_data'):
    if filename.endswith(".json"): 
         with open('/Users/petertea/tennis_analytics/projects/roland_garros_project/2021/rg_2021_json_data/' + filename) as file_name:
                tracking_data_json = json.load(file_name)
                file_year = [int(s) for s in filename.split('_') if s.isdigit()]
                match_info_to_add = get_match_level_info(tracking_data_json, year = file_year[0])
                match_info_to_add['filename'] = filename
                data_list.append(match_info_to_add)
    else:
        continue

        
available_matches = pd.DataFrame(data_list)
available_matches.sort_values(by=['year', 'match_type'], inplace = True)
available_matches.to_csv('rg_2021_matches_in_repo.csv', index = False)
#available_matches[available_matches['match_type'] == "Men's Singles"].head()

# %%
available_matches.sort_values(by = ['filename'])
# Out:
#     year              player1           player2 player1_id player1_country  \
# 40  2021           S.WILLIAMS        E.RYBAKINA       3370             USA
# 53  2021           V.AZARENKA  A.PAVLYUCHENKOVA      12595             BLR
# 1   2021           T.ZIDANSEK         S.CIRSTEA      33787             SLO
# 83  2021        M.VONDROUSOVA          P.BADOSA      36620             CZE
# 22  2021              C.GAUFF           J.BRADY      44185             USA
# 84  2021           S.STEPHENS         K.MUCHOVA      21500             USA
# 2   2021         B.KREJCIKOVA       E.SVITOLINA      26436             CZE
# 65  2021              S.KENIN          J.PEGULA      35854             USA
# 28  2021            M.SAKKARI         E.MERTENS      28771             GRE
# 45  2021          A.KONTAVEIT         I.SWIATEK      26434             EST
# 8   2021           S.WILLIAMS         D.COLLINS       3370             USA
# 85  2021           E.RYBAKINA         E.VESNINA      38569             KAZ
# 76  2021           V.AZARENKA            M.KEYS      12595             BLR
# 11  2021     A.PAVLYUCHENKOVA       A.SABALENKA      15108             RUS
# 61  2021             P.HERCOG     M.VONDROUSOVA      18049             SLO
# 33  2021             P.BADOSA          A.BOGDAN      32919             ESP
# 37  2021              A.BARTY         M.LINETTE      27902             AUS
# 90  2021              F.FERRO           J.BRADY      30524             FRA
# 68  2021          Ka.PLISKOVA        S.STEPHENS      18274             CZE
# 5   2021                 A.LI       E.SVITOLINA      40660             USA
# 86  2021          A.KONTAVEIT      K.MLADENOVIC      26434             EST
# 7   2021           R.PETERSON         I.SWIATEK      28280             SWE
# 75  2021           S.WILLIAMS      M.BUZARNESCU       3370             USA
# 32  2021           V.AZARENKA          C.TAUSON      12595             BLR
# 67  2021          A.SASNOVICH       A.SABALENKA      26058             BLR
# 13  2021          D.KASATKINA          B.BENCIC      31281             RUS
# 51  2021             P.HERCOG          C.GARCIA      18049             SLO
# 43  2021                H.TAN     M.VONDROUSOVA      31398             FRA
# 19  2021              A.BARTY            B.PERA      27902             AUS
# 54  2021             ES.LIANG           F.FERRO      42514             TPE
# 25  2021          Ka.PLISKOVA           D.VEKIC      18274             CZE
# 55  2021     C.SUAREZ NAVARRO        S.STEPHENS      11073             ESP
# 21  2021              O.BABEL       E.SVITOLINA      44509             FRA
# 87  2021              S.KENIN       J.OSTAPENKO      35854             USA
# 66  2021           G.MUGURUZA         M.KOSTYUK      23872             ESP
# 69  2021       AK.SCHMIEDLOVA      K.MLADENOVIC      26485             SVK
# 62  2021              K.JUVAN         I.SWIATEK      40087             SLO
# 50  2021           S.WILLIAMS            I.BEGU       3370             USA
# 71  2021             G.MINNEN         P.KVITOVA      31313             BEL
# 29  2021           V.AZARENKA      S.KUZNETSOVA      12595             BLR
# 36  2021              O.DODIN            M.KEYS      28687             FRA
# 9   2021             A.KONJUH       A.SABALENKA      31288             CRO
# 0   2021          L.SIEGEMUND          C.GARCIA       9086             GER
# 20  2021             A.CORNET             H.TAN      13263             FRA
# 56  2021              C.BUREL         D.KOVINIC      41884             FRA
# 41  2021               PM.TIG           N.OSAKA      26506             ROU
# 58  2021             A.ZVEREV       K.NISHIKORI      30350             GER
# 24  2021  A.DAVIDOVICH FOKINA        F.DELBONIS      39036             ESP
# 80  2021          S.TSITSIPAS   P.CARRENO BUSTA      35398             GRE
# 18  2021              C.GARIN        D.MEDVEDEV      26967             CHI
# 3   2021           N.DJOKOVIC        R.BERANKIS       9801             SRB
# 17  2021         M.BERRETTINI            S.KWON      29046             ITA
# 79  2021            D.KOEPFER         R.FEDERER      32094             GER
# 34  2021              R.NADAL          C.NORRIE       7792             ESP
# 60  2021        D.SCHWARTZMAN   P.KOHLSCHREIBER      24162             ARG
# 30  2021            C.ALCARAZ         JL.STRUFF      44408             ESP
# 74  2021             A.ZVEREV           L.DJERE      30350             GER
# 16  2021          K.NISHIKORI       H.LAAKSONEN      13059             JPN
# 91  2021            F.FOGNINI        F.DELBONIS       9852             ITA
# 14  2021          S.TSITSIPAS           J.ISNER      35398             GRE
# 72  2021            S.JOHNSON   P.CARRENO BUSTA      18972             USA
# 44  2021             R.OPELKA        D.MEDVEDEV      32402             USA
# 63  2021           N.DJOKOVIC          P.CUEVAS       9801             SRB
# 10  2021         M.BERRETTINI           F.CORIA      29046             ITA
# 77  2021              M.CILIC         R.FEDERER      11674             CRO
# 31  2021              R.NADAL         R.GASQUET       7792             ESP
# 48  2021             J.SINNER           G.MAGER      39723             ITA
# 35  2021               M.YMER         G.MONFILS      33597             SWE
# 6   2021             A.ZVEREV       R.SAFIULLIN      30350             GER
# 26  2021          K.KHACHANOV       K.NISHIKORI      29528             RUS
# 64  2021          H.LAAKSONEN   R.BAUTISTA AGUT      19041             SUI
# 12  2021          S.TSITSIPAS        P.MARTINEZ      35398             GRE
# 88  2021           E.COUACAUD   P.CARRENO BUSTA      28510             FRA
# 42  2021               T.PAUL        D.MEDVEDEV      33541             USA
# 82  2021           N.DJOKOVIC        T.SANDGREN       9801             SRB
# 78  2021           R.BERANKIS         U.HUMBERT      17510             LTU
# 23  2021            JW.TSONGA        Y.NISHIOKA       6291             FRA
# 52  2021         M.BERRETTINI          T.DANIEL      29046             ITA
# 4   2021              M.CILIC     A.RINDERKNECH      11674             CRO
# 81  2021            D.ISTOMIN         R.FEDERER       7837             UZB
# 15  2021              R.NADAL         A.POPYRIN       7792             ESP
# 73  2021             H.GASTON         R.GASQUET      38551             FRA
# 49  2021             J.SINNER        PH.HERBERT      39723             ITA
# 59  2021      A.RAMOS-VINOLAS         G.MONFILS      14065             ESP
# 27  2021             A.ZVEREV            O.OTTE      30350             GER
# 38  2021             C.MOUTET           L.DJERE      36358             FRA
# 47  2021               C.RUUD           B.PAIRE      36389             NOR
# 39  2021            F.FOGNINI         G.BARRERE       9852             ITA
# 46  2021          M.FUCSOVICS           G.SIMON      22454             HUN
# 70  2021            P.ANDUJAR           D.THIEM       9592             ESP
# 89  2021          S.TSITSIPAS          J.CHARDY      35398             GRE
# 57  2021             A.BUBLIK        D.MEDVEDEV      29098             KAZ
#
#    player1_seed player2_id player2_country player2_seed point_id  \
# 40            7      38569             KAZ           21   2_12_4
# 53           15      15108             RUS           31    3_8_3
# 1                    14440             ROU                 2_7_7
# 83           20      32919             ESP           33    3_8_5
# 22           24      27929             USA           13    1_7_4
# 84                   35961             CZE           18   2_12_5
# 2                    23968             UKR            5    2_8_4
# 65            4      21863             USA           28   3_10_5
# 28           17      26448             BEL           14    3_8_5
# 45           30      40613             POL            8    2_6_5
# 8             7      30464             USA                2_10_5
# 85           21       9117             RUS                2_10_3
# 76           15      24265             USA           23   2_8_11
# 11           31      33249             BLR            3    3_6_5
# 61                   36620             CZE           20   2_9_11
# 33           33      19858             ROU                3_10_9
# 37            1      21355             POL                 2_4_6
# 90                   27929             USA           13   3_12_5
# 68            9      21500             USA                 2_7_7
# 5                    23968             UKR            5   2_10_4
# 86           30      19921             FRA                 2_6_4
# 7                    40613             POL            8    2_7_3
# 75            7      13153             ROU                 3_7_3
# 32           15      42533             DEN                2_10_5
# 67                   33249             BLR            3    2_9_7
# 13                   28865             SUI           10    2_8_5
# 51                   23726             FRA                2_10_5
# 43                   36620             CZE           20    2_9_5
# 19            1      28763             USA                 3_8_7
# 54                   30524             FRA                3_10_4
# 25            9      26513             CRO                2_10_4
# 55                   21500             USA                3_10_5
# 21                   23968             UKR            5   2_12_4
# 87            4      28758             LAT                 3_9_3
# 66           12      40683             UKR                2_10_4
# 69                   19921             FRA                 2_6_3
# 62                   40613             POL            8  2_12_15
# 50            7      16659             ROU                 2_8_4
# 71                   18124             CZE           11    3_7_4
# 29           15       5745             RUS                 3_9_7
# 36                   24265             USA           23    3_7_4
# 9                    33249             BLR            3    2_9_6
# 0                    23726             FRA                 2_7_9
# 20                   31398             FRA                2_10_4
# 56                   25890             MNE               2_13_16
# 41                   30764             JPN            2  2_13_11
# 58            6      13059             JPN                 3_7_3
# 24                   20304             ARG                4_10_9
# 80            5      21578             ESP           12   3_12_4
# 18           22      28836             RUS            2   3_12_4
# 3             1      17510             LTU                 3_7_7
# 17            9      34679             KOR                3_10_4
# 79                    2508             SUI            8   4_12_4
# 34            3      28593             GBR                 3_9_6
# 60           10       4825             GER                 3_7_9
# 30                   23386             GER                 3_8_5
# 74            6      28518             SRB                 3_8_3
# 16                   19041             SUI                 2_1_4
# 91           27      20304             ARG                 3_9_8
# 14            5      15820             USA           31    4_7_4
# 72                   21578             ESP           12    3_8_7
# 44           32      28836             RUS            2   3_10_4
# 63            1       9767             URU                3_10_4
# 10            9      24618             ARG                 3_8_3
# 77                    2508             SUI            8    4_8_5
# 31            3       6083             FRA                 3_8_5
# 48           18      27258             ITA                 4_9_6
# 35                    9525             FRA           14    4_9_5
# 6             6      33560             RUS                3_13_7
# 26           23      13059             JPN                5_10_3
# 64                   13354             ESP           11    4_8_4
# 12            5      32244             ESP                 3_9_8
# 88                   21578             ESP           12   4_10_6
# 42                   28836             RUS            2    4_9_3
# 82            1      21707             USA                 3_8_4
# 78                   36307             FRA           29  4_10_15
# 23                   26310             JPN               4_13_11
# 52            9      26227             JPN                4_10_4
# 4                    29969             FRA                 3_8_9
# 81                    2508             SUI            8    3_9_5
# 15            3      36373             AUS                3_13_9
# 73                    6083             FRA                 3_8_4
# 49           18      21623             FRA                5_10_4
# 59                    9525             FRA           14   4_10_4
# 27            6      27419             GER                 5_6_4
# 38                   28518             SRB                4_12_4
# 47           15      20017             FRA               4_13_11
# 39           27      26197             FRA                 3_8_2
# 46                    7774             FRA               3_13_12
# 70                   26348             AUT            4   5_10_4
# 89            5      11493             FRA                 3_7_3
# 57                   28836             RUS            2   3_12_3
#
#                  court_name  court_id  num_sets_completed       match_type  \
# 40  Court Philippe CHATRIER         1                   1  Women's Singles
# 53  Court Philippe CHATRIER         1                   2  Women's Singles
# 1     Court Suzanne LENGLEN         2                   1  Women's Singles
# 83    Court Suzanne LENGLEN         2                   2  Women's Singles
# 22    Court Suzanne LENGLEN         2                   1  Women's Singles
# 84    Court Simonne MATHIEU         3                   1  Women's Singles
# 2   Court Philippe CHATRIER         1                   1  Women's Singles
# 65    Court Suzanne LENGLEN         2                   2  Women's Singles
# 28    Court Simonne MATHIEU         3                   2  Women's Singles
# 45  Court Philippe CHATRIER         1                   1  Women's Singles
# 8   Court Philippe CHATRIER         1                   1  Women's Singles
# 85    Court Suzanne LENGLEN         2                   1  Women's Singles
# 76  Court Philippe CHATRIER         1                   1  Women's Singles
# 11    Court Simonne MATHIEU         3                   2  Women's Singles
# 61    Court Suzanne LENGLEN         2                   1  Women's Singles
# 33    Court Simonne MATHIEU         3                   2  Women's Singles
# 37  Court Philippe CHATRIER         1                   1  Women's Singles
# 90    Court Simonne MATHIEU         3                   2  Women's Singles
# 68  Court Philippe CHATRIER         1                   1  Women's Singles
# 5     Court Suzanne LENGLEN         2                   1  Women's Singles
# 86    Court Suzanne LENGLEN         2                   1  Women's Singles
# 7     Court Simonne MATHIEU         3                   1  Women's Singles
# 75  Court Philippe CHATRIER         1                   2  Women's Singles
# 32    Court Simonne MATHIEU         3                   1  Women's Singles
# 67    Court Suzanne LENGLEN         2                   1  Women's Singles
# 13    Court Simonne MATHIEU         3                   1  Women's Singles
# 51    Court Suzanne LENGLEN         2                   1  Women's Singles
# 43  Court Philippe CHATRIER         1                   1  Women's Singles
# 19  Court Philippe CHATRIER         1                   2  Women's Singles
# 54    Court Suzanne LENGLEN         2                   2  Women's Singles
# 25    Court Suzanne LENGLEN         2                   1  Women's Singles
# 55    Court Simonne MATHIEU         3                   2  Women's Singles
# 21  Court Philippe CHATRIER         1                   1  Women's Singles
# 87    Court Suzanne LENGLEN         2                   2  Women's Singles
# 66    Court Simonne MATHIEU         3                   1  Women's Singles
# 69    Court Simonne MATHIEU         3                   1  Women's Singles
# 62  Court Philippe CHATRIER         1                   1  Women's Singles
# 50  Court Philippe CHATRIER         1                   1  Women's Singles
# 71    Court Suzanne LENGLEN         2                   3  Women's Singles
# 29  Court Philippe CHATRIER         1                   2  Women's Singles
# 36    Court Simonne MATHIEU         3                   2  Women's Singles
# 9     Court Suzanne LENGLEN         2                   2  Women's Singles
# 0     Court Suzanne LENGLEN         2                   1  Women's Singles
# 20    Court Simonne MATHIEU         3                   1  Women's Singles
# 56    Court Simonne MATHIEU         3                   1  Women's Singles
# 41  Court Philippe CHATRIER         1                   2  Women's Singles
# 58  Court Philippe CHATRIER         1                   2    Men's Singles
# 24    Court Suzanne LENGLEN         2                   3    Men's Singles
# 80  Court Philippe CHATRIER         1                   3    Men's Singles
# 18    Court Suzanne LENGLEN         2                   2    Men's Singles
# 3   Court Philippe CHATRIER         1                   2    Men's Singles
# 17    Court Simonne MATHIEU         3                   2    Men's Singles
# 79  Court Philippe CHATRIER         1                   3    Men's Singles
# 34    Court Suzanne LENGLEN         2                   3    Men's Singles
# 60    Court Suzanne LENGLEN         2                   2    Men's Singles
# 30    Court Simonne MATHIEU         3                   2    Men's Singles
# 74  Court Philippe CHATRIER         1                   2    Men's Singles
# 16    Court Simonne MATHIEU         3                   1    Men's Singles
# 91    Court Suzanne LENGLEN         2                   3    Men's Singles
# 14  Court Philippe CHATRIER         1                   3    Men's Singles
# 72    Court Simonne MATHIEU         3                   2    Men's Singles
# 44    Court Suzanne LENGLEN         2                   3    Men's Singles
# 63    Court Suzanne LENGLEN         2                   2    Men's Singles
# 10    Court Simonne MATHIEU         3                   2    Men's Singles
# 77  Court Philippe CHATRIER         1                   3    Men's Singles
# 31  Court Philippe CHATRIER         1                   2    Men's Singles
# 48    Court Simonne MATHIEU         3                   4    Men's Singles
# 35    Court Suzanne LENGLEN         2                   3    Men's Singles
# 6     Court Suzanne LENGLEN         2                   2    Men's Singles
# 26  Court Philippe CHATRIER         1                   4    Men's Singles
# 64    Court Simonne MATHIEU         3                   3    Men's Singles
# 12    Court Suzanne LENGLEN         2                   3    Men's Singles
# 88    Court Simonne MATHIEU         3                   4    Men's Singles
# 42  Court Philippe CHATRIER         1                   3    Men's Singles
# 82  Court Philippe CHATRIER         1                   2    Men's Singles
# 78    Court Simonne MATHIEU         3                   3    Men's Singles
# 23    Court Suzanne LENGLEN         2                   3    Men's Singles
# 52    Court Simonne MATHIEU         3                   3    Men's Singles
# 4     Court Simonne MATHIEU         3                   2    Men's Singles
# 81  Court Philippe CHATRIER         1                   3    Men's Singles
# 15  Court Philippe CHATRIER         1                   2    Men's Singles
# 73    Court Suzanne LENGLEN         2                   2    Men's Singles
# 49    Court Suzanne LENGLEN         2                   4    Men's Singles
# 59    Court Suzanne LENGLEN         2                   3    Men's Singles
# 27    Court Suzanne LENGLEN         2                   4    Men's Singles
# 38    Court Simonne MATHIEU         3                   4    Men's Singles
# 47    Court Simonne MATHIEU         3                   4    Men's Singles
# 39    Court Suzanne LENGLEN         2                   2    Men's Singles
# 46    Court Simonne MATHIEU         3                   3    Men's Singles
# 70  Court Philippe CHATRIER         1                   4    Men's Singles
# 89  Court Philippe CHATRIER         1                   2    Men's Singles
# 57  Court Philippe CHATRIER         1                   2    Men's Singles
#
#    match_status                                filename
# 40            I  wta_year_2021_SD012_tracking_data.json
# 53            I  wta_year_2021_SD013_tracking_data.json
# 1             I  wta_year_2021_SD014_tracking_data.json
# 83            I  wta_year_2021_SD015_tracking_data.json
# 22            R  wta_year_2021_SD017_tracking_data.json
# 84            I  wta_year_2021_SD018_tracking_data.json
# 2             I  wta_year_2021_SD019_tracking_data.json
# 65            I  wta_year_2021_SD020_tracking_data.json
# 28            I  wta_year_2021_SD021_tracking_data.json
# 45            I  wta_year_2021_SD023_tracking_data.json
# 8             I  wta_year_2021_SD024_tracking_data.json
# 85            I  wta_year_2021_SD025_tracking_data.json
# 76            I  wta_year_2021_SD026_tracking_data.json
# 11            I  wta_year_2021_SD027_tracking_data.json
# 61            I  wta_year_2021_SD030_tracking_data.json
# 33            I  wta_year_2021_SD031_tracking_data.json
# 37            R  wta_year_2021_SD032_tracking_data.json
# 90            I  wta_year_2021_SD035_tracking_data.json
# 68            I  wta_year_2021_SD036_tracking_data.json
# 5             I  wta_year_2021_SD039_tracking_data.json
# 86            I  wta_year_2021_SD046_tracking_data.json
# 7             I  wta_year_2021_SD047_tracking_data.json
# 75            I  wta_year_2021_SD048_tracking_data.json
# 32            I  wta_year_2021_SD052_tracking_data.json
# 67            I  wta_year_2021_SD055_tracking_data.json
# 13            I  wta_year_2021_SD059_tracking_data.json
# 51            I  wta_year_2021_SD060_tracking_data.json
# 43            I  wta_year_2021_SD061_tracking_data.json
# 19            I  wta_year_2021_SD064_tracking_data.json
# 54            I  wta_year_2021_SD070_tracking_data.json
# 25            I  wta_year_2021_SD072_tracking_data.json
# 55            I  wta_year_2021_SD073_tracking_data.json
# 21            I  wta_year_2021_SD079_tracking_data.json
# 87            I  wta_year_2021_SD080_tracking_data.json
# 66            I  wta_year_2021_SD088_tracking_data.json
# 69            I  wta_year_2021_SD093_tracking_data.json
# 62            I  wta_year_2021_SD095_tracking_data.json
# 50            I  wta_year_2021_SD096_tracking_data.json
# 71            C  wta_year_2021_SD103_tracking_data.json
# 29            I  wta_year_2021_SD104_tracking_data.json
# 36            I  wta_year_2021_SD107_tracking_data.json
# 9             C  wta_year_2021_SD111_tracking_data.json
# 0             I  wta_year_2021_SD121_tracking_data.json
# 20            I  wta_year_2021_SD122_tracking_data.json
# 56            I  wta_year_2021_SD125_tracking_data.json
# 41            C  wta_year_2021_SD127_tracking_data.json
# 58            I      year_2021_SM012_tracking_data.json
# 24            I      year_2021_SM013_tracking_data.json
# 80            C      year_2021_SM014_tracking_data.json
# 18            I      year_2021_SM015_tracking_data.json
# 3             I      year_2021_SM016_tracking_data.json
# 17            I      year_2021_SM018_tracking_data.json
# 79            I      year_2021_SM019_tracking_data.json
# 34            C      year_2021_SM020_tracking_data.json
# 60            I      year_2021_SM022_tracking_data.json
# 30            I      year_2021_SM023_tracking_data.json
# 74            I      year_2021_SM024_tracking_data.json
# 16            R      year_2021_SM025_tracking_data.json
# 91            C      year_2021_SM027_tracking_data.json
# 14            I      year_2021_SM028_tracking_data.json
# 72            I      year_2021_SM029_tracking_data.json
# 44            C      year_2021_SM031_tracking_data.json
# 63            I      year_2021_SM032_tracking_data.json
# 10            I      year_2021_SM036_tracking_data.json
# 77            I      year_2021_SM039_tracking_data.json
# 31            I      year_2021_SM040_tracking_data.json
# 48            C      year_2021_SM042_tracking_data.json
# 35            I      year_2021_SM043_tracking_data.json
# 6             I      year_2021_SM048_tracking_data.json
# 26            I      year_2021_SM050_tracking_data.json
# 64            I      year_2021_SM051_tracking_data.json
# 12            C      year_2021_SM056_tracking_data.json
# 88            C      year_2021_SM059_tracking_data.json
# 42            I      year_2021_SM063_tracking_data.json
# 82            I      year_2021_SM064_tracking_data.json
# 78            I      year_2021_SM067_tracking_data.json
# 23            I      year_2021_SM070_tracking_data.json
# 52            I      year_2021_SM072_tracking_data.json
# 4             I      year_2021_SM078_tracking_data.json
# 81            C      year_2021_SM079_tracking_data.json
# 15            I      year_2021_SM080_tracking_data.json
# 73            I      year_2021_SM081_tracking_data.json
# 49            I      year_2021_SM084_tracking_data.json
# 59            I      year_2021_SM087_tracking_data.json
# 27            I      year_2021_SM096_tracking_data.json
# 38            C      year_2021_SM098_tracking_data.json
# 47            C      year_2021_SM104_tracking_data.json
# 39            I      year_2021_SM108_tracking_data.json
# 46            C      year_2021_SM109_tracking_data.json
# 70            I      year_2021_SM111_tracking_data.json
# 89            I      year_2021_SM112_tracking_data.json
# 57            I      year_2021_SM127_tracking_data.json

# %%
rg_2021_data_frame[rg_2021_data_frame['match_id'] == 'year_2021_SM112_tracking_data.json']
# Out:
#     point_ID  set_num  game_num  point_num  serve_num server_id returner_id  \
# 0    1_1_1_1      1.0       1.0        1.0        1.0     11493       35398
# 1    1_1_2_1      1.0       1.0        2.0        1.0     11493       35398
# 2    1_1_3_1      1.0       1.0        3.0        1.0     11493       35398
# 3    1_1_4_1      1.0       1.0        4.0        1.0     11493       35398
# 4    1_1_4_2      1.0       1.0        4.0        2.0     11493       35398
# ..       ...      ...       ...        ...        ...       ...         ...
# 238  3_7_1_1      3.0       7.0        1.0        1.0     11493       35398
# 239  3_7_2_1      3.0       7.0        2.0        1.0     11493       35398
# 240  3_7_2_2      3.0       7.0        2.0        2.0     11493       35398
# 241  3_7_3_1      3.0       7.0        3.0        1.0     11493       35398
# 242  3_7_3_2      3.0       7.0        3.0        2.0     11493       35398
#
#     point_winner_id  court_side serve_speed_kph  ... returner_score player1  \
# 0             35398  DeuceCourt         193 KPH  ...            0.0   11493
# 1             11493     AdCourt         203 KPH  ...            1.0   11493
# 2             11493  DeuceCourt         212 KPH  ...            1.0   11493
# 3             35398     AdCourt       210.4 KPH  ...            1.0   11493
# 4             35398     AdCourt      135.84 KPH  ...            1.0   11493
# ..              ...         ...             ...  ...            ...     ...
# 238           35398  DeuceCourt         177 KPH  ...            0.0   11493
# 239           35398     AdCourt      204.94 KPH  ...            1.0   11493
# 240           35398     AdCourt      159.79 KPH  ...            1.0   11493
# 241           35398  DeuceCourt      193.28 KPH  ...            2.0   11493
# 242           35398  DeuceCourt         166 KPH  ...            2.0   11493
#
#     player2 p1_cum_games  p2_cum_games  p1_cum_sets  p2_cum_sets  \
# 0     35398          0.0           0.0          0.0          0.0
# 1     35398          0.0           0.0          0.0          0.0
# 2     35398          0.0           0.0          0.0          0.0
# 3     35398          0.0           0.0          0.0          0.0
# 4     35398          0.0           0.0          0.0          0.0
# ..      ...          ...           ...          ...          ...
# 238   35398          1.0           5.0          0.0          2.0
# 239   35398          1.0           5.0          0.0          2.0
# 240   35398          1.0           5.0          0.0          2.0
# 241   35398          1.0           5.0          0.0          2.0
# 242   35398          1.0           5.0          0.0          2.0
#
#                                match_id  year is_wta
# 0    year_2021_SM112_tracking_data.json  2021  False
# 1    year_2021_SM112_tracking_data.json  2021  False
# 2    year_2021_SM112_tracking_data.json  2021  False
# 3    year_2021_SM112_tracking_data.json  2021  False
# 4    year_2021_SM112_tracking_data.json  2021  False
# ..                                  ...   ...    ...
# 238  year_2021_SM112_tracking_data.json  2021  False
# 239  year_2021_SM112_tracking_data.json  2021  False
# 240  year_2021_SM112_tracking_data.json  2021  False
# 241  year_2021_SM112_tracking_data.json  2021  False
# 242  year_2021_SM112_tracking_data.json  2021  False
#
# [243 rows x 71 columns]

# %%
rg_2021_data_frame.head()
# Out:
#   point_ID  set_num  game_num  point_num  serve_num server_id returner_id  \
# 0  1_1_1_1      1.0       1.0        1.0        1.0     23726        9086
# 1  1_1_2_1      1.0       1.0        2.0        1.0     23726        9086
# 2  1_1_2_2      1.0       1.0        2.0        2.0     23726        9086
# 3  1_1_3_1      1.0       1.0        3.0        1.0     23726        9086
# 4  1_1_3_2      1.0       1.0        3.0        2.0     23726        9086
#
#   point_winner_id  court_side serve_speed_kph  ... returner_score player1  \
# 0           23726  DeuceCourt         155 KPH  ...            0.0   23726
# 1           23726     AdCourt      159.76 KPH  ...            0.0   23726
# 2           23726     AdCourt         128 KPH  ...            0.0   23726
# 3           23726  DeuceCourt      168.31 KPH  ...            0.0   23726
# 4           23726  DeuceCourt         133 KPH  ...            0.0   23726
#
#   player2 p1_cum_games  p2_cum_games  p1_cum_sets  p2_cum_sets  \
# 0    9086          0.0           0.0          0.0          0.0
# 1    9086          0.0           0.0          0.0          0.0
# 2    9086          0.0           0.0          0.0          0.0
# 3    9086          0.0           0.0          0.0          0.0
# 4    9086          0.0           0.0          0.0          0.0
#
#                                  match_id  year is_wta
# 0  wta_year_2021_SD121_tracking_data.json  2021   True
# 1  wta_year_2021_SD121_tracking_data.json  2021   True
# 2  wta_year_2021_SD121_tracking_data.json  2021   True
# 3  wta_year_2021_SD121_tracking_data.json  2021   True
# 4  wta_year_2021_SD121_tracking_data.json  2021   True
#
# [5 rows x 77 columns]
