# %% [markdown]
# ### Description
#
# This script will scrape `official` player height and weight data from the ATP website

# %%
import pandas as pd
pd.set_option('display.max_rows', 100)

import requests

from bs4 import BeautifulSoup
from dateutil.parser import parse

# %%
def collect_atp_official_player_data(player_profile_url):
    
    # Connect to player page
    player_page = requests.get(link).text

    # Get (entire) HTML File
    player_html = BeautifulSoup(player_page, 'lxml')
    
    # Player Name
    player_first_name_html = player_html.find("div", attrs={"class": "first-name"})
    player_first_name = player_first_name_html.text.strip()

    player_surname_html = player_html.find("div", attrs={"class": "last-name"})
    player_surname = player_surname_html.text.strip()

    player_name = player_first_name + ' ' + player_surname
    
    # -- Get player weight in imperial units
    try:
        player_weight_lbs_html = player_html.find("span", attrs={"class": "table-weight-lbs"})
        player_weight_lbs = player_weight_lbs_html.text.strip()
    except (KeyError, AttributeError):
        player_weight_lbs = None
        
    
    # -- Get player weight in kg
    try:
        player_weight_kg_html = player_html.find("span", attrs={"class": "table-weight-kg-wrapper"})
        player_weight_kg = player_weight_kg_html.text.lower().replace('(','').replace('kg)','')
    except (KeyError, AttributeError):
        player_weight_kg = None
         
    
    
    # -- Get player height in feet & inches
    try:
        player_height_imp_html = player_html.find("span", attrs={"class": "table-height-ft"})
        player_height_imp = player_height_imp_html.text
    except (KeyError, AttributeError):
        player_height_imp = None
         
    
    # -- Get player height in cm
    try:
        player_height_cm_html = player_html.find("span", attrs={"class": "table-height-cm-wrapper"})
        player_height_cm = player_height_cm_html.text.lower().replace('(','').replace('cm)','')
    except (KeyError, AttributeError):
        player_height_cm = None
        
        # -- Get player handedness
    for item in player_html.find_all("div", attrs={"class": "table-value"}):
        if 'handed' in item.text.lower().strip():
            player_handedness = item.text.lower().strip().split(',')[0]


    
    player_dictionary = {
        'player_name': player_name,
        'player_height_inches': player_height_imp,
        'player_height_cm': player_height_cm,
        'player_weight_lbs': player_weight_lbs,
        'player_weight_kg': player_weight_kg,
        'player_handedness': player_handedness
    }

    return player_dictionary

# %%
# Loop through to collect all data
atp_link_data = pd.read_csv('./data/raw_data/atp_official_site_urls.csv')
atp_link_data
atp_data_list = []
for link in atp_link_data['bio_link']:
    if 'overview' in link:
        print(link)
        atp_data_list.append( collect_atp_official_player_data(link) )
    
atp_height_weight_data = pd.DataFrame(atp_data_list)
# Out:
# https://www.atptour.com/en/players/novak-djokovic/d643/overview
# https://www.atptour.com/en/players/rafael-nadal/n409/overview
# https://www.atptour.com/en/players/dominic-thiem/tb69/overview
# https://www.atptour.com/en/players/roger-federer/f324/overview
# https://www.atptour.com/en/players/daniil-medvedev/mm58/overview
# https://www.atptour.com/en/players/stefanos-tsitsipas/te51/overview
# https://www.atptour.com/en/players/alexander-zverev/z355/overview
# https://www.atptour.com/en/players/matteo-berrettini/bk40/overview
# https://www.atptour.com/en/players/gael-monfils/mc65/overview
# https://www.atptour.com/en/players/david-goffin/gb88/overview
# https://www.atptour.com/en/players/fabio-fognini/f510/overview
# https://www.atptour.com/en/players/roberto-bautista-agut/bd06/overview
# https://www.atptour.com/en/players/diego-schwartzman/sm37/overview
# 83             Marton Fucsovics                 6'2"              188
# 84                 Dennis Novak                 6'0"              183
# 85            Stefano Travaglia                 6'1"              185
# 86                Yuichi Sugita                 5'9"              175
# 87                Andreas Seppi                 6'3"              191
# 88                Nicolas Jarry                 6'6"              198
# 89            Yasutaka Uchiyama                 6'0"              183
# 90            Mikhail Kukushkin                 6'0"              183
# 91              Dominik Koepfer                5'11"              180
# 92               Vasek Pospisil                 6'4"              193
# 93                 Hugo Dellien                5'11"              180
# 94             Gregoire Barrere                 6'0"              183
# 95                Andrej Martin                 6'0"              183
# 96  Alejandro Davidovich Fokina                 6'0"              183
# 97                 Lloyd Harris                 6'4"              193
# 98      Roberto Carballes Baena                 6'0"              183
# 99             Salvatore Caruso                 6'1"              185
#
#    player_weight_lbs player_weight_kg player_handedness
# 0                170               77      right-handed
# 1                187               85       left-handed
# 2                174               79      right-handed
# 3                187               85      right-handed
# 4                182               83      right-handed
# 5                196               89      right-handed
# 6                198               90      right-handed
# 7                209               95      right-handed
# 8                187               85      right-handed
# 9                154               70      right-handed
# 10               174               79      right-handed
# 11               165               75      right-handed
# 12               141               64      right-handed
# 13               154               70      right-handed
# 14               192               87      right-handed
# 15               165               75       left-handed
# 16               179               81      right-handed
# 17               187               85      right-handed
# 18               179               81      right-handed
# 19               194               88      right-handed
# 20               238              108      right-handed
# 21               176               80      right-handed
# 22               183               83      right-handed
# 23               190               86      right-handed
# 24               172               78      right-handed
# 25               152               69      right-handed
# 26               174               79      right-handed
# 27               165               75      right-handed
# 28               179               81      right-handed
# 29               216               98      right-handed
# 30               161               73      right-handed
# 31               165               75      right-handed
# 32               187               85      right-handed
# 33               202               92      right-handed
# 34               174               79       left-handed
# 35               170               77      right-handed
# 36               196               89      right-handed
# 37               174               79       left-handed
# 38               225              102      right-handed
# 39               187               85      right-handed
# 40               168               76       left-handed
# 41               162               73       left-handed
# 42               174               79      right-handed
# 43               183               83      right-handed
# 44               209               95      right-handed
# 45               168               76      right-handed
# 46               165               75      right-handed
# 47               141               64       left-handed
# 48               205               93      right-handed
# 49               174               79      right-handed
# 50               176               80      right-handed
# 51               198               90       left-handed
# 52               176               80      right-handed
# 53               154               70      right-handed
# 54               195               88      right-handed
# 55               194               88       left-handed
# 56               180               82      right-handed
# 57               185               84      right-handed
# 58               165               75      right-handed
# 59               173               78      right-handed
# 60               161               73      right-handed
# 61               154               70      right-handed
# 62               190               86      right-handed
# 63               181               82      right-handed
# 64               207               94       left-handed
# 65               163               74      right-handed
# 66               152               69      right-handed
# 67               165               75      right-handed
# 68               190               86      right-handed
# 69               159               72      right-handed
# 70               165               75      right-handed
# 71               170               77      right-handed
# 72               167               76      right-handed
# 73               154               70      right-handed
# 74               156               71       left-handed
# 75               172               78      right-handed
# 76               181               82       left-handed
# 77               198               90       left-handed
# 78               170               77      right-handed
# 79               181               82      right-handed
# 80               190               86      right-handed
# 81               172               78       left-handed
# 82               181               82      right-handed
# 83               181               82      right-handed
# 84               176               80      right-handed
# 85               176               80      right-handed
# 86               159               72      right-handed
# 87               172               78      right-handed
# 88               198               90      right-handed
# 89               172               78      right-handed
# 90               159               72      right-handed
# 91               175               79       left-handed
# 92               194               88      right-handed
# 93               165               75      right-handed
# 94               176               80      right-handed
# 95               183               83      right-handed
# 96               176               80      right-handed
# 97               176               80      right-handed
# 98               170               77      right-handed
# 99               176               80      right-handed

# %%
atp_height_weight_data.to_csv('./data/processed_data/official_atp_height_2020.csv', index = False)

# %% [markdown]
# ### Appendix: Prototype Code

# %%
link = 'https://www.atptour.com/en/players/joao-domingues/d985/overview'
collect_atp_official_player_data(link)
# Out:
# {'player_name': 'Joao Domingues',
#  'player_height_inches': None,
#  'player_height_cm': None,
#  'player_weight_lbs': '154',
#  'player_weight_kg': '70',
#  'player_handedness': 'right-handed'}

# %%
link = 'https://www.atptour.com/en/players/benoit-paire/pd31/overview'

# Connect to player page
player_page = requests.get(link).text

# Get (entire) HTML File
player_html = BeautifulSoup(player_page, 'lxml')
player_html
# Out:
# <!DOCTYPE html>
# <!-- START : /modules/global/head --><!--[if lt IE 7]>
#     <html class="no-js lt-ie10 lt-ie9 lt-ie8 lt-ie7 ">
# <![endif]--><!--[if IE 7]>
#     <html class="no-js lt-ie10 lt-ie9 lt-ie8 ">
# <![endif]--><!--[if IE 8]>
#     <html class="no-js lt-ie10 lt-ie9 ">
# <![endif]--><!--[if IE 9]>
#     <html class="no-js lt-ie10 ">
# <![endif]--><!--[if gt IE 9]><!--><html class="no-js" translate="no">
# <!--<![endif]-->
# <head>
# <!-- disable auto format for telephone numbers -->
# <meta content="telephone=no" name="format-detection"/>
# <title>
# 	Benoit Paire | Overview | ATP Tour | Tennis
# </title>
# <meta content="initial-scale=1.0, width=768, user-scalable=yes, minimum-scale=1.0, maximum-scale=1.25" name="viewport"/>
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="" name="keywords"/>
# <meta content="Official tennis player profile of Benoit Paire on the ATP Tour. Featuring news, bio, rankings, playing activity, coach, stats, win-loss, points breakdown, videos, and more." name="description"/>
# <meta content="SKYPE_TOOLBAR_PARSER_COMPATIBLE" name="SKYPE_TOOLBAR"/>
# <meta content="https://www.atptour.com/-/media/tennis/players/head-shot/2018/paire_head_ao18.png" name="thumbnail"/>
# <meta content="notranslate" name="google"/>
# <meta content="Benoit Paire" property="pageTransitionTitle"/>
# <meta content="132901818553" property="fb:app_id"/>
# <meta content="24410993700" property="fb:pages"/>
# <meta content="en" property="og:locale"/>
# <meta content="article" property="og:type"/>
# <meta property="og:title"/>
# <meta content="Official tennis player profile of Benoit Paire on the ATP Tour. Featuring news, bio, rankings, playing activity, coach, stats, win-loss, points breakdown, videos, and more." property="og:description"/>
# <meta content="https://www.atptour.com/-/media/tennis/players/head-shot/2018/paire_head_ao18.png" property="og:image"/>
# <meta content="www.atptour.com/en/players/benoit-paire/pd31/overview" property="og:url"/>
# <meta content="ATP Tour" property="og:site_name"/>
# <meta content="summary" name="twitter:card"/>
# <meta name="twitter:title"/>
# <meta content="@atpworldtour" name="twitter:creator"/>
# <meta content="Official tennis player profile of Benoit Paire on the ATP Tour. Featuring news, bio, rankings, playing activity, coach, stats, win-loss, points breakdown, videos, and more." name="twitter:description"/>
# <meta content="https://www.atptour.com/-/media/tennis/players/head-shot/2018/paire_head_ao18.png" name="twitter:image"/>
# <!-- Google Ad Manager Header -->
# <script async="" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script>
# <script>
#     window.googletag = window.googletag || { cmd: [] };
#
#
#     googletag.cmd.push(function () {
#
#
#                 googletag.defineSlot('/21840952109/Body-Slot-1', [728,90], 'div-gpt-ad-Body-Slot-1')
#                     .defineSizeMapping(googletag.sizeMapping().addSize([728, 0],  [728,90]).addSize([0, 0], [320,50] ).build())
#                     .setCollapseEmptyDiv(true)
#                     .setTargeting('Position', ['ATP Body Slot 1'])
#                     .addService(googletag.pubads());
#
#
#
#                 googletag.defineSlot('/21840952109/Footer', [728,90], 'div-gpt-ad-Footer')
#                     .defineSizeMapping(googletag.sizeMapping().addSize([728, 0],  [728,90]).addSize([0, 0], [320,50] ).build())
#                     .setCollapseEmptyDiv(true)
#                     .setTargeting('Position', ['ATP Footer'])
#                     .addService(googletag.pubads());
#
#
#
#                 googletag.defineSlot('/21840952109/Right-Rail-News', [300,250], 'div-gpt-ad-Right-Rail-News')
#                     .defineSizeMapping(googletag.sizeMapping().addSize([728, 0],  [300,250]).addSize([0, 0], []).build())
#                     .setCollapseEmptyDiv(true)
#                     .setTargeting('Position', ['ATP Right Rail News'])
#                     .addService(googletag.pubads());
#
#
#
#                 googletag.defineSlot('/21840952109/Right-Rail-Scores', [300,250], 'div-gpt-ad-Right-Rail-Scores')
#                     .defineSizeMapping(googletag.sizeMapping().addSize([728, 0],  [300,250]).addSize([0, 0], []).build())
#                     .setCollapseEmptyDiv(true)
#                     .setTargeting('Position', ['ATP Right Rail Scores'])
#                     .addService(googletag.pubads());
#
#
#
#     googletag.pubads().enableSingleRequest();
#     googletag.pubads().collapseEmptyDivs();
#
#         googletag.pubads().
#             setTargeting('Language',['English']).
#             setTargeting('Site',['ATP Tour']).
#             setTargeting('Player',['PD31']).
#             setTargeting('Device',['Desktop']).
#             setTargeting('Site-Section',['ATP Players']);
#
#     googletag.enableServices();
#     });
# </script>
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-L3J1QW9KG6"></script>
# <script>
#         window.dataLayer = window.dataLayer || [];
#         function gtag() { dataLayer.push(arguments); }
#         gtag('js', new Date());
#         gtag('config', 'G-L3J1QW9KG6');
#     </script>
# <!-- Google Analytics -->
# <script>
# 	(function (i, s, o, g, r, a, m) {
# 	    i['GoogleAnalyticsObject'] = r; i[r] = i[r] || function () {
# 	        (i[r].q = i[r].q || []).push(arguments)
# 	    }, i[r].l = 1 * new Date(); a = s.createElement(o),
# 	        m = s.getElementsByTagName(o)[0]; a.async = 1; a.src = g; m.parentNode.insertBefore(a, m)
# 	})(window, document, 'script', '//www.google-analytics.com/analytics.js', 'ga');
#
# 	ga('create', 'UA-4616629-30', 'auto');
# 	ga('create', 'UA-18575440-1', 'auto', 'TTVTracker');
#
#
#     ga('send', 'pageview');
# 	ga('TTVTracker.send', 'pageview');
# </script>
# <script>
#         var cacheBuster = 637334422002220049
#     </script>
# <link href="/Assets/atpwt/styles/desktop.css?bust=637334422002220049" rel="stylesheet"/>
# <script src="/assets/atpwt/scripts/vendor/require.js"></script>
# <script src="/assets/atpwt/scripts/desktop.js?bust=637334422002220049"></script>
# <link href="/assets/atpwt/images/global/favicon.ico" rel="icon"/>
# <script>
#         var _comscore = _comscore || [];
#         _comscore.push(
#             { c1: "2", c2: "17223859" }
#         );
#         (function () { var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true; s.src = (document.location.protocol == "https:" ? "https://sb" : "http://sb") + ".scorecardresearch.com/beacon.js"; el.parentNode.insertBefore(s, el); }
#         )();
#     </script>
# <noscript>
# <img src="https://b.scorecardresearch.com/p?c1=2&amp;c2=17223859&amp;cv=2.0&amp;cj=1"/>
# </noscript>
# <!-- RUM's Header 1.3.3.0 -->
# <!-- Facebook Pixel Code -->
# <script>
#         !(function (f, b, e, v, n, t, s) {
#             if (f.fbq) return;
#             n = f.fbq = function () {
#                 n.callMethod ? n.callMethod.apply(n, arguments) : n.queue.push(arguments);
#             };
#             if (!f._fbq) f._fbq = n;
#             n.push = n;
#             n.loaded = !0;
#             n.version = "2.0";
#             n.queue = [];
#             t = b.createElement(e);
#             t.async = !0;
#             t.src = v;
#             s = b.getElementsByTagName(e)[0];
#             s.parentNode.insertBefore(t, s);
#         })(
#             window,
#             document,
#             "script",
#             "https://connect.facebook.net/en_US/fbevents.js"
#         );
#         fbq("init", "360708664482081");
#         fbq("track", "PageView");
#     </script>
# <noscript>
# <img height="1" src="https://www.facebook.com/tr?id=360708664482081&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/>
# </noscript>
# <!-- DO NOT MODIFY -->
# <script>
#         fbq("track", "Purchase", {
#             value: "VALUE-OF-THE-ORDER",
#             currency: "GBP"
#         });
#     </script>
# <!-- End Facebook Pixel Code -->
# </head>
# <!-- END : /modules/global/head -->
# <body class="is-desktop" data-google-analytics-id="UA-4616629-30" data-signalr-url="https://push.atptour.com/signalr/signalr">
# <!-- START : /modules/global/header -->
# <div class="header empty-subnav" id="header">
# <div class="sub-header">
# <div class="container">
# <div class="sub-header-sponsor-logo">
# <img alt="Technology Service Partner" src="/-/media/images/sponsored-headers/infosys_atp_tsp_neg_16_2.svg?iar=0&amp;hash=41264F24B8B516D003870174750E19DD"/>
# </div>
# <ul class="sub-header-links">
# <li class="atp-tour-app-link">
# <a class="external" data-ga-action="Click" data-ga-category="Outbound" data-ga-label="ATP Tour App" href="/en/apps">
#                         ATP Tour App
#                         </a>
# </li>
# <li class="atp-challenger-tour-link">
# <a class="external" data-ga-action="Click" data-ga-category="Outbound" data-ga-label="ATP Challenger Tour" href="/en/atp-challenger-tour" target="_blank">
#                         ATP Challenger Tour
#                         </a>
# </li>
# <li class="atp-champions-tour-link">
# <a class="external" data-ga-action="Click" data-ga-category="Outbound" data-ga-label="ATP Champions Tour" href="http://www.atpchampionstour.com/" target="_blank">
#                         ATP Champions Tour
#                         </a>
# </li>
# <li class="login-link">
# <a data-ga-action="Click" data-ga-category="Main Navigation" data-ga-label="Register" href="https://www.atptour.com/en/newsletters/subscribe">
#                         Register
#                     </a>
# <span class="icon icon-myatp"></span>
# </li>
# <li class="sub-header-language-selector">
# <!-- START LANGUAGE SELECTOR-->
# <div class="language-selector" id="languageSelector">
# <div class="language-flag">
# <img alt="USA" src="/-/media/images/flags/gbr.svg?iar=0&amp;hash=B856B7F977A814CA494427BBE323E6F9"/>
# <span class="icon icon-arrow-down"></span>
# </div>
# <ul class="language-dropdown" id="languageDropdown">
# <li>
# <a class="languageLink" data-language-code="es">
#                                     Spanish <img alt="zh" height="32" src="/-/media/images/flags/esp.svg?h=32&amp;iar=0&amp;w=44&amp;hash=8551A726138A1EF828794408742F58C5" width="44"/>
# </a>
# </li>
# <li>
# <a class="languageLink" data-language-code="en">
#                                     English <img alt="USA" height="32" src="/-/media/images/flags/gbr.svg?h=32&amp;iar=0&amp;w=44&amp;hash=278C0EF514ED1A4C121847AA22897F4E" width="44"/>
# </a>
# </li>
# </ul>
# </div>
# <!-- END LANGUAGE SELECTOR-->
# </li>
# </ul>
# </div>
# </div>
# <script>
#     require(["modules/global/languageSwitcher"],
#         function (LanguageSwitcher) {
#             return new LanguageSwitcher({
#                 elementId : "#languageDropdown"
#             });
#         });
# </script>
# <div class="main-header" id="mainHeader">
# <div class="container atp-header-container">
# <div class="atp-menu" id="controlMenu">
# <div class="atp-menu-icon">
# <div class="atp-menu-icon-top"></div>
# <div class="atp-menu-icon-center"></div>
# <div class="atp-menu-icon-bottom"></div>
# </div>
# <div class="atp-menu-label">
#                 Menu
#             </div>
# </div>
# <h1 class="atp-logo">
# <a class="atp-logo-link" data-ga-action="Click" data-ga-category="Main Navigation" data-ga-label="
a>
# </li>
# <li class="atp-sub-nav-item">
# <a data-ga-action="Click" data-ga-category="Main Navigation" data-ga-label="Story of the Season" href="/en/news/story-of-the-season">Story of the Season</a>
# </li>
# <li class="atp-sub-nav-item">
# <a data-ga-action="Click" data-ga-category="Main Navigation" data-ga-label="ATP Heritage" href="/en/news/atp-heritage">ATP Heritage</a>
# </li>
# <li class="atp-sub-nav-item">
# <a data-ga-action="Click" data-ga-category="Main Navigation" data-ga-label="ATP Awards" href="/en/news/atp-awards">ATP Awards</a>
# </li>
# <li class="atp-sub-nav-item">
# <a data-ga-action="Click" data-ga-category="Main Navigation" data-ga-label="On The Road" href="/en/news/on-the-road">On The Road</a>
# </li>
# <li class="atp-sub-nav-item">
# <a data-ga-action="Click" data-ga-category="Main Navigation" data-ga-label="Tennis Radio" href="/en/news/tennis-radio">Tennis Radio</a>
# </li>
# <li class="atp-sub-nav-item">
# <a data-ga-action="Click" data-ga-category="Main Navigation" data-ga-label="ATP ACES For Charity" href="/en/corporate/atp-aces-for-charity">ATP ACES For Charity</a>
# </li>
# </ul></li> <li class="atp-nav-item more-item">
# <a data-ga-action="Click" data-ga-category="Main Navigation" data-ga-label="Video" href="/en/video">
#         Video
#     </a>
# <ul class="atp-sub-nav"> <li class="atp-sub-nav-item">
# <a data-ga-action="Click" data-ga-category="Main Navigation" data-ga-label="Landing" href="/en/video">Landing</a>
# </li>
# <li class="atp-sub-nav-item">
# <a data-ga-action="Click" data-ga-category="Main Navigation" data-ga-label="Latest" href="/en/video/video-search-results/all/all/all/all/all/all">Latest</a>
# </li>
# <li class="atp-sub-nav-item">
# <a data-ga-action="Click" data-ga-category="Main Navigation" data-ga-label="Hot Shots" href="/en/video/video-search-results/all/hot-shot/all/all/all/all">Hot Shots</a>
# </li>
# <li class="atp-sub-nav-item">
# <a data-ga-action="Click" data-ga-category="Main Navigation" data-ga-label="Highlights" href="/en/video/video-search-results/all/highlights/all/all/all/all">Highlights</a>
# </li>
# <li class="atp-sub-nav-item">
# <a data-ga-action="Click" data-ga-category="Main Navigation" data-ga-label="Interviews" href="/en/video/video-search-results/all/interviews/all/all/all/all">Interviews</a>
# </li>
# <li class="atp-sub-nav-item">
# <a data-ga-action="Click" data-ga-category="Main Navigation" data-ga-label="My Story" href="/en/video/video-search-results/all/my-story/all/all/all/all">My Story</a>
# </li>
# <li class="atp-sub-nav-item">
# <a data-ga-action="Click" data-ga-category="Main Navigation" data-ga-label="Uncovered" href="/en/video/video-search-results/all/uncovered/all/all/all/all">Uncovered</a>
# </li>
# <li class="atp-sub-nav-item">
# <a data-ga-action="Click" data-ga-category="Main Navigation" data-ga-label="Watch Live" href="/en/video/watch-live">Watch Live</a>
# </li>
# </ul></li><li class="atp-nav-item atp-more-link"><a href="#">More</a><ul class="atp-sub-nav"> <li class="atp-sub-nav-item">
# <a data-ga-action="Click" data-ga-category="Main Navigation" data-ga-label="Video" href="/en/video">Video</a>
# </li>
# </ul></li>
# </ul>
# </nav>
# <div class="atp-nav-icon">
# <div class="atp-shop-link">
# <span class="icon icon-tv"></span>
# <a class="watch-live-link" data-ga-action="Click" data-ga-category="Main Navigation" data-ga-label="Watch" href="https://www.atptour.com/en/tournaments/tv-schedule">
#                                     Watch
#                                 </a>
# </div>
# <div class="atp-shop-link">
# <span class="icon icon-radio-signal-both"></span>
# <a class="listen-link" data-ga-action="Click" data-ga-category="Main Navigation" data-ga-label="Listen" href="javascript:window.open('https://tunein.com/embed/player/s289729/?autoplay=true', 'ATP Tennis RAdio', 'width=350,height=100')">
#                                     Listen
#                                 </a>
# </div>
# <div class="atp-shop-link">
# <span class="icon icon-cart"></span>
# <a class="shop-link" data-ga-action="Click" data-ga-category="Main Navigation" data-ga-label="Shop" href="http://www.tennis-warehouse.com/?from=atp">
#                                     Shop
#                                 </a>
# </div>
# <div class="atp-search" id="controlSearch">
# <div class="atp-search-label"></div>
# <div class="atp-search-label-text">
#                              Search
#                         </div>
# </div>
# </div>
# </div>
# </div>
# <div class="atp-nav-sponsor">
# <a data-ga-action="Click" data-ga-category="Outbound" data-ga-label="Emirates Header Logo" href="http://www.emirates.com" target="_blank">
# <img alt="" class="atp-nav-sponsor-image" height="80" src="/-/media/images/sponsors/emirates-premier-partner-blackbox-horizontal/emirates-premier-partner-redbox-horizontal-2019.svg?h=80&amp;iar=0&amp;hash=8BB01839CC730557A6C2915EA360EE8B"/>
# </a>
# </div>
# </div>
# </div>
# <script>
#
#     const shopLinks = [].slice.call(document.querySelectorAll('.atp-shop-link'));
#     shopLinks.forEach(function (el) {
#         el.addEventListener('click',
#             function () {
#                 const link = el.querySelector('a');
#                 link.click();
#             });
#     });
#
#     require(["modules/global/fixedHeader"],
#         function (FixedHeader) {
#             return new FixedHeader({
#                 moreText : "More"
#             });
#         });
#
#     require(["modules/global/headerNav"],
#         function (HeaderNav) {
#             return HeaderNav.get();
#         });
# </script>
# <script id="tabletMenuTemplate" type="text/html">
#     <div id="navigation" class="navigation">
#         <div id="mainNav" class="main-nav">
#             <div class="nav-section">
#                 <span class="nav-section-title">Menu</span>
#                 <ul class="nav-list">
#                         <li data-sub-navigation-json="{
#   &quot;Title&quot;: &quot;Scores&quot;,
#   &quot;SponsorLink&quot;: &quot;&quot;,
#   &quot;SponsorLogo&quot;: &quot;&quot;,
#   &quot;AdvertLink&quot;: &quot;&quot;,
#   &quot;AdvertImage&quot;: &quot;&quot;,
#   &quot;AdvertSize&quot;: &quot;&quot;,
#   &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#   &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#   &quot;AnalyticsLabel&quot;: &quot;Scores&quot;,
#   &quot;MenuItems&quot;: [
#     {
#       &quot;Title&quot;: &quot;ATP Tour&quot;,
#       &quot;Link&quot;: &quot;/en/scores/current&quot;,
#       &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#       &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#       &quot;AnalyticsLabel&quot;: &quot;ATP Tour&quot;
#     },
#     {
#       &quot;Title&quot;: &quot;ATP Challenger Tour&quot;,
#       &quot;Link&quot;: &quot;/en/scores/current-challenger&quot;,
#       &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#       &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#       &quot;AnalyticsLabel&quot;: &quot;ATP Challenger Tour&quot;
#     },
#     {
#       &quot;Title&quot;: &quot;&quot;,
#       &quot;Link&quot;: &quot;/en/scores/current/&quot;,
#       &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#       &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#       &quot;AnalyticsLabel&quot;: &quot;&quot;
#     },
#     {
#       &quot;Title&quot;: &quot;Results Archive&quot;,
#       &quot;Link&quot;: &quot;/en/scores/results-archive&quot;,
#       &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#       &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#       &quot;AnalyticsLabel&quot;: &quot;Results Archive&quot;
#     },
#     {
#       &quot;Title&quot;: &quot;ATP Tour App&quot;,
#       &quot;Link&quot;: &quot;/en/apps&quot;,
#       &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#       &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#       &quot;AnalyticsLabel&quot;: &quot;ATP Tour App&quot;
#     }
#   ]
# }">
#             <a href="/en/scores" data-ga-label="Scores"
#                data-ga-category="Main Navigation"
#                data-ga-action="Click" class="nav-push">
#                 Scores
#             </a>
#     </li>
#     <li data-sub-navigation-json="{
#   &quot;Title&quot;: &quot;Stats&quot;,
#   &quot;SponsorLink&quot;: &quot;&quot;,
#   &quot;SponsorLogo&quot;: &quot;&quot;,
#   &quot;AdvertLink&quot;: &quot;&quot;,
#   &quot;AdvertImage&quot;: &quot;&quot;,
#   &quot;AdvertSize&quot;: &quot;&quot;,
#   &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#   &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#   &quot;AnalyticsLabel&quot;: &quot;Stats&quot;,
#   &quot;MenuItems&quot;: [
#     {
#       &quot;Title&quot;: &quot;Stats Home&quot;,
#       &quot;Link&quot;: &quot;/en/stats&quot;,
#       &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#       &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#       &quot;AnalyticsLabel&quot;: &quot;Stats Home&quot;
#     },
#     {
#       &quot;Title&quot;: &quot;Serve &amp; Return Tracker&quot;,
#       &quot;Link&quot;: &quot;/en/stats/player-tendencies&quot;,
#       &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#       &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#       &quot;AnalyticsLabel&quot;: &quot;Serve &amp; Return Tracker&quot;
#     },
#     {
#       &quot;Title&quot;: &quot;Stats Leaderboards&quot;,
#       &quot;Link&quot;: &quot;/en/stats/leaderboard&quot;,
#       &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#       &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#       &quot;AnalyticsLabel&quot;: &quot;Stats Leaderboards&quot;
#     },
#     {
#       &quot;Title&quot;: &quot;Year-end No. 1s&quot;,
#       &quot;Link&quot;: &quot;/en/stats/year-end-no1s&quot;,
#       &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#       &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#       &quot;AnalyticsLabel&quot;: &quot;Year-end No. 1s&quot;
#     },
#     {
#       &quot;Title&quot;: &quot;Individual Match Stats&quot;,
#       &quot;Link&quot;: &quot;/en/stats/service-games-won&quot;,
#       &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#       &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#       &quot;AnalyticsLabel&quot;: &quot;Individual Match Stats&quot;
#     }
#   ]
# }">
#             <a href="/en/stats" data-ga-label="Stats"
#                data-ga-category="Main Navigation"
#                data-ga-action="Click" class="nav-push">
#                 Stats
#             </a>
#     </li>
#     <li data-sub-navigation-json="{
#   &quot;Title&quot;: &quot;Rankings&quot;,
#   &quot;SponsorLink&quot;: &quot;&quot;,
#   &quot;SponsorLogo&quot;: &quot;&quot;,
#   &quot;AdvertLink&quot;: &quot;&quot;,
#   &quot;AdvertImage&quot;: &quot;&quot;,
#   &quot;AdvertSize&quot;: &quot;&quot;,
#   &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#   &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#   &quot;AnalyticsLabel&quot;: &quot;Rankings&quot;,
#   &quot;MenuItems&quot;: [
#     {
#       &quot;Title&quot;: &quot;Rankings Home&quot;,
#       &quot;Link&quot;: &quot;/en/rankings&quot;,
#       &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#       &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#       &quot;AnalyticsLabel&quot;: &quot;Rankings Home&quot;
#     },
#     {
#       &quot;Title&quot;: &quot;Singles&quot;,
#       &quot;Link&quot;: &quot;/en/rankings/singles&quot;,
#       &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#       &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#       &quot;AnalyticsLabel&quot;: &quot;Singles&quot;
#     },
#     {
#       &quot;Title&quot;: &quot;Doubles&quot;,
#       &quot;Link&quot;: &quot;/en/rankings/doubles&quot;,
#       &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#       &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#       &quot;AnalyticsLabel&quot;: &quot;Doubles&quot;
#     },
#     {
#       &quot;Title&quot;: &quot;Doubles Race&quot;,
#       &quot;Link&quot;: &quot;/en/rankings/doubles-race-to-london&quot;,
#       &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#       &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#       &quot;AnalyticsLabel&quot;: &quot;Doubles Race&quot;
#     },
#     {
#       &quot;Title&quot;: &quot;Former No. 1s&quot;,
#       &quot;Link&quot;: &quot;/en/rankings/former-no-1s&quot;,
#       &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#       &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#       &quot;AnalyticsLabel&quot;: &quot;Former No. 1s&quot;
#     },
#     {
#       &quot;Title&quot;: &quot;Rankings FAQ&quot;,
#       &quot;Link&quot;: &quot;/en/rankings/rankings-faq&quot;,
#       &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#       &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#       &quot;AnalyticsLabel&quot;: &quot;Rankings FAQ&quot;
#     }
#   ]
# }">
#             <a href="/en/rankings" data-ga-label="Rankings"
#                data-ga-category="Main Navigation"
#                data-ga-action="Click" class="nav-push">
#                 Rankings
#             </a>
#     </li>
#     <li data-sub-navigation-json="{
#   &quot;Title&quot;: &quot;Players&quot;,
#   &quot;SponsorLink&quot;: &quot;&quot;,
#   &quot;SponsorLogo&quot;: &quot;&quot;,
#   &quot;AdvertLink&quot;: &quot;&quot;,
#   &quot;AdvertImage&quot;: &quot;&quot;,
#   &quot;AdvertSize&quot;: &quot;&quot;,
#   &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#   &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#   &quot;AnalyticsLabel&quot;: &quot;Players&quot;,
#   &quot;MenuItems&quot;: [
#     {
#       &quot;Title&quot;: &quot;Players Home&quot;,
#       &quot;Link&quot;: &quot;/en/players&quot;,
#       &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#       &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#       &quot;AnalyticsLabel&quot;: &quot;Players Home&quot;
#     },
#     {
#       &quot;Title&quot;: &quot;Performance Zone&quot;,
#       &quot;Link&quot;: &quot;/en/performance-zone&quot;,
#       &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#       &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#       &quot;AnalyticsLabel&quot;: &quot;Performance Zone&quot;
#     },
#     {
#       &quot;Title&quot;: &quot;My Point&quot;,
#       &quot;Link&quot;: &quot;/en/news/news-filter-results/all/features/my-point/all/all&quot;,
#       &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#       &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#       &quot;AnalyticsLabel&quot;: &quot;My Point&quot;
#     },
#     {
#       &quot;Title&quot;: &quot;Five Things To Know&quot;,
#       &quot;Link&quot;: &quot;/en/news/news-filter-results/all/features/all/five-things-to-know/all/all/&quot;,
#       &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#       &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#       &quot;AnalyticsLabel&quot;: &quot;Five Things To Know&quot;
#     },
#     {
#       &quot;Title&quot;: &quot;Win Loss Index&quot;,
#       &quot;Link&quot;: &quot;/en/performance-zone/win-loss-index&quot;,
#       &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#       &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#       &quot;AnalyticsLabel&quot;: &quot;Win Loss Index&quot;
#     },
#     {
#       &quot;Title&quot;: &quot;ATP Coach Members&quot;,
#       &quot;Link&quot;: &quot;/en/players/coaches&quot;,
#       &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#       &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#       &quot;AnalyticsLabel&quot;: &quot;ATP Coach Members&quot;
#     },
#     {
#       &quot;Title&quot;: &quot;Coaches&#39; Corner&quot;,
#       &quot;Link&quot;: &quot;/en/news/news-filter-results/all/features/coach/all/all/&quot;,
#       &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#       &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#       &quot;AnalyticsLabel&quot;: &quot;Coaches&#39; Corner&quot;
#     }
#   ]
# }">
#             <a href="/en/players" data-ga-label="Players"
#                data-ga-category="Main Navigation"
#                data-ga-action="Click" class="nav-push">
#                 Players
#             </a>
#     </li>
#     <li data-sub-navigation-json="{
#   &quot;Title&quot;: &quot;Tournaments&quot;,
#   &quot;SponsorLink&quot;: &quot;&quot;,
#   &quot;SponsorLogo&quot;: &quot;&quot;,
#   &quot;AdvertLink&quot;: &quot;&quot;,
#   &quot;AdvertImage&quot;: &quot;&quot;,
#   &quot;AdvertSize&quot;: &quot;&quot;,
#   &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#   &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#   &quot;AnalyticsLabel&quot;: &quot;Tournaments&quot;,
#   &quot;MenuItems&quot;: [
#     {
#       &quot;Title&quot;: &quot;Calendar&quot;,
#       &quot;Link&quot;: &quot;/en/tournaments&quot;,
#       &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#       &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#       &quot;AnalyticsLabel&quot;: &quot;Calendar&quot;
#     },
#     {
#       &quot;Title&quot;: &quot;ATP Cup&quot;,
#       &quot;Link&quot;: &quot;http://www.atpcup.com&quot;,
#       &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#       &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#       &quot;AnalyticsLabel&quot;: &quot;ATP Cup&quot;
#     },
#     {
#       &quot;Title&quot;: &quot;
quot;,
#       &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#       &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#       &quot;AnalyticsLabel&quot;: &quot;Uncovered&quot;
#     },
#     {
#       &quot;Title&quot;: &quot;Watch Live&quot;,
#       &quot;Link&quot;: &quot;/en/video/watch-live&quot;,
#       &quot;AnalyticsCategory&quot;: &quot;Main Navigation&quot;,
#       &quot;AnalyticsAction&quot;: &quot;Click&quot;,
#       &quot;AnalyticsLabel&quot;: &quot;Watch Live&quot;
#     }
#   ]
# }">
#             <a href="/en/video" data-ga-label="Video"
#                data-ga-category="Main Navigation"
#                data-ga-action="Click" class="nav-push">
#                 Video
#             </a>
#     </li>
#
#                 </ul>
#             </div>
#             <div class="nav-section">
#                 <span class="nav-section-title">Other Tours</span>
#
#                     <ul class="nav-list secondary">
#                             <li>
#                                 <a class="external" target="_blank" href="/en/atp-challenger-tour">
#                                 ATP Challenger Tour
#                                 </a>
#                             </li>
#                             <li>
#                                 <a class="external" target="_blank" href="http://www.atpchampionstour.com/">
#                                 ATP Champions Tour
#                                 </a>
#                             </li>
#                     </ul>
#
#                     <div class="nav-section change-language">
#                         <span class="nav-section-title">Change Language</span>
#                         <div class="language-flags">
#                                 <a href="/en/players/,-w-,/,-w-,/overview" ><img src="/-/media/images/flags/esp.svg?h=32&amp;iar=0&amp;w=44&amp;hash=8551A726138A1EF828794408742F58C5" alt="zh" width="44" height="32" /></a>
#                                 <a href="/en/players/,-w-,/,-w-,/overview" class=current><img src="/-/media/images/flags/gbr.svg?h=32&amp;iar=0&amp;w=44&amp;hash=278C0EF514ED1A4C121847AA22897F4E" alt="USA" width="44" height="32" /></a>
#                                 <a href="/en/players/,-w-,/,-w-,/overview" ><img src="/-/media/images/flags/jpn.svg?h=32&amp;iar=0&amp;w=44&amp;hash=2D1677FACC06E79B13604B5D0C46A115" alt="JPN" width="44" height="32" /></a>
#                                 <a href="/en/players/,-w-,/,-w-,/overview" ><img src="/-/media/images/flags/ita.svg?h=32&amp;iar=0&amp;w=44&amp;hash=5177FE4145D2B3EA8BF329CDF6838BAB" alt="ITA" width="44" height="32" /></a>
#                         </div>
#                     </div>
#                 <button id="closeNav" class="close-nav">
#                     <span>
#                         Close
#                     </span>
#                 </button>
#             </div>
#         </div>
#         <div id="subNav" class="sub-nav"></div>
#     </div>
# </script>
# <script id="subNavTemplate" type="text/template">
#     <span class="sub-nav-title"><%- rc.Title %></span>
#     <a href="<%- rc.SponsorLink %>" target="_blank" class="sponsor-logo" data-ga-label="<%- rc.AnalyticsLabel %>" dada-ga-category="<%- rc.AnalyticsCategory %>" data-ga-action="<%- rc.AnalyticsAction %>"><img alt="" src="<%- rc.SponsorLogo %>" /></a>
#     <div class="nav-section">
#         <ul class="nav-list">
#             <% _.each( rc.MenuItems, function( menuItem ) { %>
#             <li><a href="<%- menuItem.Link %>" data-ga-label="<%- menuItem.AnalyticsLabel %>" data-ga-category="<%- menuItem.AnalyticsCategory %>" data-ga-action="<%- menuItem.AnalyticsAction %>"><%- menuItem.Title %></a></li>
#             <% }); %>
#         </ul>
#     </div>
#     <div class="iab-wrapper"><a href="<%- rc.AdvertLink %>"><img alt="" src="<%- rc.AdvertImage %><%- rc.AdvertSize %>" /></a></div>
# </script>
# <div class="page-header" id="pageHeader">
# <!-- START: PAGEHEADER -->
# <div class="page-header-holder is-empty" data-outside-element="pageHeader">
# <h1 class="page-title">
#             Benoit Paire
#         </h1>
# <div class="sub-navigation-wrap" id="Player_subNav">
# ...
#                                                 <a v-bind:href="match.TeamOne.PlayerTwoLink" class="scoring-player-flag">
#                                                     <img v-bind:src="match.TeamOne.PlayerTwoFlag">
#                                                 </a>
#                                                 <a v-bind:href="match.TeamOne.PlayerTwoLink" class="scoring-player-name">{{match.TeamOne.PlayerTwoName}}</a>
#                                             </div>
#                                         </div>
#                                     </div>
#                                 </td>
#                                 <td v-html="match.TeamOne.Scores.CurrentScore" class="current-score"></td>
#                                 <td>
#                                     <span v-html="match.TeamOne.Scores.SetOne"></span>
#                                     <sup v-html="match.TeamOne.Scores.SetOneTiebreak"></sup>
#                                 </td>
#                                 <td>
#                                     <span v-html="match.TeamOne.Scores.SetTwo"></span>
#                                     <sup v-html="match.TeamOne.Scores.SetTwoTiebreak"></sup>
#                                 </td>
#                                 <td>
#                                     <span v-html="match.TeamOne.Scores.SetThree"></span>
#                                     <sup v-html="match.TeamOne.Scores.SetThreeTiebreak"></sup>
#                                 </td>
#                                 <template v-if="match.NumberOfSets === 5">
#                                     <td>
#                                         <span v-html="match.TeamOne.Scores.SetFour"></span>
#                                         <sup v-html="match.TeamOne.Scores.SetFourTiebreak"></sup>
#                                     </td>
#                                     <td>
#                                         <span v-html="match.TeamOne.Scores.SetFive"></span>
#                                         <sup v-html="match.TeamOne.Scores.SetFiveTiebreak"></sup>
#                                     </td>
#                                 </template>
#                             </tr>
#                             <tr>
#                                 <td v-bind:class="match.TeamTwo.TeamStatus">
#                                     <div class="scoring-players">
#                                         <div class="team">
#                                             <div class="scoring-player">
#                                                 <a v-bind:href="match.TeamTwo.PlayerOneLink" class="scoring-player-flag">
#                                                     <img v-bind:src="match.TeamTwo.PlayerOneFlag">
#                                                 </a>
#                                                 <a v-bind:href="match.TeamTwo.PlayerOneLink" class="scoring-player-name">{{match.TeamTwo.PlayerOneName}}</a>
#                                             </div>
#                                             <div v-if="match.MatchType === 'doubles'" class="scoring-player">
#                                                 <a v-bind:href="match.TeamTwo.PlayerTwoLink" class="scoring-player-flag">
#                                                     <img v-bind:src="match.TeamTwo.PlayerTwoFlag">
#                                                 </a>
#                                                 <a v-bind:href="match.TeamTwo.PlayerTwoLink" class="scoring-player-name">{{match.TeamTwo.PlayerTwoName}}</a>
#                                             </div>
#                                         </div>
#                                     </div>
#                                 </td>
#                                 <td v-html="match.TeamTwo.Scores.CurrentScore" class="current-score"></td>
#                                 <td>
#                                     <span v-html="match.TeamTwo.Scores.SetOne"></span>
#                                     <sup v-html="match.TeamTwo.Scores.SetOneTiebreak"></sup>
#                                 </td>
#                                 <td>
#                                     <span v-html="match.TeamTwo.Scores.SetTwo"></span>
#                                     <sup v-html="match.TeamTwo.Scores.SetTwoTiebreak"></sup>
#                                 </td>
#                                 <td>
#                                     <span v-html="match.TeamTwo.Scores.SetThree"></span>
#                                     <sup v-html="match.TeamTwo.Scores.SetThreeTiebreak"></sup>
#                                 </td>
#                                 <template v-if="match.NumberOfSets === 5">
#                                     <td>
#                                         <span v-html="match.TeamTwo.Scores.SetFour"></span>
#                                         <sup v-html="match.TeamTwo.Scores.SetFourTiebreak"></sup>
#                                     </td>
#                                     <td>
#                                         <span v-html="match.TeamTwo.Scores.SetFive"></span>
#                                         <sup v-html="match.TeamTwo.Scores.SetFiveTiebreak"></sup>
#                                     </td>
#                                 </template>
#                             </tr>
#                             <tr class="match-info-row">
#                                 <td v-bind:colspan="match.NumberOfSets === 5 ? 7 : 5 ">{{match.MatchInfo}}</td>
#
#                             </tr>
#                         </tbody>
#                     </table>
#                 </div>
#
#             </div>
#         </div>
#     </div>
#
# </script>
# </div>
# <!-- START : /modules/global/footer -->
# <!-- START : /modules/global/footer -->
# <div class="container footer" id="footer">
# <div class="footer-holder" id="footerLinksHolder">
# <div class="footer-links-column">
# <h6 class="footer-links-title">Corporate</h6>
# <ul class="footer-links">
# <li>
# <a data-ga-action="Click" data-ga-category="Outbound" data-ga-label="About" href="/en/corporate/about">About</a>
# </li>
# <li>
# <a data-ga-action="Click" data-ga-category="Outbound" data-ga-label="Careers" href="/en/corporate/careers">Careers</a>
# </li>
# <li>
# <a data-ga-action="Click" data-ga-category="Outbound" data-ga-label="Structure" href="/en/corporate/structure">Structure</a>
# </li>
# <li>
# <a data-ga-action="Click" data-ga-category="Outbound" data-ga-label="Senior Leadership Team" href="/en/corporate/management">Senior Leadership Team</a>
# </li>
# <li>
# <a data-ga-action="Click" data-ga-category="Outbound" data-ga-label="Board of Directors" href="/en/corporate/board-of-directors">Board of Directors</a>
# </li>
# <li>
# <a data-ga-action="Click" data-ga-category="Outbound" data-ga-label="Rulebook" href="/en/corporate/rulebook">Rulebook</a>
# </li>
# <li>
# <a data-ga-action="Click" data-ga-category="Outbound" data-ga-label="ATP Aces for Charity" href="/en/corporate/atp-aces-for-charity">ATP Aces for Charity</a>
# </li>
# <li>
# <a data-ga-action="Click" data-ga-category="Outbound" data-ga-label="History" href="/en/corporate/history">History</a>
# </li>
# </ul>
# </div>
# <div class="footer-links-column">
# <h6 class="footer-links-title">Media</h6>
# <ul class="footer-links">
# <li>
# <a data-ga-action="Click" data-ga-category="Outbound" data-ga-label="RSS Feed" href="/en/media/rss-feed">RSS Feed</a>
# </li>
# <li>
# <a data-ga-action="Click" data-ga-category="Outbound" data-ga-label="Newsletters" href="/en/newsletters/subscribe">Newsletters</a>
# </li>
# <li>
# <a data-ga-action="Click" data-ga-category="Outbound" data-ga-label="Rankings and Info Reports" href="/en/media/rankings-and-stats">Rankings and Info Reports</a>
# </li>
# <li>
# <a data-ga-action="Click" data-ga-category="Outbound" data-ga-label="Media Guide" href="/en/media/mediaguide">Media Guide</a>
# </li>
# <li>
# <a data-ga-action="Click" data-ga-category="Outbound" data-ga-label="News Releases" href="/en/media/media-releases">News Releases</a>
# </li>
# <li>
# <a class="external" data-ga-action="Click" data-ga-category="Outbound" data-ga-label="Daily Media Notes" href="https://www.atptour.com/en/media/daily-media-notes?year=2020">Daily Media Notes</a>
# </li>
# <li>
# <a class="external" data-ga-action="Click" data-ga-category="Outbound" data-ga-label="ATP Tour Archive" href="https://www.atptourarchive.com/" target="_blank">ATP Tour Archive</a>
# </li>
# </ul>
# </div>
# <div class="footer-links-column">
# <h6 class="footer-links-title">Partnerships</h6>
# <ul class="footer-links">
# <li>
# <a data-ga-action="Click" data-ga-category="Outbound" data-ga-label="Partnership Opportunities" href="/en/partnership-opportunities">Partnership Opportunities</a>
# </li>
# <li>
# <a data-ga-action="Click" data-ga-category="Outbound" data-ga-label="Official ATP Tennis Club" href="/en/partnerships/official-atp-tennis-club">Official ATP Tennis Club</a>
# </li>
# <li>
# <a data-ga-action="Click" data-ga-category="Outbound" data-ga-label="ATP Partners" href="/en/partnerships/atp-partners">ATP Partners</a>
# </li>
# </ul>
# </div>
# <div class="footer-links-column">
# <h6 class="footer-links-title">Affiliates</h6>
# <ul class="footer-links">
# <li>
# <a class="external" data-ga-action="Click" data-ga-category="Outbound" data-ga-label="GPTCA" href="http://www.gptcatennis.org" target="_blank">GPTCA</a>
# </li>
# <li>
# <a class="external" data-ga-action="Click" data-ga-category="Outbound" data-ga-label="Women's Tennis Association" href="http://www.wtatennis.com" target="_blank">Women's Tennis Association</a>
# </li>
# <li>
# <a class="external" data-ga-action="Click" data-ga-category="Outbound" data-ga-label="Intl. Tennis Federation" href="http://www.itftennis.com" target="_blank">Intl. Tennis Federation</a>
# </li>
# <li>
# <a class="external" data-ga-action="Click" data-ga-category="Outbound" data-ga-label="Intl. Tennis Hall of Fame" href="http://www.tennisfame.com" target="_blank">Intl. Tennis Hall of Fame</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="footer-foot">
# <div class="copyright">
# <p>
# <style>
#     .summary-tbody td[data-type*='Rating'] {
#     background: none;
#     }
#     .is-desktop .atp-logo{
#     margin-right:15px;
#     }
#     .atp-nav-list&gt;.atp-nav-item {
#     float: left;
#     margin-left: 15px;
#     position: relative;
#     width: auto;
#     }
#     .atp-nav-list&gt;.atp-nav-item&gt;a {
#     font-size:15px;
#     }
#     .breakpoint-768 .sub-header-links{display:none;}
#     .is-mobile .scores-daily-schedule-content td.day-table-seed, .scores-results-content td.day-table-seed {
#     padding-left: 0px;
#     width: 32px;
#     }
#     .tourney-details.action-buttons a[href*="watch-live"] {
#     display: none !important;
#     }
#     a[href*="540/draws?matchType=qualifier"]{
#     display:none;
#     }
#     a[href*="540/live-scores"] {
#     display:none;
#     }
#     .tourney-details.action-buttons a[href*="560/live-scores"] {
#     border-left: 2px solid;
#     }
# </style>
# </p><p>© Copyright 1994 - 2020 ATP Tour, Inc. All Rights Reserved. No part of this site may be reproduced, stored in a retrieval system or transmitted in any way or by any means (including photocopying, recording or storing it in any medium by electronic means), without the written permission of ATP Tour, Inc..</p>
# <ul class="copyright-links">
# <li>
# <a href="/en/terms-and-conditions">
#                         Terms &amp; Conditions
#                     </a>
# </li>
# <li>
# <a href="/en/privacy-policy">
#                         Privacy
#                     </a>
# </li>
# <li>
# <a href="/en/corporate/modern-slavery-statement">
#                         Modern Slavery Statement
#                     </a>
# </li>
# <li>
# <a href="/en/contact-us">
#                         Feedback
#                     </a>
# </li>
# </ul>
# </div>
# <ul class="footer-social">
# <li>
# <a class="icon-facebook-circleless" ga-action="Click" ga-category="Outbound" ga-label="Facebook" ga-use="true" href="https://www.facebook.com/ATPTour" target="_blank"></a>
# </li>
# <li>
# <a class="icon-twitter-circleless" ga-action="Click" ga-category="Outbound" ga-label="Twitter" ga-use="true" href="https://twitter.com/atptour" target="_blank"></a>
# </li>
# <li>
# <a class="icon-instagram-circleless" ga-action="Click" ga-category="Outbound" ga-label="Instagram" ga-use="true" href="https://instagram.com/atptour" target="_blank"></a>
# </li>
# <li>
# <a class="icon-youtube-circleless" ga-action="Click" ga-category="Outbound" ga-label="Youtube" ga-use="true" href="https://www.youtube.com/ATPWorldTour" target="_blank"></a>
# </li>
# </ul>
# </div>
# </div>
# <!-- END : /modules/global/footer -->
# </div>
# <!-- END : WRAPPER-->
# <!-- END : /modules/global/footer -->
# <!-- START: /modules/global/atp-loader -->
# <!-- END: /modules/global/atp-loader -->
# <script type="text/javascript">
#         function openLSHDWindow(year, wkno, eventid, tour, lang, ref_file, width, height, hasScrollBars) {
#             // ADD NAME FIELD and make sure it get's focus!!!
#             var theWidth = width;
#             var theHeight = height;
#             var scrollBars = "scrollbars";
#             if (hasScrollBars == false) scrollBars = "scrollbars=0";
#             if ((theWidth == "") || (theWidth == null)) theWidth = 1042;
#             if ((theHeight == "") || (theHeight == null)) theHeight = 631;
#             var theLeft = (screen.availWidth - theWidth) / 2;
#             var theTop = (screen.availHeight - theHeight) / 2;
#             var strCheckRef = escape(ref_file);
#
#             var lsURL = "https://www.protennislive.com/LSHD/main.html?year=" +
#                 year +
#                 "&wkno=" +
#                 wkno +
#                 "&eventid=" +
#                 eventid +
#                 "&tour=" +
#                 tour +
#                 "&lang=" +
#                 lang +
#                 "&ref=" +
#                 strCheckRef;
#
#             var popupWin = window.open(lsURL,
#                 '_' + Math.round(Math.random() * 1000000),
#                 'top=' +
#                 theTop +
#                 ',left=' +
#                 theLeft +
#                 ',menubar=0,toolbar=0,location=0,directories=0,status=0,' +
#                 scrollBars +
#                 ',width=' +
#                 theWidth +
#                 ', height=' +
#                 theHeight);
#         }
#
#     function openLSBTFWindow(year, wkno, eventid, tour, lang, ref_file, width, height, hasScrollBars) {
#         // ADD NAME FIELD and make sure it get's focus!!!
#         var theWidth = width;
#         var theHeight = height;
#         var scrollBars = "scrollbars";
#         if (hasScrollBars == false) scrollBars = "scrollbars=0";
#         if ((theWidth == "") || (theWidth == null)) theWidth = 1042;
#         if ((theHeight == "") || (theHeight == null)) theHeight = 631;
#         var theLeft = (screen.availWidth - theWidth) / 2;
#         var theTop = (screen.availHeight - theHeight) / 2;
#         var strCheckRef = escape(ref_file);
#
#         lsURL = "https://www.protennislive.com/lsbtf/main.html?year=" +
#             year +
#             "&wkno=" +
#             wkno +
#             "&eventid=" +
#             eventid +
#             "&tour=" +
#             tour +
#             "&lang=" +
#             lang +
#             "&ref=" +
#             strCheckRef;
#
#         var popupWin = window.open(lsURL,
#             '_' + Math.round(Math.random() * 1000000),
#             'top=' +
#             theTop +
#             ',left=' +
#             theLeft +
#             ',menubar=0,toolbar=0,location=0,directories=0,status=0,' +
#             scrollBars +
#             ',width=' +
#             theWidth +
#             ', height=' +
#             theHeight);
#     }
#     </script>
# <script type="text/javascript">
#
#         setTimeout(function () {
#             var a = document.createElement("script");
#             var b = document.getElementsByTagName("script")[0];
#             a.src = document.location.protocol +
#                 "//script.crazyegg.com/pages/scripts/0014/0351.js?" +
#                 Math.floor(new Date().getTime() / 3600000);
#             a.async = true;
#             a.type = "text/javascript";
#             b.parentNode.insertBefore(a, b)
#         },
#             1);
#     </script>
# </body>
# <!-- RUM's Footer 1.3.3.0 -->
# </html>

# %%
# -- Get Player Name
player_first_name_html = player_html.find("div", attrs={"class": "first-name"})
player_first_name = player_first_name_html.text.strip()

player_surname_html = player_html.find("div", attrs={"class": "last-name"})
player_surname = player_surname_html.text.strip()

player_name = player_first_name + ' ' + player_surname
player_name
# Out:
# 'Benoit Paire'

# %%
# -- Get player weight in imperial units
player_weight_lbs = player_html.find("span", attrs={"class": "table-weight-lbs"})
player_weight_lbs.text
# Out:
# '176'

# %%
# -- Get player weight in kg
player_weight_kg = player_html.find("span", attrs={"class": "table-weight-kg-wrapper"})
player_weight_kg.text.lower().replace('(','').replace('kg)','')
# Out:
# '80'

# %%
# -- Get player height in feet & inches
player_height_imp = player_html.find("span", attrs={"class": "table-height-ft"})
player_height_imp.text
# Out:
# '6\'5"'

# %%
# -- Get player height in cm
player_height_cm = player_html.find("span", attrs={"class": "table-height-cm-wrapper"})
player_height_cm.text.lower().replace('(','').replace('cm)','')
# Out:
# '196'

# %%
# -- Get player handedness
for item in player_html.find_all("div", attrs={"class": "table-value"}):
    if 'handed' in item.text.lower().strip():
        player_handedness = item.text.lower().strip().split(',')[0]
player_handedness
# Out:
# 'right-handed'
